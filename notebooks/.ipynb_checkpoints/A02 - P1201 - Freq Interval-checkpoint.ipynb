# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
import os
import ntpath
import pickle as pkl
import xlrd
import time
import string
import math

from os import listdir
from os.path import isfile, join

# %% [markdown]
# ### Notebook options

# %%
pd.set_option('display.max_colwidth', -1) # Column width
plt.rcParams['figure.figsize'] = [15, 10] # Size of the plots

# %% [markdown]
# ### General Assumptions

# %%
time_col = 'datetime'
time_gran_col = 'datetime_gran'
value_col = 'val'
scaled_value_col = 'scaled_val'
time_granularity = 'min'

# %%
fmt = '%Y-%m-%d %H:%M:%S'
base_date = datetime.strptime('2016-01-01 00:00:01', fmt)
start_date = datetime.strptime('2016-01-01 00:00:01', fmt)
stop_date = datetime.strptime('2019-01-01 00:00:01', fmt)

# %% [markdown]
# ### Data Directories

# %%
pump = 'P1201'
RAW_DATA_DIR = '../data/raw/'+pump+'/'
PROC_DATA_DIR = '../data/processed/'+pump+'/'
INT_DATA_DIR = '../data/interim/'+pump+'/'

# %% [markdown]
# ### Reading Interim Data - tag separated

# %%
from utils import read_data_withfeature
df_features_all = read_data_withfeature(INT_DATA_DIR + 'initial/', True)
# Out:
# Number of files found in ../data/interim/P1201/initial/ is 42
# ../data/interim/P1201/initial/HART_P1CP04-PY12003AFB.MEAS.pkl ['HART_P1CP04:PY12003AFB.MEAS']
# ../data/interim/P1201/initial/12GTWY_E101-ZAE12131FI.CIN.pkl ['12GTWY_E101:ZAE12131FI.CIN']
# ../data/interim/P1201/initial/HART_P1CP04-FY12847FB.MEAS.pkl ['HART_P1CP04:FY12847FB.MEAS']
# ../data/interim/P1201/initial/HART_U1CP03-PY24092FB.MEAS.pkl ['HART_U1CP03:PY24092FB.MEAS']
# ../data/interim/P1201/initial/12GTWY_FG404-AAH12570SP.PNT.pkl ['12GTWY_FG404:AAH12570SP.PNT']
# ../data/interim/P1201/initial/HART_P1CP01-PI12046BT.MEAS.pkl ['HART_P1CP01:PI12046BT.MEAS']
# ../data/interim/P1201/initial/12GTWY_FG404-AAH12569SP.PNT.pkl ['12GTWY_FG404:AAH12569SP.PNT']
# ../data/interim/P1201/initial/12V04CP4-PC12007.MEAS.pkl ['12V04CP4:PC12007.MEAS']
# ../data/interim/P1201/initial/HART_P1CP04-PY12109FB.MEAS.pkl ['HART_P1CP04:PY12109FB.MEAS']
# ../data/interim/P1201/initial/12GTWY_FG404-AAH12555BSP.PNT.pkl ['12GTWY_FG404:AAH12555BSP.PNT']
# ../data/interim/P1201/initial/12GTWY_E101-FTE12404MS.CIN.pkl ['12GTWY_E101:FTE12404MS.CIN']
# ../data/interim/P1201/initial/12V04CP4-LC12005A.MEAS.pkl ['12V04CP4:LC12005A.MEAS']
# ../data/interim/P1201/initial/12P01BCP4-FC12847.OUT.pkl ['12P01BCP4:FC12847.OUT']
# ../data/interim/P1201/initial/HART_U1CP03-PX12003BT.MEAS.pkl ['HART_U1CP03:PX12003BT.MEAS']
# ../data/interim/P1201/initial/12V04CP4-FC12006.OUT.pkl ['12V04CP4:FC12006.OUT']
# ../data/interim/P1201/initial/HART_P1CP04-PY12516FB.MEAS.pkl ['HART_P1CP04:PY12516FB.MEAS']
# ../data/interim/P1201/initial/HART_P1CP04-PX12003FB.MEAS.pkl ['HART_P1CP04:PX12003FB.MEAS']
# ../data/interim/P1201/initial/12GTWY_E101-FALE12404FI.CIN.pkl ['12GTWY_E101:FALE12404FI.CIN']
# ../data/interim/P1201/initial/HART_P1CP01-PI12037BT.MEAS.pkl ['HART_P1CP01:PI12037BT.MEAS']
# ../data/interim/P1201/initial/HART_P1CP01-PI12026BT.MEAS.pkl ['HART_P1CP01:PI12026BT.MEAS']
# ../data/interim/P1201/initial/12GTWY_E101-E12101FI.CIN.pkl ['12GTWY_E101:E12101FI.CIN']
# ../data/interim/P1201/initial/HART_P1CP04-PY12110FB.MEAS.pkl ['HART_P1CP04:PY12110FB.MEAS']
# ../data/interim/P1201/initial/12P01BCP4-XI12597.CIN.pkl ['12P01BCP4:XI12597.CIN']
# ../data/interim/P1201/initial/HART_P1CP04-LY12001FB.MEAS.pkl ['HART_P1CP04:LY12001FB.MEAS']
# ../data/interim/P1201/initial/12GTWY_FG404-AI12554B.PNT.pkl []
# ../data/interim/P1201/initial/12P01BCP4-FC12847.SPT.pkl ['12P01BCP4:FC12847.SPT']
# ../data/interim/P1201/initial/12V05CP4-PC12073.MEAS.pkl ['12V05CP4:PC12073.MEAS']
# ../data/interim/P1201/initial/12P01BCP4-PI12956.PNT.pkl ['12P01BCP4:PI12956.PNT']
# ../data/interim/P1201/initial/12V08CP4-FC12351.MEAS.pkl ['12V08CP4:FC12351.MEAS']
# ../data/interim/P1201/initial/12DATASCRCP1-TI12813.PNT.pkl ['12DATASCRCP1:TI12813.PNT']
# ../data/interim/P1201/initial/12V04CP4-FC12006.MEAS.pkl ['12V04CP4:FC12006.MEAS']
# ../data/interim/P1201/initial/12GTWY_E101-FIE12404.PNT.pkl ['12GTWY_E101:FIE12404.PNT']
# ../data/interim/P1201/initial/HART_P1CP04-PI12003BT.MEAS.pkl ['HART_P1CP04:PI12003BT.MEAS']
# ../data/interim/P1201/initial/12P01BCP4-PI12955.PNT.pkl ['12P01BCP4:PI12955.PNT']
# ../data/interim/P1201/initial/HART_P1CP04-HY12017FB.MEAS.pkl ['HART_P1CP04:HY12017FB.MEAS']
# ../data/interim/P1201/initial/12P01BCP4-FC12847.MEAS.pkl ['12P01BCP4:FC12847.MEAS']
# ../data/interim/P1201/initial/12GTWY_E104-E12104FI.CIN.pkl ['12GTWY_E104:E12104FI.CIN']
# ../data/interim/P1201/initial/12GTWY_E104-HAE12131FI.CIN.pkl ['12GTWY_E104:HAE12131FI.CIN']
# ../data/interim/P1201/initial/12GTWY_FG404-AAH12554BSP.PNT.pkl ['12GTWY_FG404:AAH12554BSP.PNT']
# ../data/interim/P1201/initial/12GTWY_E428-HAE12646FI.CIN.pkl ['12GTWY_E428:HAE12646FI.CIN']
# ../data/interim/P1201/initial/HART_P1CP04-FI12002BT.MEAS.pkl ['HART_P1CP04:FI12002BT.MEAS']
# ../data/interim/P1201/initial/12GTWY_E101-FALE12404SP.PNT.pkl ['12GTWY_E101:FALE12404SP.PNT']
# Number of features extracted from 42 files is 41

# %% [markdown]
# ### Tags provided in the metadata file

# %%
metadata_tags = ['12GTWY_E101:FALE12404SP.PNT',
'12GTWY_E101:FIE12404.PNT',
'12P01BCP4:FC12847.MEAS',
'12P01BCP4:FC12847.OUT',
'12P01BCP4:FC12847.SPT',
'12P01BCP4:PI12955.PNT',
'12P01BCP4:PI12956.PNT',
'12P01BCP4:XI12597.CIN',
'HART_P1CP04:FY12847FB.MEAS',
'12V04CP4:FC12006.MEAS',
'12V04CP4:FC12006.OUT',
'12V04CP4:PC12007.MEAS',
'12V05CP4:PC12073.MEAS',
'12V04CP4:LC12005A.MEAS',
'12V08CP4:FC12351.MEAS',
'12DATASCRCP1:TI12813.PNT']

print('Length of the metadata tags ', len(metadata_tags))
# Out:
# Length of the metadata tags  16

# %%
# Number of common files
avail_tags = list(df_features_all.keys())
common_tags = set(metadata_tags).intersection(set(avail_tags))
extra_tags = set(avail_tags)-set(metadata_tags)
print(len(common_tags))
print(common_tags)

print(len(extra_tags))
print(extra_tags)

use_tags = common_tags
# Out:
# 16
# {'12P01BCP4:FC12847.MEAS', '12V05CP4:PC12073.MEAS', '12DATASCRCP1:TI12813.PNT', '12GTWY_E101:FALE12404SP.PNT', '12P01BCP4:PI12955.PNT', '12V04CP4:FC12006.MEAS', '12V04CP4:FC12006.OUT', '12P01BCP4:FC12847.OUT', '12GTWY_E101:FIE12404.PNT', '12V04CP4:PC12007.MEAS', 'HART_P1CP04:FY12847FB.MEAS', '12P01BCP4:FC12847.SPT', '12V04CP4:LC12005A.MEAS', '12P01BCP4:XI12597.CIN', '12V08CP4:FC12351.MEAS', '12P01BCP4:PI12956.PNT'}
# 25
# {'12GTWY_E104:E12104FI.CIN', '12GTWY_FG404:AAH12554BSP.PNT', '12GTWY_E101:FTE12404MS.CIN', 'HART_P1CP04:PY12003AFB.MEAS', 'HART_P1CP04:PY12110FB.MEAS', 'HART_U1CP03:PX12003BT.MEAS', '12GTWY_FG404:AAH12569SP.PNT', 'HART_U1CP03:PY24092FB.MEAS', '12GTWY_FG404:AAH12555BSP.PNT', 'HART_P1CP01:PI12037BT.MEAS', 'HART_P1CP01:PI12026BT.MEAS', 'HART_P1CP04:FI12002BT.MEAS', 'HART_P1CP04:PX12003FB.MEAS', 'HART_P1CP04:LY12001FB.MEAS', 'HART_P1CP04:PY12109FB.MEAS', '12GTWY_E101:ZAE12131FI.CIN', 'HART_P1CP04:HY12017FB.MEAS', 'HART_P1CP04:PY12516FB.MEAS', '12GTWY_E104:HAE12131FI.CIN', 'HART_P1CP01:PI12046BT.MEAS', '12GTWY_E428:HAE12646FI.CIN', '12GTWY_E101:FALE12404FI.CIN', '12GTWY_E101:E12101FI.CIN', 'HART_P1CP04:PI12003BT.MEAS', '12GTWY_FG404:AAH12570SP.PNT'}

# %%
df_features = {}
for feature in use_tags:
    if feature in df_features_all.keys():
        df_features[feature] = df_features_all[feature]
    else:
        print('Feature ', feature, 'not found in df_features_all')

# %%
print('Number of features = ', len(list(df_features.keys())))
# Out:
# Number of features =  16

# %% [markdown]
# ### Remove features with substantial missing values

# %%
from utils import remove_missing_features
df_features = remove_missing_features(df_features, 'val', 20.0)

# %%
print('Number of features = ', len(list(df_features.keys())))
# Out:
# Number of features =  16

# %%
df_features.keys()
# Out:
# dict_keys(['12P01BCP4:FC12847.MEAS', '12V05CP4:PC12073.MEAS', '12DATASCRCP1:TI12813.PNT', '12GTWY_E101:FALE12404SP.PNT', '12P01BCP4:PI12955.PNT', '12V04CP4:FC12006.MEAS', '12V04CP4:FC12006.OUT', '12P01BCP4:FC12847.OUT', '12GTWY_E101:FIE12404.PNT', '12V04CP4:PC12007.MEAS', 'HART_P1CP04:FY12847FB.MEAS', '12P01BCP4:FC12847.SPT', '12V04CP4:LC12005A.MEAS', '12P01BCP4:XI12597.CIN', '12V08CP4:FC12351.MEAS', '12P01BCP4:PI12956.PNT'])

# %% [markdown]
# ### Data Aggregation for duplicate timestamps

# %%
from utils import agg_data_dup_timestamps
print(time_col)
df_features_agg = agg_data_dup_timestamps(df_features = df_features, 
                        # feature_set=['22P53CP4:PI22F31.PNT', '22P53CP4:FX22E22SPF.MEAS', 'UBNV05CPB:XI22F29X.PNT', 'UBNV05CPB:ZI22F28.PNT'], 
                        feature_set = [],
                        time_granularity='min',
                        time_col=time_col,
                        value_col=value_col,
                        time_gran_col=time_gran_col,
                        base_date=base_date)
# Out:
# datetime
# 12P01BCP4:FC12847.MEAS -- Started Ended - Aggregated 784343 rows to 395645 rows
# 12V05CP4:PC12073.MEAS -- Started Ended - Aggregated 427927 rows to 422670 rows
# 12DATASCRCP1:TI12813.PNT -- Started Ended - Aggregated 427502 rows to 422301 rows
# 12GTWY_E101:FALE12404SP.PNT -- Started Ended - Aggregated 66142 rows to 37446 rows
# 12P01BCP4:PI12955.PNT -- Started Ended - Aggregated 784487 rows to 395660 rows
# 12V04CP4:FC12006.MEAS -- Started Ended - Aggregated 428021 rows to 422744 rows
# 12V04CP4:FC12006.OUT -- Started Ended - Aggregated 428003 rows to 422728 rows
# 12P01BCP4:FC12847.OUT -- Started Ended - Aggregated 61945 rows to 39035 rows
# 12GTWY_E101:FIE12404.PNT -- Started Ended - Aggregated 386447 rows to 377510 rows
# 12V04CP4:PC12007.MEAS -- Started Ended - Aggregated 427919 rows to 422750 rows
# HART_P1CP04:FY12847FB.MEAS -- Started Ended - Aggregated 163747 rows to 100562 rows
# 12P01BCP4:FC12847.SPT -- Started Ended - Aggregated 270028 rows to 70144 rows
# 12V04CP4:LC12005A.MEAS -- Started Ended - Aggregated 426422 rows to 421152 rows
# 12P01BCP4:XI12597.CIN -- Started Ended - Aggregated 56448 rows to 34912 rows
# 12V08CP4:FC12351.MEAS -- Started Ended - Aggregated 428527 rows to 423252 rows
# 12P01BCP4:PI12956.PNT -- Started Ended - Aggregated 784472 rows to 395625 rows

# %% [markdown]
# ### Writing down df_features_agg into pickle files

# %%
from utils import write_feature_dict
dir_path = INT_DATA_DIR + 'aggregated/'
write_feature_dict(dir_path, df_features_agg)
# Out:
# Writing to file  ../data/interim/P1201/aggregated/12P01BCP4-FC12847.MEAS.pkl (395645, 2)
# Writing to file  ../data/interim/P1201/aggregated/12V05CP4-PC12073.MEAS.pkl (422670, 2)
# Writing to file  ../data/interim/P1201/aggregated/12DATASCRCP1-TI12813.PNT.pkl (422301, 2)
# Writing to file  ../data/interim/P1201/aggregated/12GTWY_E101-FALE12404SP.PNT.pkl (37446, 2)
# Writing to file  ../data/interim/P1201/aggregated/12P01BCP4-PI12955.PNT.pkl (395660, 2)
# Writing to file  ../data/interim/P1201/aggregated/12V04CP4-FC12006.MEAS.pkl (422744, 2)
# Writing to file  ../data/interim/P1201/aggregated/12V04CP4-FC12006.OUT.pkl (422728, 2)
# Writing to file  ../data/interim/P1201/aggregated/12P01BCP4-FC12847.OUT.pkl (39035, 2)
# Writing to file  ../data/interim/P1201/aggregated/12GTWY_E101-FIE12404.PNT.pkl (377510, 2)
# Writing to file  ../data/interim/P1201/aggregated/12V04CP4-PC12007.MEAS.pkl (422750, 2)
# Writing to file  ../data/interim/P1201/aggregated/HART_P1CP04-FY12847FB.MEAS.pkl (100562, 2)
# Writing to file  ../data/interim/P1201/aggregated/12P01BCP4-FC12847.SPT.pkl (70144, 2)
# Writing to file  ../data/interim/P1201/aggregated/12V04CP4-LC12005A.MEAS.pkl (421152, 2)
# Writing to file  ../data/interim/P1201/aggregated/12P01BCP4-XI12597.CIN.pkl (34912, 2)
# Writing to file  ../data/interim/P1201/aggregated/12V08CP4-FC12351.MEAS.pkl (423252, 2)
# Writing to file  ../data/interim/P1201/aggregated/12P01BCP4-PI12956.PNT.pkl (395625, 2)

# %%
list(df_features_agg.keys())
# Out:
# ['12P01BCP4:FC12847.MEAS',
#  '12V05CP4:PC12073.MEAS',
#  '12DATASCRCP1:TI12813.PNT',
#  '12GTWY_E101:FALE12404SP.PNT',
#  '12P01BCP4:PI12955.PNT',
#  '12V04CP4:FC12006.MEAS',
#  '12V04CP4:FC12006.OUT',
#  '12P01BCP4:FC12847.OUT',
#  '12GTWY_E101:FIE12404.PNT',
#  '12V04CP4:PC12007.MEAS',
#  'HART_P1CP04:FY12847FB.MEAS',
#  '12P01BCP4:FC12847.SPT',
#  '12V04CP4:LC12005A.MEAS',
#  '12P01BCP4:XI12597.CIN',
#  '12V08CP4:FC12351.MEAS',
#  '12P01BCP4:PI12956.PNT']

# %% [markdown]
# ### Counting Frequency of read time intervals

# %%
from collections import Counter

def freq_intervals(df_features, feature_set, bin_size, percentage=False, plot=False):
    
    prev_time_gran_col = 'prev_' + time_gran_col
    prev_value_col = 'prev_' + value_col
    diff_in_time = 'diff_in_time'
    # total_plots = 0

    if len(feature_set) == 0:
        feature_set = list(df_features.keys())
                
    if plot:        
        total_plots = len(feature_set)
        cols_plot = 3
        rows_plot = math.ceil(total_plots/cols_plot)
        
        plt.rcParams['figure.figsize'] = [cols_plot * 10, rows_plot * 7] # Size of the plots
        plt.figure()
        
        xlabel = 'Time Granularity - mins/hr/day'
        ylabel = 'Frequency'
        
            
    idx = 1
    for feature in feature_set:
    
        df = df_features[feature].copy()
        
        print(feature + ' -- Started ', end='')

        df[prev_value_col] = df[value_col]
        df[prev_time_gran_col] = df[time_gran_col]

        # for i in range(1, len(df)):
        #    df.loc[i, prev_time_gran_col] = df.loc[i-1, time_gran_col]  
        
        df[prev_time_gran_col] = df[time_gran_col].shift(1)
        df.dropna(subset=[prev_time_gran_col], inplace=True)
        
        # Get the difference values
        df[diff_in_time] = df[time_gran_col] - df[prev_time_gran_col]
        
        # print(df.head())
        
        # Binning the dataset
        diff = df[diff_in_time].copy()
        
        buckets = diff.apply(lambda x: math.floor(x/bin_size) * bin_size)
        buckets = list(buckets)
        bucket_len = len(buckets)
        counter = Counter(buckets)

        # The percentages in frequency_dict wont add upto 100 since only
        # values more than 1 are added to the new dictionary - look at the 
        # if statement below
        frequency_dict = {}
        for k in counter:
            v = counter[k]
            if v > 0:
                if percentage:
                    v = v / bucket_len * 100.0
                    ylabel += ' (%)'
                k = str(k * bin_size + 1) + '-' + str( (k+1) * bin_size)
                frequency_dict[k] = v
                
        if plot:
            x = list(frequency_dict.keys())
            x = list(map(str, x))
            y = list(frequency_dict.values())
                        
            plt.subplot(rows_plot, cols_plot, idx)
            # plt.xlabel(xlabel)
            plt.ylabel(ylabel)
            plt.title(feature)
            plt.xticks(rotation=45)
            plt.bar(x,y)
            
            for i, v in enumerate(y):
                v = round(v, 2)
                plt.text(i-.25, v + .25, str(v), color='blue', fontweight='bold')
            
        print('Ended')
            
        idx += 1

# %%
freq_intervals(df_features=df_features_agg, 
               #feature_set=['22P53CP4:PI22F31.PNT', '22P53CP4:FX22E22SPF.MEAS', 'UBNV05CPB:XI22F29X.PNT', 'UBNV05CPB:ZI22F28.PNT'], 
               feature_set = [],
               bin_size=1, 
               percentage=False, 
               plot=True)
# Out:
# 12P01BCP4:FC12847.MEAS -- Started Ended
# 12V05CP4:PC12073.MEAS -- Started Ended
# 12DATASCRCP1:TI12813.PNT -- Started Ended
# 12GTWY_E101:FALE12404SP.PNT -- Started Ended
# 12P01BCP4:PI12955.PNT -- Started Ended
# 12V04CP4:FC12006.MEAS -- Started Ended
# 12V04CP4:FC12006.OUT -- Started Ended
# 12P01BCP4:FC12847.OUT -- Started Ended
# 12GTWY_E101:FIE12404.PNT -- Started Ended
# 12V04CP4:PC12007.MEAS -- Started Ended
# HART_P1CP04:FY12847FB.MEAS -- Started Ended
# 12P01BCP4:FC12847.SPT -- Started Ended
# 12V04CP4:LC12005A.MEAS -- Started Ended
# 12P01BCP4:XI12597.CIN -- Started Ended
# 12V08CP4:FC12351.MEAS -- Started Ended
# 12P01BCP4:PI12956.PNT -- Started Ended
