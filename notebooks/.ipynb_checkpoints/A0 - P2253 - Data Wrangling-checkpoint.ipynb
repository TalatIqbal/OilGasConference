# %% [markdown]
# # P1201 - Data Wrangling based on the tags available in Data string

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import os
import ntpath
import pickle as pkl
import xlrd
import time
import string
from os.path import basename

# %%
pd.set_option('display.max_colwidth', -1)

# %%
RAW_DATA_DIR = '../data/raw/P1201/'
PROC_DATA_DIR = '../data/processed/P1201/'
INT_DATA_DIR = '../data/interim/P1201/'

# %%
def remove_punctuation(x):
    table = str.maketrans({key: None for key in string.punctuation})
    return x.translate(table)

# %% [markdown]
# ### Functions

# %%
def remove_punctuation(x):
    table = str.maketrans({key: None for key in string.punctuation})
    return x.translate(table)

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
def get_time(dt_str):
    dt_str = dt_str.strip()
    dtobj = datetime.strptime(dt_str, '%m/%d/%Y %I:%M:%S %p')
    return dtobj

# %%
def parse(txt):
    '''
    @{PIPoint=SCTM:22GTWY_E403:FALE22E23SP.PNT; Value=60; Timestamp=12/30/2017 11:48:05 PM}
    '''
    pi_point, val, time  = None, None, None
    delimiter = ';'
    sub_delimiter = '='
    
    txt = txt[txt.find('{')+1:txt.find('}')]    
    parsed_vals = txt.split(';')
    
    if len(parsed_vals) >= 3:
        pi_point = parsed_vals[0].split(sub_delimiter)[1]
    
        values = parsed_vals[1].split(sub_delimiter)
        if len(values) >= 2:
            val = values[1]
            if is_number(val):
                val = float(val)
            else:
                val = None
        else:
            val = None

        time_vals = parsed_vals[2].split(sub_delimiter)
        if len(time_vals) >= 2:
            time = time_vals[1]
            time = get_time(time)
        else:
            return None, None, None
        
    pi_point = pi_point.replace('SCTM:', '')
    
    return pi_point, val, time

# %%
def scale_val(val, min_val, max_val):
    if val is not None:
        return (val-min_val)/(max_val-min_val + 1e-7)
    return None

# %%
def get_minutes_after(current_date, base_date):
    
    base_ts = time.mktime(base_date.timetuple()) # Converting to Unix timestamp
    current_ts = time.mktime(current_date.timetuple())
    time_diff_min = round((current_ts - base_ts) / 60.0)
    
    return time_diff_min

# %%
fmt = '%Y-%m-%d %H:%M:%S'
base_date = datetime.strptime('2017-01-01 00:00:01', fmt)

# %% [markdown]
# ### Reading of Data - Using tags to uniquely identify

# %%
data = {} # Contains mapping between tags and data
tag_files = {} # Contains mapping between tags and the file names
files_tag = {} # Contains the mapping between file names and tags

dir_files = os.listdir(RAW_DATA_DIR)
print('No of files in %s is %d' % (RAW_DATA_DIR, len(dir_files)))

for current_file in dir_files:
    
    current_base = current_file
    current_file = RAW_DATA_DIR + '/' + current_file
    
    print('Processing ', current_file, '\t', end='')
    df = pd.read_csv(current_file, header=None)
    
    df['feature'], df['val'], df['datetime'] = zip(*df[0].map(parse))
       
    df = df[df['feature'] != None]
    df = df[df['datetime'].notnull()]
        
    tags = np.unique(df['feature'])
    print('Tags Found = ', len(tags))
    
    for tag in tags:
        df_tag = df.loc[df['feature'] == tag]
        print('tag = ', tag, '\tsize =', df_tag.shape)
        
        if tag not in data.keys():
            data[tag] = pd.DataFrame(columns=df_tag.columns.values)
        data[tag] = data[tag].append(df_tag)
# Out:
# No of files in ../data/raw/P1201/ is 28
# Processing  ../data/raw/P1201//PI29562018.csv 	Tags Found =  1
# tag =  12P01BCP4:PI12956.PNT 	size = (387615, 4)
# Processing  ../data/raw/P1201//FC12847OUTS2018.csv 	Tags Found =  1
# tag =  12P01BCP4:FC12847.OUT 	size = (23799, 4)
# Processing  ../data/raw/P1201//PI12026BT2018.csv 	Tags Found =  1
# tag =  HART_P1CP01:PI12026BT.MEAS 	size = (22594, 4)
# Processing  ../data/raw/P1201//PI29552018.csv 	Tags Found =  1
# tag =  12P01BCP4:PI12955.PNT 	size = (387625, 4)
# Processing  ../data/raw/P1201//P1201_2_2018.csv 	Tags Found =  15
# tag =  HART_P1CP01:PI12026BT.MEAS 	size = (14901, 4)
# tag =  HART_P1CP01:PI12037BT.MEAS 	size = (14901, 4)
# tag =  HART_P1CP01:PI12046BT.MEAS 	size = (14901, 4)
# tag =  HART_P1CP04:FI12002BT.MEAS 	size = (14899, 4)
# tag =  HART_P1CP04:FY12847FB.MEAS 	size = (41969, 4)
# tag =  HART_P1CP04:HY12017FB.MEAS 	size = (14907, 4)
# tag =  HART_P1CP04:LY12001FB.MEAS 	size = (14907, 4)
# tag =  HART_P1CP04:PI12003BT.MEAS 	size = (14907, 4)
# tag =  HART_P1CP04:PX12003FB.MEAS 	size = (15237, 4)
# tag =  HART_P1CP04:PY12003AFB.MEAS 	size = (219560, 4)
# tag =  HART_P1CP04:PY12109FB.MEAS 	size = (244344, 4)
# tag =  HART_P1CP04:PY12110FB.MEAS 	size = (293210, 4)
# tag =  HART_P1CP04:PY12516FB.MEAS 	size = (96943, 4)
# tag =  HART_U1CP03:PX12003BT.MEAS 	size = (14945, 4)
# tag =  HART_U1CP03:PY24092FB.MEAS 	size = (305430, 4)
# Processing  ../data/raw/P1201//P1201_3_2018.csv 	Tags Found =  6
# tag =  12P01BCP4:FC12847.MEAS 	size = (396862, 4)
# tag =  12P01BCP4:FC12847.OUT 	size = (17163, 4)
# tag =  12P01BCP4:FC12847.SPT 	size = (14910, 4)
# tag =  12P01BCP4:PI12955.PNT 	size = (396862, 4)
# tag =  12P01BCP4:PI12956.PNT 	size = (396857, 4)
# tag =  12P01BCP4:XI12597.CIN 	size = (14921, 4)
# Processing  ../data/raw/P1201//FI2002BT2018.csv 	Tags Found =  1
# tag =  HART_P1CP04:FI12002BT.MEAS 	size = (22583, 4)
# Processing  ../data/raw/P1201//P-1201_1_2016To2018.csv 	Tags Found =  14
# tag =  12GTWY_E101:E12101FI.CIN 	size = (71413, 4)
# tag =  12GTWY_E101:FALE12404FI.CIN 	size = (71410, 4)
# tag =  12GTWY_E101:FALE12404SP.PNT 	size = (35080, 4)
# tag =  12GTWY_E101:FIE12404.PNT 	size = (1, 4)
# tag =  12GTWY_E101:FTE12404MS.CIN 	size = (71387, 4)
# tag =  12GTWY_E101:ZAE12131FI.CIN 	size = (71377, 4)
# tag =  12GTWY_E104:E12104FI.CIN 	size = (71375, 4)
# tag =  12GTWY_E104:HAE12131FI.CIN 	size = (71376, 4)
# tag =  12GTWY_E428:HAE12646FI.CIN 	size = (244, 4)
# tag =  12GTWY_FG404:AAH12554BSP.PNT 	size = (35081, 4)
# tag =  12GTWY_FG404:AAH12555BSP.PNT 	size = (35081, 4)
# tag =  12GTWY_FG404:AAH12569SP.PNT 	size = (35081, 4)
# tag =  12GTWY_FG404:AAH12570SP.PNT 	size = (35081, 4)
# tag =  12GTWY_FG404:AI12554B.PNT 	size = (1, 4)
# Processing  ../data/raw/P1201//PY12109FB2018.csv 	Tags Found =  1
# tag =  HART_P1CP04:PY12109FB.MEAS 	size = (213937, 4)
# Processing  ../data/raw/P1201//LY12001FB2018.csv 	Tags Found =  1
# tag =  HART_P1CP04:LY12001FB.MEAS 	size = (22591, 4)
# Processing  ../data/raw/P1201//HY12017FB2018.csv 	Tags Found =  1
# tag =  HART_P1CP04:HY12017FB.MEAS 	size = (22594, 4)
# Processing  ../data/raw/P1201//P1201_2_2017-q1.csv 	Tags Found =  14
# tag =  HART_P1CP01:PI12026BT.MEAS 	size = (9044, 4)
# tag =  HART_P1CP01:PI12037BT.MEAS 	size = (9044, 4)
# tag =  HART_P1CP01:PI12046BT.MEAS 	size = (9044, 4)
# tag =  HART_P1CP04:FI12002BT.MEAS 	size = (9044, 4)
# tag =  HART_P1CP04:FY12847FB.MEAS 	size = (37226, 4)
# tag =  HART_P1CP04:HY12017FB.MEAS 	size = (9044, 4)
# tag =  HART_P1CP04:LY12001FB.MEAS 	size = (9043, 4)
# tag =  HART_P1CP04:PI12003BT.MEAS 	size = (9043, 4)
# tag =  HART_P1CP04:PX12003FB.MEAS 	size = (9043, 4)
# tag =  HART_P1CP04:PY12003AFB.MEAS 	size = (299847, 4)
# tag =  HART_P1CP04:PY12109FB.MEAS 	size = (469035, 4)
# tag =  HART_P1CP04:PY12110FB.MEAS 	size = (329665, 4)
# tag =  HART_P1CP04:PY12516FB.MEAS 	size = (68330, 4)
# tag =  HART_U1CP03:PY24092FB.MEAS 	size = (1, 4)
# Processing  ../data/raw/P1201//FY12847FB2018.csv 	Tags Found =  1
# tag =  HART_P1CP04:FY12847FB.MEAS 	size = (46951, 4)
# Processing  ../data/raw/P1201//PX12003FB2018.csv 	Tags Found =  1
# tag =  HART_P1CP04:PX12003FB.MEAS 	size = (22573, 4)
# Processing  ../data/raw/P1201//FC12847MEAS2018.csv 	Tags Found =  1
# tag =  12P01BCP4:FC12847.MEAS 	size = (387481, 4)
# Processing  ../data/raw/P1201//PX12003BT_PY24092FB2018.csv 	Tags Found =  2
# tag =  HART_U1CP03:PX12003BT.MEAS 	size = (22484, 4)
# tag =  HART_U1CP03:PY24092FB.MEAS 	size = (261406, 4)
# Processing  ../data/raw/P1201//XI25972018.csv 	Tags Found =  1
# tag =  12P01BCP4:XI12597.CIN 	size = (23109, 4)
# Processing  ../data/raw/P1201//p1201_2_2017-q2.csv 	Tags Found =  15
# tag =  HART_P1CP01:PI12026BT.MEAS 	size = (9210, 4)
# tag =  HART_P1CP01:PI12037BT.MEAS 	size = (9210, 4)
# tag =  HART_P1CP01:PI12046BT.MEAS 	size = (9210, 4)
# tag =  HART_P1CP04:FI12002BT.MEAS 	size = (9301, 4)
# tag =  HART_P1CP04:FY12847FB.MEAS 	size = (26190, 4)
# tag =  HART_P1CP04:HY12017FB.MEAS 	size = (9335, 4)
# tag =  HART_P1CP04:LY12001FB.MEAS 	size = (9335, 4)
# tag =  HART_P1CP04:PI12003BT.MEAS 	size = (9336, 4)
# tag =  HART_P1CP04:PX12003FB.MEAS 	size = (9331, 4)
# tag =  HART_P1CP04:PY12003AFB.MEAS 	size = (124114, 4)
# tag =  HART_P1CP04:PY12109FB.MEAS 	size = (95550, 4)
# tag =  HART_P1CP04:PY12110FB.MEAS 	size = (155126, 4)
# tag =  HART_P1CP04:PY12516FB.MEAS 	size = (43261, 4)
# tag =  HART_U1CP03:PX12003BT.MEAS 	size = (10239, 4)
# tag =  HART_U1CP03:PY24092FB.MEAS 	size = (195746, 4)
# Processing  ../data/raw/P1201//E12404SP2018.csv 	Tags Found =  1
# tag =  12GTWY_E101:FALE12404SP.PNT 	size = (21712, 4)
# Processing  ../data/raw/P1201//PI2003BT2018.csv 	Tags Found =  1
# tag =  HART_P1CP04:PI12003BT.MEAS 	size = (22591, 4)
# Processing  ../data/raw/P1201//P1201_2_2016.csv 	Tags Found =  15
# tag =  HART_P1CP01:PI12026BT.MEAS 	size = (3862, 4)
# tag =  HART_P1CP01:PI12037BT.MEAS 	size = (3861, 4)
# tag =  HART_P1CP01:PI12046BT.MEAS 	size = (3862, 4)
# tag =  HART_P1CP04:FI12002BT.MEAS 	size = (3861, 4)
# tag =  HART_P1CP04:FY12847FB.MEAS 	size = (11411, 4)
# tag =  HART_P1CP04:HY12017FB.MEAS 	size = (3859, 4)
# tag =  HART_P1CP04:LY12001FB.MEAS 	size = (3859, 4)
# tag =  HART_P1CP04:PI12003BT.MEAS 	size = (3860, 4)
# tag =  HART_P1CP04:PX12003FB.MEAS 	size = (3858, 4)
# tag =  HART_P1CP04:PY12003AFB.MEAS 	size = (161349, 4)
# tag =  HART_P1CP04:PY12109FB.MEAS 	size = (356737, 4)
# tag =  HART_P1CP04:PY12110FB.MEAS 	size = (258508, 4)
# tag =  HART_P1CP04:PY12516FB.MEAS 	size = (48658, 4)
# tag =  HART_U1CP03:PX12003BT.MEAS 	size = (3747, 4)
# tag =  HART_U1CP03:PY24092FB.MEAS 	size = (278209, 4)
# Processing  ../data/raw/P1201//P1201_3_2017.csv 	Tags Found =  6
# tag =  12P01BCP4:FC12847.MEAS 	size = (1, 4)
# tag =  12P01BCP4:FC12847.OUT 	size = (20983, 4)
# tag =  12P01BCP4:FC12847.SPT 	size = (233401, 4)
# tag =  12P01BCP4:PI12955.PNT 	size = (1, 4)
# tag =  12P01BCP4:PI12956.PNT 	size = (1, 4)
# tag =  12P01BCP4:XI12597.CIN 	size = (18418, 4)
# Processing  ../data/raw/P1201//FC12847SPTS2018.csv 	Tags Found =  1
# tag =  12P01BCP4:FC12847.SPT 	size = (21717, 4)
# Processing  ../data/raw/P1201//PI12037BT2018.csv 	Tags Found =  1
# tag =  HART_P1CP01:PI12037BT.MEAS 	size = (22594, 4)
# Processing  ../data/raw/P1201//E124042018.csv 	Tags Found =  1
# tag =  12GTWY_E101:FIE12404.PNT 	size = (386447, 4)
# Processing  ../data/raw/P1201//PY12003AFB2018.csv 	Tags Found =  1
# tag =  HART_P1CP04:PY12003AFB.MEAS 	size = (204660, 4)
# Processing  ../data/raw/P1201//PI12046BT2018.csv 	Tags Found =  1
# tag =  HART_P1CP01:PI12046BT.MEAS 	size = (22600, 4)
# Processing  ../data/raw/P1201//PY12110FB_PY12516FB2018.csv 	Tags Found =  2
# tag =  HART_P1CP04:PY12110FB.MEAS 	size = (242043, 4)
# tag =  HART_P1CP04:PY12516FB.MEAS 	size = (99177, 4)

# %%
print('Number of distince tags available are ', len(data.keys()))
# Out:
# Number of distince tags available are  35

# %% [markdown]
# ### Find the Minimum date for the items

# %%
# This is to get the base year found among all datasets
for tag, df in data.items():
    
    min_date = df['datetime'].min()
    max_date = df['datetime'].max()
    
    df_temp = df.loc[df['date_time'] == min_date]
    print('Tag = ', tag, '\tShape = ', df_temp.shape, '\t', min_date, '\t', max_date)
# Out:
# Tag =  12P01BCP4:PI12956.PNT 	Shape =  (1, 4) 	 1970-01-01 00:00:00 	 2018-11-02 14:20:40
# Tag =  12P01BCP4:FC12847.OUT 	Shape =  (1, 4) 	 2017-01-01 00:18:40 	 2018-11-02 14:20:40
# Tag =  HART_P1CP01:PI12026BT.MEAS 	Shape =  (1, 4) 	 2016-10-13 01:03:15 	 2018-11-02 13:08:35
# Tag =  12P01BCP4:PI12955.PNT 	Shape =  (1, 4) 	 1970-01-01 00:00:00 	 2018-11-02 14:20:40
# Tag =  HART_P1CP01:PI12037BT.MEAS 	Shape =  (1, 4) 	 2016-10-13 01:03:15 	 2018-11-02 13:08:35
# Tag =  HART_P1CP01:PI12046BT.MEAS 	Shape =  (1, 4) 	 2016-10-13 01:03:15 	 2018-11-02 13:08:35
# Tag =  HART_P1CP04:FI12002BT.MEAS 	Shape =  (1, 4) 	 2016-10-13 01:03:42 	 2018-11-02 13:08:35
# Tag =  HART_P1CP04:FY12847FB.MEAS 	Shape =  (1, 4) 	 2016-10-28 01:06:07 	 2018-11-02 13:08:35
# Tag =  HART_P1CP04:HY12017FB.MEAS 	Shape =  (1, 4) 	 2016-10-13 01:03:42 	 2018-11-02 13:08:40
# Tag =  HART_P1CP04:LY12001FB.MEAS 	Shape =  (1, 4) 	 2016-10-13 01:03:42 	 2018-11-02 13:08:40
# Tag =  HART_P1CP04:PI12003BT.MEAS 	Shape =  (1, 4) 	 2016-10-13 01:03:42 	 2018-11-02 13:08:40
# Tag =  HART_P1CP04:PX12003FB.MEAS 	Shape =  (1, 4) 	 2016-10-13 01:03:42 	 2018-11-02 13:08:35
# Tag =  HART_P1CP04:PY12003AFB.MEAS 	Shape =  (1, 4) 	 2016-10-13 01:03:42 	 2018-11-02 13:08:35
# Tag =  HART_P1CP04:PY12109FB.MEAS 	Shape =  (1, 4) 	 2016-10-13 01:03:42 	 2018-11-02 13:08:35
# Tag =  HART_P1CP04:PY12110FB.MEAS 	Shape =  (1, 4) 	 2016-10-13 01:03:42 	 2018-11-02 13:08:35
# Tag =  HART_P1CP04:PY12516FB.MEAS 	Shape =  (1, 4) 	 2016-10-28 01:06:07 	 2018-11-02 13:08:35
# Tag =  HART_U1CP03:PX12003BT.MEAS 	Shape =  (1, 4) 	 2016-10-13 06:56:30 	 2018-11-02 13:08:40
# Tag =  HART_U1CP03:PY24092FB.MEAS 	Shape =  (1, 4) 	 1970-01-01 00:00:00 	 2018-11-02 13:08:35
# Tag =  12P01BCP4:FC12847.MEAS 	Shape =  (1, 4) 	 1970-01-01 00:00:00 	 2018-11-02 14:20:40
# Tag =  12P01BCP4:FC12847.SPT 	Shape =  (1, 4) 	 2017-01-01 00:00:00 	 2018-11-02 14:20:40
# Tag =  12P01BCP4:XI12597.CIN 	Shape =  (1, 4) 	 2017-01-01 00:18:40 	 2018-11-02 14:20:40
# Tag =  12GTWY_E101:E12101FI.CIN 	Shape =  (1, 4) 	 2016-01-01 00:12:41 	 2018-11-02 11:49:34
# Tag =  12GTWY_E101:FALE12404FI.CIN 	Shape =  (1, 4) 	 2016-01-01 00:12:41 	 2018-11-02 11:49:34
# Tag =  12GTWY_E101:FALE12404SP.PNT 	Shape =  (1, 4) 	 2016-11-28 09:37:51 	 2018-11-02 11:49:40
# Tag =  12GTWY_E101:FIE12404.PNT 	Shape =  (1, 4) 	 1970-01-01 00:00:00 	 2018-10-22 13:14:45
# Tag =  12GTWY_E101:FTE12404MS.CIN 	Shape =  (1, 4) 	 2016-01-01 00:12:41 	 2018-11-02 11:49:34
# Tag =  12GTWY_E101:ZAE12131FI.CIN 	Shape =  (1, 4) 	 2016-01-01 00:12:41 	 2018-11-02 11:49:34
# Tag =  12GTWY_E104:E12104FI.CIN 	Shape =  (1, 4) 	 2016-01-01 00:12:41 	 2018-11-02 11:49:34
# Tag =  12GTWY_E104:HAE12131FI.CIN 	Shape =  (1, 4) 	 2016-01-01 00:12:41 	 2018-11-02 11:49:34
# Tag =  12GTWY_E428:HAE12646FI.CIN 	Shape =  (1, 4) 	 2018-09-03 13:37:40 	 2018-11-02 11:49:34
# Tag =  12GTWY_FG404:AAH12554BSP.PNT 	Shape =  (1, 4) 	 2016-11-28 09:37:52 	 2018-11-02 11:49:40
# Tag =  12GTWY_FG404:AAH12555BSP.PNT 	Shape =  (1, 4) 	 2016-11-28 09:37:52 	 2018-11-02 11:49:40
# Tag =  12GTWY_FG404:AAH12569SP.PNT 	Shape =  (1, 4) 	 2016-11-28 09:37:52 	 2018-11-02 11:49:40
# Tag =  12GTWY_FG404:AAH12570SP.PNT 	Shape =  (1, 4) 	 2016-11-28 09:37:52 	 2018-11-02 11:49:40
# Tag =  12GTWY_FG404:AI12554B.PNT 	Shape =  (1, 4) 	 1970-01-01 00:00:00 	 1970-01-01 00:00:00

# %% [markdown]
# ### Writing to Pickle Files

# %%
data['HART_P1CP04:PY12003AFB.MEAS'].head()
# Out:
#                                                                                              0  \
# 161529  @{PIPoint=HART_P1CP04:PY12003AFB.MEAS; Value=28.0625; Timestamp=11/2/2018 1:08:35 PM}
# 161530  @{PIPoint=HART_P1CP04:PY12003AFB.MEAS; Value=28.04688; Timestamp=11/2/2018 1:08:15 PM}
# 161531  @{PIPoint=HART_P1CP04:PY12003AFB.MEAS; Value=28.04688; Timestamp=11/2/2018 1:07:05 PM}
# 161532  @{PIPoint=HART_P1CP04:PY12003AFB.MEAS; Value=28.04688; Timestamp=11/2/2018 1:05:55 PM}
# 161533  @{PIPoint=HART_P1CP04:PY12003AFB.MEAS; Value=28.0625; Timestamp=11/2/2018 1:04:45 PM}
#
#                             feature      val            datetime
# 161529  HART_P1CP04:PY12003AFB.MEAS  28.0625 2018-11-02 13:08:35
# 161530  HART_P1CP04:PY12003AFB.MEAS  28.0469 2018-11-02 13:08:15
# 161531  HART_P1CP04:PY12003AFB.MEAS  28.0469 2018-11-02 13:07:05
# 161532  HART_P1CP04:PY12003AFB.MEAS  28.0469 2018-11-02 13:05:55
# 161533  HART_P1CP04:PY12003AFB.MEAS  28.0625 2018-11-02 13:04:45

# %%
fmt = '%Y-%m-%d %H:%M:%S'
base_date = datetime.strptime('2016-01-01 00:00:01', fmt)### Combining Dataframes from both years and Normalization

for tag, df in data.items():
    
    df = df[['feature', 'datetime', 'val']]
    f_name = tag.replace(':', '_')
    pkl_file = INT_DATA_DIR + '/' + f_name + '.pkl'
    print('Writing to file ', pkl_file)
    
    with open(pkl_file, 'wb') as f:
        pkl.dump(df, f, protocol=pkl.HIGHEST_PROTOCOL)
# Out:
# Writing to file  ../data/interim/P1201//12P01BCP4_PI12956.PNT.pkl
# Writing to file  ../data/interim/P1201//12P01BCP4_FC12847.OUT.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP01_PI12026BT.MEAS.pkl
# Writing to file  ../data/interim/P1201//12P01BCP4_PI12955.PNT.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP01_PI12037BT.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP01_PI12046BT.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP04_FI12002BT.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP04_FY12847FB.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP04_HY12017FB.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP04_LY12001FB.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP04_PI12003BT.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP04_PX12003FB.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP04_PY12003AFB.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP04_PY12109FB.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP04_PY12110FB.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_P1CP04_PY12516FB.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_U1CP03_PX12003BT.MEAS.pkl
# Writing to file  ../data/interim/P1201//HART_U1CP03_PY24092FB.MEAS.pkl
# Writing to file  ../data/interim/P1201//12P01BCP4_FC12847.MEAS.pkl
# Writing to file  ../data/interim/P1201//12P01BCP4_FC12847.SPT.pkl
# Writing to file  ../data/interim/P1201//12P01BCP4_XI12597.CIN.pkl
# Writing to file  ../data/interim/P1201//12GTWY_E101_E12101FI.CIN.pkl
# Writing to file  ../data/interim/P1201//12GTWY_E101_FALE12404FI.CIN.pkl
# Writing to file  ../data/interim/P1201//12GTWY_E101_FALE12404SP.PNT.pkl
# Writing to file  ../data/interim/P1201//12GTWY_E101_FIE12404.PNT.pkl
# Writing to file  ../data/interim/P1201//12GTWY_E101_FTE12404MS.CIN.pkl
# Writing to file  ../data/interim/P1201//12GTWY_E101_ZAE12131FI.CIN.pkl
# Writing to file  ../data/interim/P1201//12GTWY_E104_E12104FI.CIN.pkl
# Writing to file  ../data/interim/P1201//12GTWY_E104_HAE12131FI.CIN.pkl
# Writing to file  ../data/interim/P1201//12GTWY_E428_HAE12646FI.CIN.pkl
# Writing to file  ../data/interim/P1201//12GTWY_FG404_AAH12554BSP.PNT.pkl
# Writing to file  ../data/interim/P1201//12GTWY_FG404_AAH12555BSP.PNT.pkl
# Writing to file  ../data/interim/P1201//12GTWY_FG404_AAH12569SP.PNT.pkl
# Writing to file  ../data/interim/P1201//12GTWY_FG404_AAH12570SP.PNT.pkl
# Writing to file  ../data/interim/P1201//12GTWY_FG404_AI12554B.PNT.pkl

# %%
data['HART_U1CP03:PY24092FB.MEAS'].head()
# Out:
#                                                                                             0  \
# 1030531  @{PIPoint=HART_U1CP03:PY24092FB.MEAS; Value=78; Timestamp=11/2/2018 1:08:35 PM}
# 1030532  @{PIPoint=HART_U1CP03:PY24092FB.MEAS; Value=85.125; Timestamp=11/2/2018 1:07:45 PM}
# 1030533  @{PIPoint=HART_U1CP03:PY24092FB.MEAS; Value=88.0625; Timestamp=11/2/2018 1:06:35 PM}
# 1030534  @{PIPoint=HART_U1CP03:PY24092FB.MEAS; Value=86.4375; Timestamp=11/2/2018 1:05:35 PM}
# 1030535  @{PIPoint=HART_U1CP03:PY24092FB.MEAS; Value=87.9375; Timestamp=11/2/2018 1:04:25 PM}
#
#                             feature      val            datetime
# 1030531  HART_U1CP03:PY24092FB.MEAS  78      2018-11-02 13:08:35
# 1030532  HART_U1CP03:PY24092FB.MEAS  85.125  2018-11-02 13:07:45
# 1030533  HART_U1CP03:PY24092FB.MEAS  88.0625 2018-11-02 13:06:35
# 1030534  HART_U1CP03:PY24092FB.MEAS  86.4375 2018-11-02 13:05:35
# 1030535  HART_U1CP03:PY24092FB.MEAS  87.9375 2018-11-02 13:04:25
