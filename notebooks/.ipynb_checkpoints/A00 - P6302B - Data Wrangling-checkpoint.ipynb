# %% [markdown]
# # P6203B - Data Wrangling based on the tags available in Data string

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import os
import ntpath
import pickle as pkl
import xlrd
import time
import string
from os.path import basename

from utils import parse

# %%
pd.set_option('display.max_colwidth', -1)

# %%
pump = 'P6302B'
RAW_DATA_DIR = '../data/raw/'+pump+'/'
PROC_DATA_DIR = '../data/processed/'+pump+'/'
INT_DATA_DIR = '../data/interim/'+pump+'/'

# %% [markdown]
# ### Reading of Data - Using tags to uniquely identify

# %%
data = {} # Contains mapping between tags and data
tag_files = {} # Contains mapping between tags and the file names
files_tag = {} # Contains the mapping between file names and tags

dir_files = os.listdir(RAW_DATA_DIR)

print('No of files in %s is %d' % (RAW_DATA_DIR, len(dir_files)))

print('| File No. | Data Files | Tags Available |')
print('| -- | -- | -- |')

idx = 1
for current_file in dir_files:

    current_base = current_file
    current_file = RAW_DATA_DIR + current_file

    if current_base.endswith('.csv'):
        print('| ' + str(idx) + ' | ', current_base, end=' | ')
        df = pd.read_csv(current_file, header=None)
        idx += 1

        df['feature'], df['val'], df['datetime'] = zip(*df[0].map(parse))

        df = df[df['feature'] != None]
        df = df[df['datetime'].notnull()]

        tags = np.unique(df['feature'])


        print(', '.join(map(str,tags)) + '|')

        for tag in tags:
            df_tag = df.loc[df['feature'] == tag]

            # print('Intersection = ', longestSubstringFinder(tag, current_base))

            if tag not in data.keys():
                data[tag] = pd.DataFrame(columns=df_tag.columns.values)
            data[tag] = data[tag].append(df_tag)
# Out:
# No of files in ../data/raw/P6302B/ is 81
# | File No. | Data Files | Tags Available |
# | -- | -- | -- |
# 1 |  P6302B 2016 Item 31-40.csv | PT61A98.PV, PT61B00.PV, PT63103.PV, PT63105.PV, TA61B47.PV, TA63109.PV|
# 2 |  P6302B 2016 Item 5-11 Jul Dec.csv | 05GTWY_BN06:XT61B16.PNT, 05GTWY_BN06:XT61B17.PNT, 05GTWY_BN06:XT61B18.PNT, 05GTWY_BN06:XT61B19.PNT, 05GTWY_BN06:XT61B20.PNT, 05GTWY_BN06:ZT61B14.PNT, 05GTWY_BN06:ZT61B15.PNT|
# 3 |  P6302B 2014 Item 51-63.csv | 07DATASCRCP1:AI07003.PNT, F61221VP, PC63112.AV, PC63112E.AV, PT63112.PV, T6150.PV, T6151.PV, T6152.PV, T6153.PV, TC63109.AV, TC63109E.AV, TT61B06.PV, TT63109.PV|
# 4 |  P6302B 2015 Item 7-11 Nov.csv | 05GTWY_BN06:XT61B18.PNT, 05GTWY_BN06:XT61B19.PNT, 05GTWY_BN06:XT61B20.PNT, 05GTWY_BN06:ZT61B14.PNT, 05GTWY_BN06:ZT61B15.PNT|
# 5 |  TT63109 PV Jan to Jun.csv | TT63109.PV|
# 6 |  P6302B 2015 Item 21-30.csv | PA61B223.PV, PA63110.PV, PA63112.PV, PA63113.PV, PAH61A98.PV, PAL61A98.PV, PC61A98.AV, PC61A98E.AV, PDA61B21.PV|
# 7 |  P6302B 2018 Item 11-20.csv | 05GTWY_BN06:ZT61B15.PNT, FA61A99.PV, FIE61A99.PV, FT61A99.PV, LA63114.PV, LAL63114.PV, LT63114.PV, P6302BDI.PV, P6302BSD.PV, PA61B00.PV|
# 8 |  F61221 Jul to Dec.csv | F61221|
# 9 |  TC63109 AV Jan to Jun.csv | TC63109.AV|
# 10 |  P6302B 2015 Item 1-6 Dec.csv | 05GTWY_BN06:XT61B10.PNT, 05GTWY_BN06:XT61B11.PNT, 05GTWY_BN06:XT61B12.PNT, 05GTWY_BN06:XT61B13.PNT, 05GTWY_BN06:XT61B16.PNT, 05GTWY_BN06:XT61B17.PNT|
# 11 |  PT61B00 PV 2017.csv | PT61B00.PV|
# 12 |  P6302B 2015 Item 1-6 Sept.csv | 05GTWY_BN06:XT61B10.PNT, 05GTWY_BN06:XT61B11.PNT, 05GTWY_BN06:XT61B12.PNT, 05GTWY_BN06:XT61B13.PNT, 05GTWY_BN06:XT61B16.PNT, 05GTWY_BN06:XT61B17.PNT|
# 13 |  P6302B 2015 Item 7-11 Jul.csv | 05GTWY_BN06:XT61B18.PNT, 05GTWY_BN06:XT61B19.PNT, 05GTWY_BN06:XT61B20.PNT, 05GTWY_BN06:ZT61B14.PNT, 05GTWY_BN06:ZT61B15.PNT|
# 14 |  P6302B 2016 Item 1-4 Jul Dec.csv | 05GTWY_BN06:XT61B10.PNT, 05GTWY_BN06:XT61B11.PNT, 05GTWY_BN06:XT61B12.PNT, 05GTWY_BN06:XT61B13.PNT|
# 15 |  P6302B 2018 Item 31-40.csv | PIE61B00.PV, PIE61B22.PV, PIE61B23.PV, PIE63113.PV, PT61A98.PV, PT61B00.PV, PT63103.PV, PT63105.PV, TA61B47.PV, TA63109.PV|
# 16 |  TT63109 PV Jul to Dec.csv | TT63109.PV|
# 17 |  P6302B 2014 Item 21-30.csv | PA61B223.PV, PA63110.PV, PA63112.PV, PA63113.PV, PAH61A98.PV, PAL61A98.PV, PC61A98.AV, PC61A98E.AV, PDA61B21.PV|
# 18 |  P6302B 2017 Item 11 jan jun.csv | 05GTWY_BN06:ZT61B15.PNT|
# 19 |  PT61B00 PV 2016.csv | PT61B00.PV|
# 20 |  PT61B00 PV 2014.csv | PT61B00.PV|
# 21 |  F61221 Jan to Jun.csv | F61221|
# 22 |  P6302B 2017 Item 31-40.csv | PT61A98.PV, PT61B00.PV, PT63103.PV, PT63105.PV, TA61B47.PV, TA63109.PV|
# 23 |  P6302B 2015 Item 51-63.csv | 07DATASCRCP1:AI07003.PNT, F61221VP, PC63112.AV, PC63112E.AV, PT63112.PV, T6150.PV, T6151.PV, T6152.PV, T6153.PV, TC63109.AV, TC63109E.AV, TT61B06.PV, TT63109.PV|
# 24 |  TC63109 AV Jul to Dec.csv | TC63109.AV|
# 25 |  PT61B00 PV 2015.csv | PT61B00.PV|
# 26 |  PC63112 AV Jul to Dec.csv | PC63112.AV|
# 27 |  P6302B 2017 Item 51-63.csv | 07DATASCRCP1:AI07003.PNT, F61221VP, PC63112.AV, PC63112E.AV, PT63112.PV, T6150.PV, T6151.PV, T6152.PV, T6153.PV, TC63109.AV, TC63109E.AV, TT61B06.PV, TT63109.PV|
# 28 |  P6302B 2015 Item 31-40.csv | PT61A98.PV, PT61B00.PV, PT63103.PV, PT63105.PV, TA61B47.PV, TA63109.PV|
# 29 |  P6302B 2015 Item 2-6 Jan Mar.csv | 05GTWY_BN06:XT61B11.PNT, 05GTWY_BN06:XT61B12.PNT, 05GTWY_BN06:XT61B13.PNT, 05GTWY_BN06:XT61B16.PNT, 05GTWY_BN06:XT61B17.PNT|
# 30 |  P6302B 2015 Item 7-11 Sep.csv | 05GTWY_BN06:XT61B18.PNT, 05GTWY_BN06:XT61B19.PNT, 05GTWY_BN06:XT61B20.PNT, 05GTWY_BN06:ZT61B14.PNT, 05GTWY_BN06:ZT61B15.PNT|
# 31 |  P6302B 2015 Item 7-11 Oct.csv | 05GTWY_BN06:XT61B18.PNT, 05GTWY_BN06:XT61B19.PNT, 05GTWY_BN06:XT61B20.PNT, 05GTWY_BN06:ZT61B14.PNT, 05GTWY_BN06:ZT61B15.PNT|
# 32 |  P6302B 2018 Item 51-62.csv | F61221VP, PC63112.AV, PC63112E.AV, PT63112.PV, T6150.PV, T6151.PV, T6152.PV, T6153.PV, TC63109.AV, TC63109E.AV, TT61B06.PV, TT63109.PV|
# 33 |  P6302B 2016 Item 21-30.csv | PA61B223.PV, PA63110.PV, PA63112.PV, PA63113.PV, PAH61A98.PV, PAL61A98.PV, PC61A98.AV, PC61A98E.AV, PDA61B21.PV|
# 34 |  PT63112 PV Jul to Dec.csv | PT63112.PV|
# 35 |  P6302B 2017 Item 6-10 Jul Dec.csv | 05GTWY_BN06:XT61B17.PNT, 05GTWY_BN06:XT61B18.PNT, 05GTWY_BN06:XT61B19.PNT, 05GTWY_BN06:XT61B20.PNT, 05GTWY_BN06:ZT61B14.PNT|
# 36 |  P6302B 2017 Item 21-30.csv | PA61B223.PV, PA63110.PV, PA63112.PV, PA63113.PV, PAH61A98.PV, PAL61A98.PV, PC61A98.AV, PC61A98E.AV, PDA61B21.PV|
# 37 |  P6302B 2014 Item 7-11.csv | 05GTWY_BN06:XT61B18.PNT, 05GTWY_BN06:XT61B19.PNT, 05GTWY_BN06:XT61B20.PNT, 05GTWY_BN06:ZT61B14.PNT, 05GTWY_BN06:ZT61B15.PNT|
# 38 |  PC63112 AV Jan to Jun.csv | PC63112.AV|
# 39 |  P6302B 2016 Item 51-63.csv | 07DATASCRCP1:AI07003.PNT, F61221VP, PC63112.AV, PC63112E.AV, PT63112.PV, T6150.PV, T6151.PV, T6152.PV, T6153.PV, TC63109.AV, TC63109E.AV, TT61B06.PV, TT63109.PV|
# 40 |  P6302B 2015 Item 7-11 Aug.csv | 05GTWY_BN06:XT61B18.PNT, 05GTWY_BN06:XT61B19.PNT, 05GTWY_BN06:XT61B20.PNT, 05GTWY_BN06:ZT61B14.PNT, 05GTWY_BN06:ZT61B15.PNT|
# 41 |  P6302B 2017 Item 1-4 Jul Dec.csv | 05GTWY_BN06:XT61B10.PNT, 05GTWY_BN06:XT61B11.PNT, 05GTWY_BN06:XT61B12.PNT, 05GTWY_BN06:XT61B13.PNT|
# 42 |  P6302B 2014 Item 31-40.csv |

# %%
data['PA61B223.PV'].head()
# Out:
#                                                                         0  \
# 0  @{PIPoint=PA61B223.PV; Value=NORMAL; Timestamp=12/30/2015 11:48:15 PM}
# 1  @{PIPoint=PA61B223.PV; Value=NORMAL; Timestamp=12/30/2015 11:18:15 PM}
# 2  @{PIPoint=PA61B223.PV; Value=NORMAL; Timestamp=12/30/2015 10:48:15 PM}
# 3  @{PIPoint=PA61B223.PV; Value=NORMAL; Timestamp=12/30/2015 10:19:14 PM}
# 4  @{PIPoint=PA61B223.PV; Value=NORMAL; Timestamp=12/30/2015 9:49:14 PM}
#
#        feature     val            datetime
# 0  PA61B223.PV  NORMAL 2015-12-30 23:48:15
# 1  PA61B223.PV  NORMAL 2015-12-30 23:18:15
# 2  PA61B223.PV  NORMAL 2015-12-30 22:48:15
# 3  PA61B223.PV  NORMAL 2015-12-30 22:19:14
# 4  PA61B223.PV  NORMAL 2015-12-30 21:49:14

# %%
print('Number of distinct tags available are ', len(data.keys()))
# Out:
# Number of distinct tags available are  63

# %%
# Printing all the keys
', '.join(map(str, data.keys()))
# Out:
# 'PT61A98.PV, PT61B00.PV, PT63103.PV, PT63105.PV, TA61B47.PV, TA63109.PV, 05GTWY_BN06:XT61B16.PNT, 05GTWY_BN06:XT61B17.PNT, 05GTWY_BN06:XT61B18.PNT, 05GTWY_BN06:XT61B19.PNT, 05GTWY_BN06:XT61B20.PNT, 05GTWY_BN06:ZT61B14.PNT, 05GTWY_BN06:ZT61B15.PNT, 07DATASCRCP1:AI07003.PNT, F61221VP, PC63112.AV, PC63112E.AV, PT63112.PV, T6150.PV, T6151.PV, T6152.PV, T6153.PV, TC63109.AV, TC63109E.AV, TT61B06.PV, TT63109.PV, PA61B223.PV, PA63110.PV, PA63112.PV, PA63113.PV, PAH61A98.PV, PAL61A98.PV, PC61A98.AV, PC61A98E.AV, PDA61B21.PV, FA61A99.PV, FIE61A99.PV, FT61A99.PV, LA63114.PV, LAL63114.PV, LT63114.PV, P6302BDI.PV, P6302BSD.PV, PA61B00.PV, F61221, 05GTWY_BN06:XT61B10.PNT, 05GTWY_BN06:XT61B11.PNT, 05GTWY_BN06:XT61B12.PNT, 05GTWY_BN06:XT61B13.PNT, PIE61B00.PV, PIE61B22.PV, PIE61B23.PV, PIE63113.PV, PIE61608.PV, TAE61B47.PV, TT61B01.PV, TT61B02.PV, TT61B03.PV, TT61B04.PV, TT61B05.PV, XA61B34.PV, XA61B58.PV, XAE61B34.PV'

# %%
data.keys()
# Out:
# dict_keys(['PT61A98.PV', 'PT61B00.PV', 'PT63103.PV', 'PT63105.PV', 'TA61B47.PV', 'TA63109.PV', '05GTWY_BN06:XT61B16.PNT', '05GTWY_BN06:XT61B17.PNT', '05GTWY_BN06:XT61B18.PNT', '05GTWY_BN06:XT61B19.PNT', '05GTWY_BN06:XT61B20.PNT', '05GTWY_BN06:ZT61B14.PNT', '05GTWY_BN06:ZT61B15.PNT', '07DATASCRCP1:AI07003.PNT', 'F61221VP', 'PC63112.AV', 'PC63112E.AV', 'PT63112.PV', 'T6150.PV', 'T6151.PV', 'T6152.PV', 'T6153.PV', 'TC63109.AV', 'TC63109E.AV', 'TT61B06.PV', 'TT63109.PV', 'PA61B223.PV', 'PA63110.PV', 'PA63112.PV', 'PA63113.PV', 'PAH61A98.PV', 'PAL61A98.PV', 'PC61A98.AV', 'PC61A98E.AV', 'PDA61B21.PV', 'FA61A99.PV', 'FIE61A99.PV', 'FT61A99.PV', 'LA63114.PV', 'LAL63114.PV', 'LT63114.PV', 'P6302BDI.PV', 'P6302BSD.PV', 'PA61B00.PV', 'F61221', '05GTWY_BN06:XT61B10.PNT', '05GTWY_BN06:XT61B11.PNT', '05GTWY_BN06:XT61B12.PNT', '05GTWY_BN06:XT61B13.PNT', 'PIE61B00.PV', 'PIE61B22.PV', 'PIE61B23.PV', 'PIE63113.PV', 'PIE61608.PV', 'TAE61B47.PV', 'TT61B01.PV', 'TT61B02.PV', 'TT61B03.PV', 'TT61B04.PV', 'TT61B05.PV', 'XA61B34.PV', 'XA61B58.PV', 'XAE61B34.PV'])

# %% [markdown]
# ### Remove data that resulted in default values

# %%
fmt = '%Y-%m-%d %H:%M:%S'
remove_before = datetime.strptime('2010-01-01 00:00:01', fmt)
for tag, df in data.items():
    df = df.loc[df['datetime'] > remove_before][['val', 'datetime', 'feature']]
    data[tag] = df

# %%
data['PA61B223.PV'].head()
# Out:
#       val            datetime      feature
# 0  NORMAL 2015-12-30 23:48:15  PA61B223.PV
# 1  NORMAL 2015-12-30 23:18:15  PA61B223.PV
# 2  NORMAL 2015-12-30 22:48:15  PA61B223.PV
# 3  NORMAL 2015-12-30 22:19:14  PA61B223.PV
# 4  NORMAL 2015-12-30 21:49:14  PA61B223.PV

# %% [markdown]
# ### Find the First and Last Date for features

# %%
# This is to get the base year found among all datasets
print('| Tag | First Data | Last Date |')
print('| -- | -- | -- |')
for tag, df in data.items():
    
    min_date = df['datetime'].min()
    max_date = df['datetime'].max()
    
    df_temp = df.loc[df['datetime'] == min_date]
    print('| ', tag, ' | ', min_date, ' | ', max_date , ' |')
# Out:
# | Tag | First Data | Last Date |
# | -- | -- | -- |
# |  PT61A98.PV  |  2014-01-01 00:00:26  |  2018-11-30 09:15:58  |
# |  PT61B00.PV  |  2014-01-01 00:00:26  |  2018-11-26 11:44:22  |
# |  PT63103.PV  |  2014-01-01 00:00:26  |  2018-11-26 11:44:22  |
# |  PT63105.PV  |  2014-01-21 14:37:21  |  2018-11-30 09:15:58  |
# |  TA61B47.PV  |  2014-01-21 14:37:31  |  2018-11-26 11:44:31  |
# |  TA63109.PV  |  2014-01-21 14:37:31  |  2018-11-26 11:44:31  |
# |  05GTWY_BN06:XT61B16.PNT  |  2014-01-01 00:00:00  |  2018-11-30 08:07:55  |
# |  05GTWY_BN06:XT61B17.PNT  |  2014-01-01 00:00:00  |  2018-11-30 08:07:55  |
# |  05GTWY_BN06:XT61B18.PNT  |  2014-01-01 00:00:00  |  2018-11-30 08:07:55  |
# |  05GTWY_BN06:XT61B19.PNT  |  2014-01-01 00:00:00  |  2018-11-30 08:07:55  |
# |  05GTWY_BN06:XT61B20.PNT  |  2014-01-01 00:00:00  |  2018-11-30 08:07:05  |
# |  05GTWY_BN06:ZT61B14.PNT  |  2015-01-01 00:00:21  |  2018-11-30 08:07:05  |
# |  05GTWY_BN06:ZT61B15.PNT  |  2015-01-01 00:00:21  |  2018-11-30 09:08:45  |
# |  07DATASCRCP1:AI07003.PNT  |  NaT  |  NaT  |
# |  F61221VP  |  2014-01-01 00:00:09  |  2018-11-30 09:40:10  |
# |  PC63112.AV  |  2014-01-01 00:00:15  |  2018-11-30 09:40:15  |
# |  PC63112E.AV  |  2014-01-01 00:26:15  |  2018-11-30 09:40:15  |
# |  PT63112.PV  |  2014-01-01 00:00:26  |  2018-11-30 09:39:58  |
# |  T6150.PV  |  2014-01-01 00:18:33  |  2018-11-30 09:39:59  |
# |  T6151.PV  |  2014-01-01 00:00:33  |  2018-11-30 09:39:59  |
# |  T6152.PV  |  2014-01-01 00:59:33  |  2018-11-30 06:43:58  |
# |  T6153.PV  |  2014-01-01 00:00:33  |  2018-11-30 09:39:59  |
# |  TC63109.AV  |  2014-01-01 00:00:34  |  2018-11-30 09:39:59  |
# |  TC63109E.AV  |  2014-01-21 14:37:31  |  2018-11-26 11:44:31  |
# |  TT61B06.PV  |  2014-01-01 00:01:34  |  2018-11-30 09:39:59  |
# |  TT63109.PV  |  2014-01-01 00:00:34  |  2018-11-30 09:39:59  |
# |  PA61B223.PV  |  2014-01-01 00:26:15  |  2018-11-30 09:13:15  |
# |  PA63110.PV  |  2014-01-01 00:26:15  |  2018-11-30 09:13:15  |
# |  PA63112.PV  |  2014-01-01 00:26:15  |  2018-11-30 09:13:15  |
# |  PA63113.PV  |  2014-01-01 00:26:15  |  2018-11-30 09:13:15  |
# |  PAH61A98.PV  |  2014-01-01 00:26:15  |  2018-11-30 09:13:15  |
# |  PAL61A98.PV  |  2014-01-01 00:26:15  |  2018-11-30 09:13:15  |
# |  PC61A98.AV  |  2014-01-01 00:00:15  |  2018-11-30 09:13:15  |
# |  PC61A98E.AV  |  2014-01-01 00:26:15  |  2018-11-30 09:13:15  |
# |  PDA61B21.PV  |  2014-01-01 00:26:15  |  2018-11-30 09:13:15  |
# |  FA61A99.PV  |  2014-01-01 00:06:10  |  2018-11-30 09:08:10  |
# |  FIE61A99.PV  |  2018-03-26 03:21:52  |  2018-11-30 09:08:10  |
# |  FT61A99.PV  |  2014-01-01 00:00:09  |  2018-11-30 09:08:10  |
# |  LA63114.PV  |  2014-01-01 00:26:15  |  2018-11-30 09:08:15  |
# |  LAL63114.PV  |  2014-01-01 00:26:15  |  2018-11-30 09:08:15  |
# |  LT63114.PV  |  2014-01-01 00:00:15  |  2018-11-30 09:08:15  |
# |  P6302BDI.PV  |  2014-01-01 00:25:15  |  2018-11-30 09:08:15  |
# |  P6302BSD.PV  |  2014-01-01 00:26:15  |  2018-11-30 09:08:15  |
# |  PA61B00.PV  |  2014-01-01 00:26:15  |  2018-11-30 09:08:15  |
# |  F61221  |  2014-01-01 00:00:09  |  2018-11-30 09:35:10  |
# |  05GTWY_BN06:XT61B10.PNT  |  2014-01-01 00:00:00  |  2018-11-30 08:07:55  |
# |  05GTWY_BN06:XT61B11.PNT  |  2014-01-01 00:00:00  |  2018-11-30 08:07:55  |
# |  05GTWY_BN06:XT61B12.PNT  |  2014-01-01 00:00:00  |  2018-11-30 08:07:55  |
# |  05GTWY_BN06:XT61B13.PNT  |  2014-01-01 00:00:00  |  2018-11-30 08:07:55  |
# |  PIE61B00.PV  |  2018-03-26 03:21:52  |  2018-11-30 09:16:10  |
# |  PIE61B22.PV  |  2018-03-26 03:21:52  |  2018-11-30 09:16:10  |
# |  PIE61B23.PV  |  2018-03-26 03:21:53  |  2018-11-30 09:16:10  |
# |  PIE63113.PV  |  2018-03-26 03:21:53  |  2018-11-30 09:16:10  |
# |  PIE61608.PV  |  2018-03-26 03:21:53  |  2018-11-30 09:13:10  |
# |  TAE61B47.PV  |  2014-01-21 14:37:31  |  2018-11-26 11:44:31  |
# |  TT61B01.PV  |  2014-01-01 00:01:34  |  2018-11-30 09:34:59  |
# |  TT61B02.PV  |  2014-01-01 00:00:34  |  2018-11-30 09:29:59  |
# |  TT61B03.PV  |  2014-01-01 00:00:34  |  2018-11-30 09:34:59  |
# |  TT61B04.PV  |  2014-01-01 00:00:34  |  2018-11-30 09:30:59  |
# |  TT61B05.PV  |  2014-01-01 00:00:34  |  2018-11-30 09:34:59  |
# |  XA61B34.PV  |  2014-01-21 14:37:31  |  2018-11-26 11:44:31  |
# |  XA61B58.PV  |  2014-01-21 14:37:31  |  2018-11-26 11:44:31  |
# |  XAE61B34.PV  |  2014-01-21 14:37:31  |  2018-11-26 11:44:31  |

# %%
data['PA61B223.PV'].head()
# Out:
#       val            datetime      feature
# 0  NORMAL 2015-12-30 23:48:15  PA61B223.PV
# 1  NORMAL 2015-12-30 23:18:15  PA61B223.PV
# 2  NORMAL 2015-12-30 22:48:15  PA61B223.PV
# 3  NORMAL 2015-12-30 22:19:14  PA61B223.PV
# 4  NORMAL 2015-12-30 21:49:14  PA61B223.PV

# %%
meta_feature = [
    '05GTWY_BN06:XT61B10.PNT',
    '05GTWY_BN06:XT61B11.PNT',
    '05GTWY_BN06:XT61B12.PNT',
    '05GTWY_BN06:XT61B13.PNT',
    '05GTWY_BN06:XT61B16.PNT',
    '05GTWY_BN06:XT61B17.PNT',
    '05GTWY_BN06:XT61B18.PNT',
    '05GTWY_BN06:XT61B19.PNT',
    '05GTWY_BN06:XT61B20.PNT',
    '05GTWY_BN06:ZT61B14.PNT',
    '05GTWY_BN06:ZT61B15.PNT',
    'FA61A99.PV',
    'FIE61A99.PV',
    'FT61A99.PV',
    'LA63114.PV',
    'LAL63114.PV',
    'LT63114.PV',
    'P6302BDI.PV',
    'P6302BSD.PV',
    'PA61B00.PV',
    'PA61B223.PV',
    'PA63110.PV',
    'PA63112.PV',
    'PA63113.PV',
    'PAH61A98.PV',
    'PAL61A98.PV',
    'PC61A98.AV',
    'PC61A98E.AV',
    'PDA61B21.PV',
    'PIE61608.PV',
    'PIE61B00.PV',
    'PIE61B22.PV',
    'PIE61B23.PV',
    'PIE63113.PV',
    'PT61A98.PV',
    'PT61B00.PV',
    'PT63103.PV',
    'PT63105.PV',
    'TA61B47.PV',
    'TA63109.PV',
    'TAE61B47.PV',
    'TT61B01.PV',
    'TT61B02.PV',
    'TT61B03.PV',
    'TT61B04.PV',
    'XA61B34.PV',
    'XA61B58.PV',
    'XAE61B34.PV',
    'F61221',
    'TT61B05.PV',
    'TT61B06.PV',
    'TC63109E.AV',
    'TT63109.PV',
    'PC63112.AV',
    'PC63112E.AV',
    'PT63112.PV',
    'TC63109.AV',
    'F61221VP',
    'T6150.PV',
    'T6151.PV',
    'T6152.PV',
    'T6153.PV',
    '07DATASCRCP1:AI07003.PNT'
]

# meta_feature = ['PA61B223.PV', 'PA63110.PV', 'PA63112.PV', 'PA63113.PV', 'PAH61A98.PV', 'PAL61A98.PV', 'PC61A98.AV', 'PC61A98E.AV', 'PDA61B21.PV']

extra_features = list(set(data.keys()) - set(meta_feature))

print('| Tag | Size | First Date | Last Date |')
print('| -- | -- | -- | -- |')
for tag in meta_feature:
    
    df = data[tag]
    
    min_date = df['datetime'].min()
    max_date = df['datetime'].max()
    
    print('|', tag, '|', len(df), '|', min_date, '|', max_date, '|')
    
print('\n| Tag | Size | First Date | Last Date |')
print('| -- | -- | -- | -- |')
for tag in extra_features:
    
    df = data[tag]
    
    min_date = df['datetime'].min()
    max_date = df['datetime'].max()
    
    print('|', tag, '|', len(df), '|', min_date, '|', max_date, '|')
# Out:
# | Tag | Size | First Date | Last Date |
# | -- | -- | -- | -- |
# | 05GTWY_BN06:XT61B10.PNT | 4133086 | 2014-01-01 00:00:00 | 2018-11-30 08:07:55 |
# | 05GTWY_BN06:XT61B11.PNT | 4039732 | 2014-01-01 00:00:00 | 2018-11-30 08:07:55 |
# | 05GTWY_BN06:XT61B12.PNT | 4006519 | 2014-01-01 00:00:00 | 2018-11-30 08:07:55 |
# | 05GTWY_BN06:XT61B13.PNT | 4026078 | 2014-01-01 00:00:00 | 2018-11-30 08:07:55 |
# | 05GTWY_BN06:XT61B16.PNT | 3315919 | 2014-01-01 00:00:00 | 2018-11-30 08:07:55 |
# | 05GTWY_BN06:XT61B17.PNT | 4052945 | 2014-01-01 00:00:00 | 2018-11-30 08:07:55 |
# | 05GTWY_BN06:XT61B18.PNT | 4349675 | 2014-01-01 00:00:00 | 2018-11-30 08:07:55 |
# | 05GTWY_BN06:XT61B19.PNT | 4387554 | 2014-01-01 00:00:00 | 2018-11-30 08:07:55 |
# | 05GTWY_BN06:XT61B20.PNT | 4334858 | 2014-01-01 00:00:00 | 2018-11-30 08:07:05 |
# | 05GTWY_BN06:ZT61B14.PNT | 4125992 | 2015-01-01 00:00:21 | 2018-11-30 08:07:05 |
# | 05GTWY_BN06:ZT61B15.PNT | 4102902 | 2015-01-01 00:00:21 | 2018-11-30 09:08:45 |
# | FA61A99.PV | 549030 | 2014-01-01 00:06:10 | 2018-11-30 09:08:10 |
# | FIE61A99.PV | 154348 | 2018-03-26 03:21:52 | 2018-11-30 09:08:10 |
# | FT61A99.PV | 1231734 | 2014-01-01 00:00:09 | 2018-11-30 09:08:10 |
# | LA63114.PV | 549182 | 2014-01-01 00:26:15 | 2018-11-30 09:08:15 |
# | LAL63114.PV | 549159 | 2014-01-01 00:26:15 | 2018-11-30 09:08:15 |
# | LT63114.PV | 1744986 | 2014-01-01 00:00:15 | 2018-11-30 09:08:15 |
# | P6302BDI.PV | 550345 | 2014-01-01 00:25:15 | 2018-11-30 09:08:15 |
# | P6302BSD.PV | 549092 | 2014-01-01 00:26:15 | 2018-11-30 09:08:15 |
# | PA61B00.PV | 549159 | 2014-01-01 00:26:15 | 2018-11-30 09:08:15 |
# | PA61B223.PV | 549160 | 2014-01-01 00:26:15 | 2018-11-30 09:13:15 |
# | PA63110.PV | 549059 | 2014-01-01 00:26:15 | 2018-11-30 09:13:15 |
# | PA63112.PV | 549174 | 2014-01-01 00:26:15 | 2018-11-30 09:13:15 |
# | PA63113.PV | 549156 | 2014-01-01 00:26:15 | 2018-11-30 09:13:15 |
# | PAH61A98.PV | 549158 | 2014-01-01 00:26:15 | 2018-11-30 09:13:15 |
# | PAL61A98.PV | 549163 | 2014-01-01 00:26:15 | 2018-11-30 09:13:15 |
# | PC61A98.AV | 1853370 | 2014-01-01 00:00:15 | 2018-11-30 09:13:15 |
# | PC61A98E.AV | 551609 | 2014-01-01 00:26:15 | 2018-11-30 09:13:15 |
# | PDA61B21.PV | 549049 | 2014-01-01 00:26:15 | 2018-11-30 09:13:15 |
# | PIE61608.PV | 87326 | 2018-03-26 03:21:53 | 2018-11-30 09:13:10 |
# | PIE61B00.PV | 160387 | 2018-03-26 03:21:52 | 2018-11-30 09:16:10 |
# | PIE61B22.PV | 60449 | 2018-03-26 03:21:52 | 2018-11-30 09:16:10 |
# | PIE61B23.PV | 64989 | 2018-03-26 03:21:53 | 2018-11-30 09:16:10 |
# | PIE63113.PV | 214588 | 2018-03-26 03:21:53 | 2018-11-30 09:16:10 |
# | PT61A98.PV | 1949625 | 2014-01-01 00:00:26 | 2018-11-30 09:15:58 |
# | PT61B00.PV | 2097026 | 2014-01-01 00:00:26 | 2018-11-26 11:44:22 |
# | PT63103.PV | 1316380 | 2014-01-01 00:00:26 | 2018-11-26 11:44:22 |
# | PT63105.PV | 689899 | 2014-01-21 14:37:21 | 2018-11-30 09:15:58 |
# | TA61B47.PV | 267 | 2014-01-21 14:37:31 | 2018-11-26 11:44:31 |
# | TA63109.PV | 221 | 2014-01-21 14:37:31 | 2018-11-26 11:44:31 |
# | TAE61B47.PV | 229 | 2014-01-21 14:37:31 | 2018-11-26 11:44:31 |
# | TT61B01.PV | 1538350 | 2014-01-01 00:01:34 | 2018-11-30 09:34:59 |
# | TT61B02.PV | 1587413 | 2014-01-01 00:00:34 | 2018-11-30 09:29:59 |
# | TT61B03.PV | 1562492 | 2014-01-01 00:00:34 | 2018-11-30 09:34:59 |
# | TT61B04.PV | 1499154 | 2014-01-01 00:00:34 | 2018-11-30 09:30:59 |
# | XA61B34.PV | 313 | 2014-01-21 14:37:31 | 2018-11-26 11:44:31 |
# | XA61B58.PV | 282 | 2014-01-21 14:37:31 | 2018-11-26 11:44:31 |
# | XAE61B34.PV | 226 | 2014-01-21 14:37:31 | 2018-11-26 11:44:31 |
# | F61221 | 1400207 | 2014-01-01 00:00:09 | 2018-11-30 09:35:10 |
# | TT61B05.PV | 1638093 | 2014-01-01 00:00:34 | 2018-11-30 09:34:59 |
# | TT61B06.PV | 1498412 | 2014-01-01 00:01:34 | 2018-11-30 09:39:59 |
# | TC63109E.AV | 431 | 2014-01-21 14:37:31 | 2018-11-26 11:44:31 |
# | TT63109.PV | 1970864 | 2014-01-01 00:00:34 | 2018-11-30 09:39:59 |
# | PC63112.AV | 1907399 | 2014-01-01 00:00:15 | 2018-11-30 09:40:15 |
# | PC63112E.AV | 551314 | 2014-01-01 00:26:15 | 2018-11-30 09:40:15 |
# | PT63112.PV | 1979423 | 2014-01-01 00:00:26 | 2018-11-30 09:39:58 |
# | TC63109.AV | 1871614 | 2014-01-01 00:00:34 | 2018-11-30 09:39:59 |
# | F61221VP | 1485573 | 2014-01-01 00:00:09 | 2018-11-30 09:40:10 |
# | T6150.PV | 533274 | 2014-01-01 00:18:33 | 2018-11-30 09:39:59 |
# | T6151.PV | 791259 | 2014-01-01 00:00:33 | 2018-11-30 09:39:59 |
# | T6152.PV | 844419 | 2014-01-01 00:59:33 | 2018-11-30 06:43:58 |
# | T6153.PV | 952184 | 2014-01-01 00:00:33 | 2018-11-30 09:39:59 |
# | 07DATASCRCP1:AI07003.PNT | 0 | NaT | NaT |
#
# | Tag | Size | First Date | Last Date |
# | -- | -- | -- | -- |

# %% [markdown]
# ### Writing to Pickle Files

# %%
from utils import write_feature_dict

dir_path = INT_DATA_DIR + 'initial/'
write_feature_dict(dir_path, data)
# Out:
# Writing to file  ../data/interim/P6302B/initial/PT61A98.PV.pkl (1949625, 3) [ PT61A98.PV ]
# Writing to file  ../data/interim/P6302B/initial/PT61B00.PV.pkl (2097026, 3) [ PT61B00.PV ]
# Writing to file  ../data/interim/P6302B/initial/PT63103.PV.pkl (1316380, 3) [ PT63103.PV ]
# Writing to file  ../data/interim/P6302B/initial/PT63105.PV.pkl (689899, 3) [ PT63105.PV ]
# Writing to file  ../data/interim/P6302B/initial/TA61B47.PV.pkl (267, 3) [ TA61B47.PV ]
# Writing to file  ../data/interim/P6302B/initial/TA63109.PV.pkl (221, 3) [ TA63109.PV ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B16.PNT.pkl (3315919, 3) [ 05GTWY_BN06:XT61B16.PNT ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B17.PNT.pkl (4052945, 3) [ 05GTWY_BN06:XT61B17.PNT ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B18.PNT.pkl (4349675, 3) [ 05GTWY_BN06:XT61B18.PNT ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B19.PNT.pkl (4387554, 3) [ 05GTWY_BN06:XT61B19.PNT ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B20.PNT.pkl (4334858, 3) [ 05GTWY_BN06:XT61B20.PNT ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-ZT61B14.PNT.pkl (4125992, 3) [ 05GTWY_BN06:ZT61B14.PNT ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-ZT61B15.PNT.pkl (4102902, 3) [ 05GTWY_BN06:ZT61B15.PNT ]
# Writing to file  ../data/interim/P6302B/initial/07DATASCRCP1-AI07003.PNT.pkl (0, 3) [ 07DATASCRCP1:AI07003.PNT ]
# Writing to file  ../data/interim/P6302B/initial/F61221VP.pkl (1485573, 3) [ F61221VP ]
# Writing to file  ../data/interim/P6302B/initial/PC63112.AV.pkl (1907399, 3) [ PC63112.AV ]
# Writing to file  ../data/interim/P6302B/initial/PC63112E.AV.pkl (551314, 3) [ PC63112E.AV ]
# Writing to file  ../data/interim/P6302B/initial/PT63112.PV.pkl (1979423, 3) [ PT63112.PV ]
# Writing to file  ../data/interim/P6302B/initial/T6150.PV.pkl (533274, 3) [ T6150.PV ]
# Writing to file  ../data/interim/P6302B/initial/T6151.PV.pkl (791259, 3) [ T6151.PV ]
# Writing to file  ../data/interim/P6302B/initial/T6152.PV.pkl (844419, 3) [ T6152.PV ]
# Writing to file  ../data/interim/P6302B/initial/T6153.PV.pkl (952184, 3) [ T6153.PV ]
# Writing to file  ../data/interim/P6302B/initial/TC63109.AV.pkl (1871614, 3) [ TC63109.AV ]
# Writing to file  ../data/interim/P6302B/initial/TC63109E.AV.pkl (431, 3) [ TC63109E.AV ]
# Writing to file  ../data/interim/P6302B/initial/TT61B06.PV.pkl (1498412, 3) [ TT61B06.PV ]
# Writing to file  ../data/interim/P6302B/initial/TT63109.PV.pkl (1970864, 3) [ TT63109.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA61B223.PV.pkl (549160, 3) [ PA61B223.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA63110.PV.pkl (549059, 3) [ PA63110.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA63112.PV.pkl (549174, 3) [ PA63112.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA63113.PV.pkl (549156, 3) [ PA63113.PV ]
# Writing to file  ../data/interim/P6302B/initial/PAH61A98.PV.pkl (549158, 3) [ PAH61A98.PV ]
# Writing to file  ../data/interim/P6302B/initial/PAL61A98.PV.pkl (549163, 3) [ PAL61A98.PV ]
# Writing to file  ../data/interim/P6302B/initial/PC61A98.AV.pkl (1853370, 3) [ PC61A98.AV ]
# Writing to file  ../data/interim/P6302B/initial/PC61A98E.AV.pkl (551609, 3) [ PC61A98E.AV ]
# Writing to file  ../data/interim/P6302B/initial/PDA61B21.PV.pkl (549049, 3) [ PDA61B21.PV ]
# Writing to file  ../data/interim/P6302B/initial/FA61A99.PV.pkl (549030, 3) [ FA61A99.PV ]
# Writing to file  ../data/interim/P6302B/initial/FIE61A99.PV.pkl (154348, 3) [ FIE61A99.PV ]
# Writing to file  ../data/interim/P6302B/initial/FT61A99.PV.pkl (1231734, 3) [ FT61A99.PV ]
# Writing to file  ../data/interim/P6302B/initial/LA63114.PV.pkl (549182, 3) [ LA63114.PV ]
# Writing to file  ../data/interim/P6302B/initial/LAL63114.PV.pkl (549159, 3) [ LAL63114.PV ]
# Writing to file  ../data/interim/P6302B/initial/LT63114.PV.pkl (1744986, 3) [ LT63114.PV ]
# Writing to file  ../data/interim/P6302B/initial/P6302BDI.PV.pkl (550345, 3) [ P6302BDI.PV ]
# Writing to file  ../data/interim/P6302B/initial/P6302BSD.PV.pkl (549092, 3) [ P6302BSD.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA61B00.PV.pkl (549159, 3) [ PA61B00.PV ]
# Writing to file  ../data/interim/P6302B/initial/F61221.pkl (1400207, 3) [ F61221 ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B10.PNT.pkl (4133086, 3) [ 05GTWY_BN06:XT61B10.PNT ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B11.PNT.pkl (4039732, 3) [ 05GTWY_BN06:XT61B11.PNT ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B12.PNT.pkl (4006519, 3) [ 05GTWY_BN06:XT61B12.PNT ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B13.PNT.pkl (4026078, 3) [ 05GTWY_BN06:XT61B13.PNT ]
# Writing to file  ../data/interim/P6302B/initial/PIE61B00.PV.pkl (160387, 3) [ PIE61B00.PV ]
# Writing to file  ../data/interim/P6302B/initial/PIE61B22.PV.pkl (60449, 3) [ PIE61B22.PV ]
# Writing to file  ../data/interim/P6302B/initial/PIE61B23.PV.pkl (64989, 3) [ PIE61B23.PV ]
# Writing to file  ../data/interim/P6302B/initial/PIE63113.PV.pkl (214588, 3) [ PIE63113.PV ]
# Writing to file  ../data/interim/P6302B/initial/PIE61608.PV.pkl (87326, 3) [ PIE61608.PV ]
# Writing to file  ../data/interim/P6302B/initial/TAE61B47.PV.pkl (229, 3) [ TAE61B47.PV ]
# Writing to file  ../data/interim/P6302B/initial/TT61B01.PV.pkl (1538350, 3) [ TT61B01.PV ]
# Writing to file  ../data/interim/P6302B/initial/TT61B02.PV.pkl (1587413, 3) [ TT61B02.PV ]
# Writing to file  ../data/interim/P6302B/initial/TT61B03.PV.pkl (1562492, 3) [ TT61B03.PV ]
# Writing to file  ../data/interim/P6302B/initial/TT61B04.PV.pkl (1499154, 3) [ TT61B04.PV ]
# Writing to file  ../data/interim/P6302B/initial/TT61B05.PV.pkl (1638093, 3) [ TT61B05.PV ]
# Writing to file  ../data/interim/P6302B/initial/XA61B34.PV.pkl (313, 3) [ XA61B34.PV ]
# Writing to file  ../data/interim/P6302B/initial/XA61B58.PV.pkl (282, 3) [ XA61B58.PV ]
# Writing to file  ../data/interim/P6302B/initial/XAE61B34.PV.pkl (226, 3) [ XAE61B34.PV ]

# %% [markdown]
# ### Read data from Pickle Files

# %%
from utils import read_data_withfeature
df_features_all = read_data_withfeature(INT_DATA_DIR + 'initial/', True)
# Out:
# Number of files found in ../data/interim/P6302B/initial/ is 63
# ../data/interim/P6302B/initial/TT61B05.PV.pkl ['TT61B05.PV']
# ../data/interim/P6302B/initial/TAE61B47.PV.pkl ['TAE61B47.PV']
# ../data/interim/P6302B/initial/PA61B223.PV.pkl ['PA61B223.PV']
# ../data/interim/P6302B/initial/PA63113.PV.pkl ['PA63113.PV']
# ../data/interim/P6302B/initial/PT63105.PV.pkl ['PT63105.PV']
# ../data/interim/P6302B/initial/TC63109E.AV.pkl ['TC63109E.AV']
# ../data/interim/P6302B/initial/PT61B00.PV.pkl ['PT61B00.PV']
# ../data/interim/P6302B/initial/LA63114.PV.pkl ['LA63114.PV']
# ../data/interim/P6302B/initial/PC63112E.AV.pkl ['PC63112E.AV']
# ../data/interim/P6302B/initial/T6153.PV.pkl ['T6153.PV']
# ../data/interim/P6302B/initial/XA61B58.PV.pkl ['XA61B58.PV']
# ../data/interim/P6302B/initial/PIE61B23.PV.pkl ['PIE61B23.PV']
# ../data/interim/P6302B/initial/PAH61A98.PV.pkl ['PAH61A98.PV']
# ../data/interim/P6302B/initial/TT61B03.PV.pkl ['TT61B03.PV']
# ../data/interim/P6302B/initial/LT63114.PV.pkl ['LT63114.PV']
# ../data/interim/P6302B/initial/PA61B00.PV.pkl ['PA61B00.PV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B17.PNT.pkl ['05GTWY_BN06:XT61B17.PNT']
# ../data/interim/P6302B/initial/P6302BSD.PV.pkl ['P6302BSD.PV']
# ../data/interim/P6302B/initial/T6151.PV.pkl ['T6151.PV']
# ../data/interim/P6302B/initial/TT61B01.PV.pkl ['TT61B01.PV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B16.PNT.pkl ['05GTWY_BN06:XT61B16.PNT']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B20.PNT.pkl ['05GTWY_BN06:XT61B20.PNT']
# ../data/interim/P6302B/initial/PT63103.PV.pkl ['PT63103.PV']
# ../data/interim/P6302B/initial/TA63109.PV.pkl ['TA63109.PV']
# ../data/interim/P6302B/initial/PA63110.PV.pkl ['PA63110.PV']
# ../data/interim/P6302B/initial/PDA61B21.PV.pkl ['PDA61B21.PV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B13.PNT.pkl ['05GTWY_BN06:XT61B13.PNT']
# ../data/interim/P6302B/initial/P6302BDI.PV.pkl ['P6302BDI.PV']
# ../data/interim/P6302B/initial/TA61B47.PV.pkl ['TA61B47.PV']
# ../data/interim/P6302B/initial/XAE61B34.PV.pkl ['XAE61B34.PV']
# ../data/interim/P6302B/initial/PIE61B00.PV.pkl ['PIE61B00.PV']
# ../data/interim/P6302B/initial/TT61B04.PV.pkl ['TT61B04.PV']
# ../data/interim/P6302B/initial/F61221VP.pkl ['F61221VP']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B12.PNT.pkl ['05GTWY_BN06:XT61B12.PNT']
# ../data/interim/P6302B/initial/F61221.pkl ['F61221']
# ../data/interim/P6302B/initial/FA61A99.PV.pkl ['FA61A99.PV']
# ../data/interim/P6302B/initial/TT61B06.PV.pkl ['TT61B06.PV']
# ../data/interim/P6302B/initial/PA63112.PV.pkl ['PA63112.PV']
# ../data/interim/P6302B/initial/PC61A98E.AV.pkl ['PC61A98E.AV']
# ../data/interim/P6302B/initial/TT61B02.PV.pkl ['TT61B02.PV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B10.PNT.pkl ['05GTWY_BN06:XT61B10.PNT']
# ../data/interim/P6302B/initial/PC61A98.AV.pkl ['PC61A98.AV']
# ../data/interim/P6302B/initial/PIE61B22.PV.pkl ['PIE61B22.PV']
# ../data/interim/P6302B/initial/T6152.PV.pkl ['T6152.PV']
# ../data/interim/P6302B/initial/FT61A99.PV.pkl ['FT61A99.PV']
# ../data/interim/P6302B/initial/07DATASCRCP1-AI07003.PNT.pkl []
# ../data/interim/P6302B/initial/05GTWY_BN06-ZT61B14.PNT.pkl ['05GTWY_BN06:ZT61B14.PNT']
# ../data/interim/P6302B/initial/TC63109.AV.pkl ['TC63109.AV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B19.PNT.pkl ['05GTWY_BN06:XT61B19.PNT']
# ../data/interim/P6302B/initial/PAL61A98.PV.pkl ['PAL61A98.PV']
# ../data/interim/P6302B/initial/PT63112.PV.pkl ['PT63112.PV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B18.PNT.pkl ['05GTWY_BN06:XT61B18.PNT']
# ../data/interim/P6302B/initial/TT63109.PV.pkl ['TT63109.PV']
# ../data/interim/P6302B/initial/FIE61A99.PV.pkl ['FIE61A99.PV']
# ../data/interim/P6302B/initial/PIE63113.PV.pkl ['PIE63113.PV']
# ../data/interim/P6302B/initial/05GTWY_BN06-ZT61B15.PNT.pkl ['05GTWY_BN06:ZT61B15.PNT']
# ../data/interim/P6302B/initial/PC63112.AV.pkl ['PC63112.AV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B11.PNT.pkl ['05GTWY_BN06:XT61B11.PNT']
# ../data/interim/P6302B/initial/PT61A98.PV.pkl ['PT61A98.PV']
# ../data/interim/P6302B/initial/LAL63114.PV.pkl ['LAL63114.PV']
# ../data/interim/P6302B/initial/PIE61608.PV.pkl ['PIE61608.PV']
# ../data/interim/P6302B/initial/XA61B34.PV.pkl ['XA61B34.PV']
# ../data/interim/P6302B/initial/T6150.PV.pkl ['T6150.PV']
# Number of features extracted from 63 files is 62

# %%
df_features_all['PAL61A98.PV'].head()
# Out:
#             val            datetime      feature
# 2381781  NORMAL 2015-12-30 23:48:15  PAL61A98.PV
# 2381782  NORMAL 2015-12-30 23:18:15  PAL61A98.PV
# 2381783  NORMAL 2015-12-30 22:48:15  PAL61A98.PV
# 2381784  NORMAL 2015-12-30 22:19:14  PAL61A98.PV
# 2381785  NORMAL 2015-12-30 21:49:14  PAL61A98.PV

# %% [markdown]
# ### Find distinct dates for a feature

# %%
feature = 'PAL61A98.PV'
date_col = 'date'
df = df_features_all[feature]
df[date_col] = df['datetime'].apply(lambda x: x.date())

# %%
np.unique(df[date_col])
# Out:
# array([datetime.date(2014, 1, 1), datetime.date(2014, 1, 2),
#        datetime.date(2014, 1, 3), ..., datetime.date(2018, 11, 28),
#        datetime.date(2018, 11, 29), datetime.date(2018, 11, 30)],
#       dtype=object)

# %% [markdown]
# # Find Distinct Values in Alarms

# %%
tag_categ = {}
tag_categ['alarm'] = [
    'FA61A99.PV',
    'LA63114.PV',
    'LAL63114.PV',
    'PA61B00.PV',
    'PA61B223.PV',
    'PA63110.PV',
    'PA63112.PV',
    'PA63113.PV',
    'PAH61A98.PV',
    'PAL61A98.PV',
    'PDA61B21.PV',
    'TA61B47.PV',
    'TA63109.PV',
    'TAE61B47.PV',
    'XA61B34.PV',
    'XA61B58.PV',
    'XAE61B34.PV',
    'P6302BDI.PV',
    'P6302BSD.PV'
]


df_alarm = {}
for tag in tag_categ['alarm']:
    df_alarm[tag] = df_features_all[tag].copy()

# %%
for tag, df in df_alarm.items():
    print(tag, '( Total Records:', len(df), ')')
    print(df.groupby('val')['val'].count())
    print('-------------------')
# Out:
# FA61A99.PV ( Total Records: 549030 )
# val
# Arc Off-line    1
# Bad             72
# Configure       32
# Error           10
# Failed          25
# NORMAL          539207
# Scan Off        1
# TRIP            9682
# Name: val, dtype: int64
# -------------------
# LA63114.PV ( Total Records: 549182 )
# val
# Arc Off-line    1
# Bad             78
# Configure       27
# Error           8
# Failed          25
# LOW             24
# NORMAL          549018
# Scan Off        1
# Name: val, dtype: int64
# -------------------
# LAL63114.PV ( Total Records: 549159 )
# val
# Arc Off-line    1
# Bad             78
# Configure       27
# Error           8
# Failed          25
# NORMAL          549010
# Scan Off        1
# TRIP            9
# Name: val, dtype: int64
# -------------------
# PA61B00.PV ( Total Records: 549159 )
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# NORMAL          548987
# Scan Off        1
# fail            34
# Name: val, dtype: int64
# -------------------
# PA61B223.PV ( Total Records: 549160 )
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# NORMAL          548990
# Scan Off        1
# fail            32
# Name: val, dtype: int64
# -------------------
# PA63110.PV ( Total Records: 549059 )
# val
# 0.0             548903
# 1.0             18
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# Scan Off        1
# Name: val, dtype: int64
# -------------------
# PA63112.PV ( Total Records: 549174 )
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# LOW             1145
# NORMAL          547891
# Scan Off        1
# Name: val, dtype: int64
# -------------------
# PA63113.PV ( Total Records: 549156 )
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# NORMAL          548985
# Scan Off        1
# TRIP            33
# Name: val, dtype: int64
# -------------------
# PAH61A98.PV ( Total Records: 549158 )
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# NORMAL          548986
# Scan Off        1
# TRIP            34
# Name: val, dtype: int64
# -------------------
# PAL61A98.PV ( Total Records: 549163 )
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# NORMAL          548967
# Scan Off        1
# TRIP            58
# Name: val, dtype: int64
# -------------------
# PDA61B21.PV ( Total Records: 549049 )
# val
# 0.0             548893
# 1.0             18
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# Scan Off        1
# Name: val, dtype: int64
# -------------------
# TA61B47.PV ( Total Records: 267 )
# val
# ALM             49
# Arc Off-line    40
# Configure       34
# Error           14
# NORM            128
# Scan Off        2
# Name: val, dtype: int64
# -------------------
# TA63109.PV ( Total Records: 221 )
# val
# Arc Off-line    34
# Configure       33
# Error           14
# HIGH            2
# NORMAL          136
# Scan Off        2
# Name: val, dtype: int64
# -------------------
# TAE61B47.PV ( Total Records: 229 )
# val
# Arc Off-line    35
# Configure       33
# Error           14
# NORMAL          141
# Scan Off        2
# TRIP            4
# Name: val, dtype: int64
# -------------------
# XA61B34.PV ( Total Records: 313 )
# val
# ALM             62
# Arc Off-line    39
# CLOSED          2
# Configure       34
# Error           14
# NORM            160
# Scan Off        2
# Name: val, dtype: int64
# -------------------
# XA61B58.PV ( Total Records: 282 )
# val
# Arc Off-line    39
# Configure       34
# Error           14
# NORMAL          164
# Scan Off        2
# fail            29
# Name: val, dtype: int64
# -------------------
# XAE61B34.PV ( Total Records: 226 )
# val
# Arc Off-line    34
# Configure       33
# Error           14
# NORMAL          140
# Scan Off        2
# fail            3
# Name: val, dtype: int64
# -------------------
# P6302BDI.PV ( Total Records: 550345 )
# val
# ??? 0           242666
# ??? 1           307535
# Arc Off-line    1
# Bad             78
# CLOSED          6
# Configure       25
# Error           8
# Failed          25
# Scan Off        1
# Name: val, dtype: int64
# -------------------
# P6302BSD.PV ( Total Records: 549092 )
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# NORMAL          548911
# Scan Off        1
# TRIP            43
# Name: val, dtype: int64
# -------------------

# %%
# Copy the data into a test dataframe to see how many values can be replaced
df_alarm_test = df_alarm.copy()

mapping = {
    'alm':0,
    '??? 0':0,
    '??? 1':1,
    '0.0':0,
    '1.0':1,
    'arc off-line':0,
    'bad':0, 
    'closed':0,
    'configure':0,
    'error':0,
    'failed':0,
    'fail':0,
    'high':0,
    'low':0,
    'normal':1,
    'norm':1,
    'scan off':0,
    'trip':0,
}

for tag, df in df_alarm_test.items():
    print(df.groupby('val')['val'].count())
    df['val'] = df['val'].apply(lambda x: str(x).lower().strip())
    df['val'] = df['val'].replace(mapping)
    print(df.groupby('val')['val'].count())
    print('---------===========----------')
# Out:
# val
# Arc Off-line    1
# Bad             72
# Configure       32
# Error           10
# Failed          25
# NORMAL          539207
# Scan Off        1
# TRIP            9682
# Name: val, dtype: int64
# val
# 0    9823
# 1    539207
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    1
# Bad             78
# Configure       27
# Error           8
# Failed          25
# LOW             24
# NORMAL          549018
# Scan Off        1
# Name: val, dtype: int64
# val
# 0    164
# 1    549018
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    1
# Bad             78
# Configure       27
# Error           8
# Failed          25
# NORMAL          549010
# Scan Off        1
# TRIP            9
# Name: val, dtype: int64
# val
# 0    149
# 1    549010
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# NORMAL          548987
# Scan Off        1
# fail            34
# Name: val, dtype: int64
# val
# 0    172
# 1    548987
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# NORMAL          548990
# Scan Off        1
# fail            32
# Name: val, dtype: int64
# val
# 0    170
# 1    548990
# Name: val, dtype: int64
# ---------===========----------
# val
# 0.0             548903
# 1.0             18
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# Scan Off        1
# Name: val, dtype: int64
# val
# 0    549041
# 1    18
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# LOW             1145
# NORMAL          547891
# Scan Off        1
# Name: val, dtype: int64
# val
# 0    1283
# 1    547891
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# NORMAL          548985
# Scan Off        1
# TRIP            33
# Name: val, dtype: int64
# val
# 0    171
# 1    548985
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# NORMAL          548986
# Scan Off        1
# TRIP            34
# Name: val, dtype: int64
# val
# 0    172
# 1    548986
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# NORMAL          548967
# Scan Off        1
# TRIP            58
# Name: val, dtype: int64
# val
# 0    196
# 1    548967
# Name: val, dtype: int64
# ---------===========----------
# val
# 0.0             548893
# 1.0             18
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# Scan Off        1
# Name: val, dtype: int64
# val
# 0    549031
# 1    18
# Name: val, dtype: int64
# ---------===========----------
# val
# ALM             49
# Arc Off-line    40
# Configure       34
# Error           14
# NORM            128
# Scan Off        2
# Name: val, dtype: int64
# val
# 0    139
# 1    128
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    34
# Configure       33
# Error           14
# HIGH            2
# NORMAL          136
# Scan Off        2
# Name: val, dtype: int64
# val
# 0    85
# 1    136
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    35
# Configure       33
# Error           14
# NORMAL          141
# Scan Off        2
# TRIP            4
# Name: val, dtype: int64
# val
# 0    88
# 1    141
# Name: val, dtype: int64
# ---------===========----------
# val
# ALM             62
# Arc Off-line    39
# CLOSED          2
# Configure       34
# Error           14
# NORM            160
# Scan Off        2
# Name: val, dtype: int64
# val
# 0    153
# 1    160
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    39
# Configure       34
# Error           14
# NORMAL          164
# Scan Off        2
# fail            29
# Name: val, dtype: int64
# val
# 0    118
# 1    164
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    34
# Configure       33
# Error           14
# NORMAL          140
# Scan Off        2
# fail            3
# Name: val, dtype: int64
# val
# 0    86
# 1    140
# Name: val, dtype: int64
# ---------===========----------
# val
# ??? 0           242666
# ??? 1           307535
# Arc Off-line    1
# Bad             78
# CLOSED          6
# Configure       25
# Error           8
# Failed          25
# Scan Off        1
# Name: val, dtype: int64
# val
# 0    242810
# 1    307535
# Name: val, dtype: int64
# ---------===========----------
# val
# Arc Off-line    1
# Bad             78
# Configure       25
# Error           8
# Failed          25
# NORMAL          548911
# Scan Off        1
# TRIP            43
# Name: val, dtype: int64
# val
# 0    181
# 1    548911
# Name: val, dtype: int64
# ---------===========----------

# %%
df_alarm['PAL61A98.PV'].head()
# Out:
#          val            datetime      feature
# 2381781  1   2015-12-30 23:48:15  PAL61A98.PV
# 2381782  1   2015-12-30 23:18:15  PAL61A98.PV
# 2381783  1   2015-12-30 22:48:15  PAL61A98.PV
# 2381784  1   2015-12-30 22:19:14  PAL61A98.PV
# 2381785  1   2015-12-30 21:49:14  PAL61A98.PV

# %% [markdown]
# ### Write down alarm files into initial directory

# %%
from utils import write_feature_dict

dir_path = INT_DATA_DIR + 'initial/'
write_feature_dict(dir_path, df_alarm, remove_existing=False)
# Out:
# Writing to file  ../data/interim/P6302B/initial/FA61A99.PV.pkl (549030, 3) [ FA61A99.PV ]
# Writing to file  ../data/interim/P6302B/initial/LA63114.PV.pkl (549182, 3) [ LA63114.PV ]
# Writing to file  ../data/interim/P6302B/initial/LAL63114.PV.pkl (549159, 3) [ LAL63114.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA61B00.PV.pkl (549159, 3) [ PA61B00.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA61B223.PV.pkl (549160, 3) [ PA61B223.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA63110.PV.pkl (549059, 3) [ PA63110.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA63112.PV.pkl (549174, 3) [ PA63112.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA63113.PV.pkl (549156, 3) [ PA63113.PV ]
# Writing to file  ../data/interim/P6302B/initial/PAH61A98.PV.pkl (549158, 3) [ PAH61A98.PV ]
# Writing to file  ../data/interim/P6302B/initial/PAL61A98.PV.pkl (549163, 3) [ PAL61A98.PV ]
# Writing to file  ../data/interim/P6302B/initial/PDA61B21.PV.pkl (549049, 3) [ PDA61B21.PV ]
# Writing to file  ../data/interim/P6302B/initial/TA61B47.PV.pkl (267, 3) [ TA61B47.PV ]
# Writing to file  ../data/interim/P6302B/initial/TA63109.PV.pkl (221, 3) [ TA63109.PV ]
# Writing to file  ../data/interim/P6302B/initial/TAE61B47.PV.pkl (229, 3) [ TAE61B47.PV ]
# Writing to file  ../data/interim/P6302B/initial/XA61B34.PV.pkl (313, 3) [ XA61B34.PV ]
# Writing to file  ../data/interim/P6302B/initial/XA61B58.PV.pkl (282, 3) [ XA61B58.PV ]
# Writing to file  ../data/interim/P6302B/initial/XAE61B34.PV.pkl (226, 3) [ XAE61B34.PV ]
# Writing to file  ../data/interim/P6302B/initial/P6302BDI.PV.pkl (550345, 3) [ P6302BDI.PV ]
# Writing to file  ../data/interim/P6302B/initial/P6302BSD.PV.pkl (549092, 3) [ P6302BSD.PV ]

# %% [markdown]
# ### Read data from Pickle Files

# %%
from utils import read_data_withfeature
df_features_all = read_data_withfeature(INT_DATA_DIR + 'initial/', True)
# Out:
# Number of files found in ../data/interim/P6302B/initial/ is 63
# ../data/interim/P6302B/initial/TT61B05.PV.pkl ['TT61B05.PV']
# ../data/interim/P6302B/initial/TAE61B47.PV.pkl ['TAE61B47.PV']
# ../data/interim/P6302B/initial/PA61B223.PV.pkl ['PA61B223.PV']
# ../data/interim/P6302B/initial/PA63113.PV.pkl ['PA63113.PV']
# ../data/interim/P6302B/initial/PT63105.PV.pkl ['PT63105.PV']
# ../data/interim/P6302B/initial/TC63109E.AV.pkl ['TC63109E.AV']
# ../data/interim/P6302B/initial/PT61B00.PV.pkl ['PT61B00.PV']
# ../data/interim/P6302B/initial/LA63114.PV.pkl ['LA63114.PV']
# ../data/interim/P6302B/initial/PC63112E.AV.pkl ['PC63112E.AV']
# ../data/interim/P6302B/initial/T6153.PV.pkl ['T6153.PV']
# ../data/interim/P6302B/initial/XA61B58.PV.pkl ['XA61B58.PV']
# ../data/interim/P6302B/initial/PIE61B23.PV.pkl ['PIE61B23.PV']
# ../data/interim/P6302B/initial/PAH61A98.PV.pkl ['PAH61A98.PV']
# ../data/interim/P6302B/initial/TT61B03.PV.pkl ['TT61B03.PV']
# ../data/interim/P6302B/initial/LT63114.PV.pkl ['LT63114.PV']
# ../data/interim/P6302B/initial/PA61B00.PV.pkl ['PA61B00.PV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B17.PNT.pkl ['05GTWY_BN06:XT61B17.PNT']
# ../data/interim/P6302B/initial/P6302BSD.PV.pkl ['P6302BSD.PV']
# ../data/interim/P6302B/initial/T6151.PV.pkl ['T6151.PV']
# ../data/interim/P6302B/initial/TT61B01.PV.pkl ['TT61B01.PV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B16.PNT.pkl ['05GTWY_BN06:XT61B16.PNT']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B20.PNT.pkl ['05GTWY_BN06:XT61B20.PNT']
# ../data/interim/P6302B/initial/PT63103.PV.pkl ['PT63103.PV']
# ../data/interim/P6302B/initial/TA63109.PV.pkl ['TA63109.PV']
# ../data/interim/P6302B/initial/PA63110.PV.pkl ['PA63110.PV']
# ../data/interim/P6302B/initial/PDA61B21.PV.pkl ['PDA61B21.PV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B13.PNT.pkl ['05GTWY_BN06:XT61B13.PNT']
# ../data/interim/P6302B/initial/P6302BDI.PV.pkl ['P6302BDI.PV']
# ../data/interim/P6302B/initial/TA61B47.PV.pkl ['TA61B47.PV']
# ../data/interim/P6302B/initial/XAE61B34.PV.pkl ['XAE61B34.PV']
# ../data/interim/P6302B/initial/PIE61B00.PV.pkl ['PIE61B00.PV']
# ../data/interim/P6302B/initial/TT61B04.PV.pkl ['TT61B04.PV']
# ../data/interim/P6302B/initial/F61221VP.pkl ['F61221VP']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B12.PNT.pkl ['05GTWY_BN06:XT61B12.PNT']
# ../data/interim/P6302B/initial/F61221.pkl ['F61221']
# ../data/interim/P6302B/initial/FA61A99.PV.pkl ['FA61A99.PV']
# ../data/interim/P6302B/initial/TT61B06.PV.pkl ['TT61B06.PV']
# ../data/interim/P6302B/initial/PA63112.PV.pkl ['PA63112.PV']
# ../data/interim/P6302B/initial/PC61A98E.AV.pkl ['PC61A98E.AV']
# ../data/interim/P6302B/initial/TT61B02.PV.pkl ['TT61B02.PV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B10.PNT.pkl ['05GTWY_BN06:XT61B10.PNT']
# ../data/interim/P6302B/initial/PC61A98.AV.pkl ['PC61A98.AV']
# ../data/interim/P6302B/initial/PIE61B22.PV.pkl ['PIE61B22.PV']
# ../data/interim/P6302B/initial/T6152.PV.pkl ['T6152.PV']
# ../data/interim/P6302B/initial/FT61A99.PV.pkl ['FT61A99.PV']
# ../data/interim/P6302B/initial/07DATASCRCP1-AI07003.PNT.pkl []
# ../data/interim/P6302B/initial/05GTWY_BN06-ZT61B14.PNT.pkl ['05GTWY_BN06:ZT61B14.PNT']
# ../data/interim/P6302B/initial/TC63109.AV.pkl ['TC63109.AV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B19.PNT.pkl ['05GTWY_BN06:XT61B19.PNT']
# ../data/interim/P6302B/initial/PAL61A98.PV.pkl ['PAL61A98.PV']
# ../data/interim/P6302B/initial/PT63112.PV.pkl ['PT63112.PV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B18.PNT.pkl ['05GTWY_BN06:XT61B18.PNT']
# ../data/interim/P6302B/initial/TT63109.PV.pkl ['TT63109.PV']
# ../data/interim/P6302B/initial/FIE61A99.PV.pkl ['FIE61A99.PV']
# ../data/interim/P6302B/initial/PIE63113.PV.pkl ['PIE63113.PV']
# ../data/interim/P6302B/initial/05GTWY_BN06-ZT61B15.PNT.pkl ['05GTWY_BN06:ZT61B15.PNT']
# ../data/interim/P6302B/initial/PC63112.AV.pkl ['PC63112.AV']
# ../data/interim/P6302B/initial/05GTWY_BN06-XT61B11.PNT.pkl ['05GTWY_BN06:XT61B11.PNT']
# ../data/interim/P6302B/initial/PT61A98.PV.pkl ['PT61A98.PV']
# ../data/interim/P6302B/initial/LAL63114.PV.pkl ['LAL63114.PV']
# ../data/interim/P6302B/initial/PIE61608.PV.pkl ['PIE61608.PV']
# ../data/interim/P6302B/initial/XA61B34.PV.pkl ['XA61B34.PV']
# ../data/interim/P6302B/initial/T6150.PV.pkl ['T6150.PV']
# Number of features extracted from 63 files is 62

# %%
from utils import get_tags, is_number
value_col = 'val'
df_tag = df_features_all['TT61B02.PV'].copy()
print(len(df_tag.loc[df_tag[value_col] == 'Error']))
# print(df_tag.dtypes)
print(len(df_tag))

df_tag[value_col] = df_tag[value_col].apply(lambda x: float(x) if is_number(x) else None)
df_tag.dropna(inplace=True)
# print(df_tag.dtypes)
print(len(df_tag))
# Out:
# 24
# 1587413
# 1587388

# %% [markdown]
# ### Removing non-float values from non-alarm tags

# %%
from utils import get_tags, is_number

non_alarm_tag_types = ['vibration', 'temperature', 'pressure', 'level', 'flow', 'setpoint']
value_col = 'val'

for non_alarm_tag_type in non_alarm_tag_types:
    na_tags = get_tags(non_alarm_tag_type)
    for tag in na_tags:
        if tag in df_features_all.keys():
            df_tag = df_features_all[tag]
            df_tag[value_col] = df_tag[value_col].apply(lambda x: float(x) if is_number(x) else None)
            # df_tag.dropna(inplace=True)

# %% [markdown]
# ### Writing to Pickle Files

# %%
from utils import write_feature_dict

dir_path = INT_DATA_DIR + 'initial/'
write_feature_dict(dir_path, df_features=df_features_all, remove_existing=False)
# Out:
# Writing to file  ../data/interim/P6302B/initial/TT61B05.PV.pkl (1638071, 3) [ TT61B05.PV ]
# Writing to file  ../data/interim/P6302B/initial/TAE61B47.PV.pkl (229, 3) [ TAE61B47.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA61B223.PV.pkl (549160, 3) [ PA61B223.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA63113.PV.pkl (549156, 3) [ PA63113.PV ]
# Writing to file  ../data/interim/P6302B/initial/PT63105.PV.pkl (689849, 3) [ PT63105.PV ]
# Writing to file  ../data/interim/P6302B/initial/TC63109E.AV.pkl (362, 3) [ TC63109E.AV ]
# Writing to file  ../data/interim/P6302B/initial/PT61B00.PV.pkl (2096958, 3) [ PT61B00.PV ]
# Writing to file  ../data/interim/P6302B/initial/LA63114.PV.pkl (549182, 3) [ LA63114.PV ]
# Writing to file  ../data/interim/P6302B/initial/PC63112E.AV.pkl (551172, 3) [ PC63112E.AV ]
# Writing to file  ../data/interim/P6302B/initial/T6153.PV.pkl (952149, 3) [ T6153.PV ]
# Writing to file  ../data/interim/P6302B/initial/XA61B58.PV.pkl (282, 3) [ XA61B58.PV ]
# Writing to file  ../data/interim/P6302B/initial/PIE61B23.PV.pkl (64972, 3) [ PIE61B23.PV ]
# Writing to file  ../data/interim/P6302B/initial/PAH61A98.PV.pkl (549158, 3) [ PAH61A98.PV ]
# Writing to file  ../data/interim/P6302B/initial/TT61B03.PV.pkl (1562467, 3) [ TT61B03.PV ]
# Writing to file  ../data/interim/P6302B/initial/LT63114.PV.pkl (1744843, 3) [ LT63114.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA61B00.PV.pkl (549159, 3) [ PA61B00.PV ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B17.PNT.pkl (4052839, 3) [ 05GTWY_BN06:XT61B17.PNT ]
# Writing to file  ../data/interim/P6302B/initial/P6302BSD.PV.pkl (549092, 3) [ P6302BSD.PV ]
# Writing to file  ../data/interim/P6302B/initial/T6151.PV.pkl (791222, 3) [ T6151.PV ]
# Writing to file  ../data/interim/P6302B/initial/TT61B01.PV.pkl (1538325, 3) [ TT61B01.PV ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B16.PNT.pkl (3315813, 3) [ 05GTWY_BN06:XT61B16.PNT ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B20.PNT.pkl (4334752, 3) [ 05GTWY_BN06:XT61B20.PNT ]
# Writing to file  ../data/interim/P6302B/initial/PT63103.PV.pkl (1316335, 3) [ PT63103.PV ]
# Writing to file  ../data/interim/P6302B/initial/TA63109.PV.pkl (221, 3) [ TA63109.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA63110.PV.pkl (549059, 3) [ PA63110.PV ]
# Writing to file  ../data/interim/P6302B/initial/PDA61B21.PV.pkl (549049, 3) [ PDA61B21.PV ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B13.PNT.pkl (4025972, 3) [ 05GTWY_BN06:XT61B13.PNT ]
# Writing to file  ../data/interim/P6302B/initial/P6302BDI.PV.pkl (550345, 3) [ P6302BDI.PV ]
# Writing to file  ../data/interim/P6302B/initial/TA61B47.PV.pkl (267, 3) [ TA61B47.PV ]
# Writing to file  ../data/interim/P6302B/initial/XAE61B34.PV.pkl (226, 3) [ XAE61B34.PV ]
# Writing to file  ../data/interim/P6302B/initial/PIE61B00.PV.pkl (156994, 3) [ PIE61B00.PV ]
# Writing to file  ../data/interim/P6302B/initial/TT61B04.PV.pkl (1499129, 3) [ TT61B04.PV ]
# Writing to file  ../data/interim/P6302B/initial/F61221VP.pkl (1485422, 3) [ F61221VP ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B12.PNT.pkl (4006413, 3) [ 05GTWY_BN06:XT61B12.PNT ]
# Writing to file  ../data/interim/P6302B/initial/F61221.pkl (1400056, 3) [ F61221 ]
# Writing to file  ../data/interim/P6302B/initial/FA61A99.PV.pkl (549030, 3) [ FA61A99.PV ]
# Writing to file  ../data/interim/P6302B/initial/TT61B06.PV.pkl (1498387, 3) [ TT61B06.PV ]
# Writing to file  ../data/interim/P6302B/initial/PA63112.PV.pkl (549174, 3) [ PA63112.PV ]
# Writing to file  ../data/interim/P6302B/initial/PC61A98E.AV.pkl (551464, 3) [ PC61A98E.AV ]
# Writing to file  ../data/interim/P6302B/initial/TT61B02.PV.pkl (1587388, 3) [ TT61B02.PV ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B10.PNT.pkl (4132980, 3) [ 05GTWY_BN06:XT61B10.PNT ]
# Writing to file  ../data/interim/P6302B/initial/PC61A98.AV.pkl (1853227, 3) [ PC61A98.AV ]
# Writing to file  ../data/interim/P6302B/initial/PIE61B22.PV.pkl (60432, 3) [ PIE61B22.PV ]
# Writing to file  ../data/interim/P6302B/initial/T6152.PV.pkl (844384, 3) [ T6152.PV ]
# Writing to file  ../data/interim/P6302B/initial/FT61A99.PV.pkl (1231599, 3) [ FT61A99.PV ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-ZT61B14.PNT.pkl (4125888, 3) [ 05GTWY_BN06:ZT61B14.PNT ]
# Writing to file  ../data/interim/P6302B/initial/TC63109.AV.pkl (1871583, 3) [ TC63109.AV ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B19.PNT.pkl (4387448, 3) [ 05GTWY_BN06:XT61B19.PNT ]
# Writing to file  ../data/interim/P6302B/initial/PAL61A98.PV.pkl (549163, 3) [ PAL61A98.PV ]
# Writing to file  ../data/interim/P6302B/initial/PT63112.PV.pkl (1979396, 3) [ PT63112.PV ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B18.PNT.pkl (4349569, 3) [ 05GTWY_BN06:XT61B18.PNT ]
# Writing to file  ../data/interim/P6302B/initial/TT63109.PV.pkl (1970833, 3) [ TT63109.PV ]
# Writing to file  ../data/interim/P6302B/initial/FIE61A99.PV.pkl (151531, 3) [ FIE61A99.PV ]
# Writing to file  ../data/interim/P6302B/initial/PIE63113.PV.pkl (214570, 3) [ PIE63113.PV ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-ZT61B15.PNT.pkl (4102798, 3) [ 05GTWY_BN06:ZT61B15.PNT ]
# Writing to file  ../data/interim/P6302B/initial/PC63112.AV.pkl (1907256, 3) [ PC63112.AV ]
# Writing to file  ../data/interim/P6302B/initial/05GTWY_BN06-XT61B11.PNT.pkl (4039626, 3) [ 05GTWY_BN06:XT61B11.PNT ]
# Writing to file  ../data/interim/P6302B/initial/PT61A98.PV.pkl (1949598, 3) [ PT61A98.PV ]
# Writing to file  ../data/interim/P6302B/initial/LAL63114.PV.pkl (549159, 3) [ LAL63114.PV ]
# Writing to file  ../data/interim/P6302B/initial/PIE61608.PV.pkl (87309, 3) [ PIE61608.PV ]
# Writing to file  ../data/interim/P6302B/initial/XA61B34.PV.pkl (313, 3) [ XA61B34.PV ]
# Writing to file  ../data/interim/P6302B/initial/T6150.PV.pkl (533238, 3) [ T6150.PV ]
