# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
import os
import ntpath
import pickle as pkl
import xlrd
import time
import string

from os import listdir
from os.path import isfile, join

# %% [markdown]
# ### Notebook options

# %%
pd.set_option('display.max_colwidth', -1) # Column width
plt.rcParams['figure.figsize'] = [15, 10] # Size of the plots

# %% [markdown]
# ### General Assumptions

# %%
time_col = 'datetime'
time_gran_col = 'datetime_gran'
value_col = 'val'
scaled_value_col = 'scaled_val'
time_granularity = 'min'

# %% [markdown]
# ### Functions

# %%
def get_seconds_after(current_date, base_date):
    
    base_ts = time.mktime(base_date.timetuple()) # Converting to Unix timestamp
    current_ts = time.mktime(current_date.timetuple())
    time_diff = round((current_ts - base_ts))
    
    return time_diff

# %%
def get_minutes_after(current_date, base_date):
        
    base_ts = time.mktime(base_date.timetuple()) # Converting to Unix timestamp
    current_ts = time.mktime(current_date.timetuple())
    time_diff = round((current_ts - base_ts) / 60.0) + 1
    
    return time_diff

# %%
def get_hours_after(current_date, base_date):
    
    base_ts = time.mktime(base_date.timetuple()) # Converting to Unix timestamp
    current_ts = time.mktime(current_date.timetuple())
    time_diff = round((current_ts - base_ts) / 60.0 / 60.0) + 1
    
    return time_diff

# %%
def get_days_after(current_date, base_date):
    
    base_ts = time.mktime(base_date.timetuple()) # Converting to Unix timestamp
    current_ts = time.mktime(current_date.timetuple())
    time_diff = round((current_ts - base_ts) / 60.0 / 60.0 / 24) + 1
    
    return time_diff

# %%
def get_months_after(current_date, base_date):    
    time_diff = ((current_date.year - base_date.year) * 12) + current_date.month - base_date.month + 1    
    return time_diff

# %%
def get_years_after(current_date, base_date):    
    time_diff = (current_date.year - base_date.year) + 1 
    return time_diff

# %%
def get_time_from_minutes(time_in_mins, base_date):    
    new_date = base_date + timedelta(minutes = time_in_mins)        
    return new_date

# %% [markdown]
# #### Debug

# %%
fmt = '%Y-%m-%d %H:%M:%S'
start_date = datetime.strptime('2017-01-01 00:00:01', fmt)
stop_date = datetime.strptime('2019-01-01 00:00:01', fmt)

td_min = get_minutes_after(stop_date, start_date)
print(td_min)

td_hours = get_hours_after(stop_date, start_date)
print(td_hours)

td_days = get_days_after(stop_date, start_date)
print(td_days)

td_mon = get_months_after(stop_date, start_date)
print(td_mon)

td_year = get_years_after(stop_date, start_date)
print(td_year)
# Out:
# 1051201
# 17521
# 731
# 25
# 3

# %% [markdown]
# ### Data Directies

# %%
RAW_DATA_DIR = '../data/raw/'
PROC_DATA_DIR = '../data/processed/P1201/'
INT_DATA_DIR = '../data/interim/P1201/'

# %% [markdown]
# ### Reading the Data

# %%
def read_data(input_path, print_debug = False):
    
    df_features = {}
    
    if os.path.isdir(input_path):
        input_files = [f for f in listdir(input_path) if (isfile(join(input_path, f))) and ((f.endswith('.pkl')) or (f.endswith('.csv')))]
    elif os.path.isfile(input_path):
        input_files = input_path
    
    if print_debug:
        print('Number of files found in %s is %d ' % (input_path, len(input_files)))
    
    for input_file in input_files:
        # feature,_ = os.path.splitext(input_file)
        input_file = input_path + input_file  
        
        with open(input_file, 'rb') as f:
            df = pkl.load(f)
            unq_features = np.unique(df['feature'])
            if len(unq_features) > 1:
                if print_debug:
                    print('There are %d features in file %s' % (len(unq_features), input_file))
                continue
            feature = unq_features[0]            
            df_features[feature]= df
    
    if print_debug:
        print('Number of features extracted from %d files is %d ' % (len(input_files), len(df_features)))
    
    return df_features

# %%
# Testing read_data function
df_features = read_data(INT_DATA_DIR, True)
# Out:
# Number of files found in ../data/interim/P1201/ is 35
# Number of features extracted from 35 files is 35

# %%
print('Number of features = ', len(list(df_features.keys())))
# Out:
# Number of features =  35

# %%
def get_granulairty_function(granularity, current_date, base_date):
    
    if granularity == 'sec':
        return get_seconds_after(current_date, base_date)
    elif granularity == 'min':
        return get_minutes_after(current_date, base_date)
    elif granularity == 'hr':
        return get_hours_after(current_date, base_date)
    elif granularity == 'day':
        return get_days_after(current_date, base_date)
    elif granularity == 'mon':
        return get_months_after(current_date, base_date)
    elif granularity == 'yr':
        return get_years_after(current_date, base_date)
    
    return get_minutes_after(current_date, base_date) # Default return function is for minutes

# %%
df_features.keys()
# Out:
# dict_keys(['HART_P1CP01_PI12026BT.MEAS', 'HART_P1CP04_PY12110FB.MEAS', '12P01BCP4_FC12847.SPT', 'HART_P1CP04_PY12516FB.MEAS', '12P01BCP4_PI12956.PNT', 'HART_P1CP01_PI12037BT.MEAS', 'HART_P1CP04_PX12003FB.MEAS', '12GTWY_E101_FTE12404MS.CIN', 'HART_U1CP03_PX12003BT.MEAS', '12GTWY_FG404_AAH12554BSP.PNT', '12GTWY_E101_E12101FI.CIN', 'HART_P1CP04_PY12109FB.MEAS', '12GTWY_E101_FALE12404SP.PNT', '12P01BCP4_PI12955.PNT', 'HART_P1CP01_PI12046BT.MEAS', '12GTWY_FG404_AAH12569SP.PNT', 'HART_U1CP03_PY24092FB.MEAS', '12GTWY_FG404_AAH12570SP.PNT', 'HART_P1CP04_FY12847FB.MEAS', '12GTWY_E101_ZAE12131FI.CIN', 'HART_P1CP04_FI12002BT.MEAS', '12GTWY_E428_HAE12646FI.CIN', '12GTWY_FG404_AAH12555BSP.PNT', '12GTWY_E101_FIE12404.PNT', '12GTWY_E104_HAE12131FI.CIN', '12P01BCP4_FC12847.MEAS', '12GTWY_E104_E12104FI.CIN', 'HART_P1CP04_HY12017FB.MEAS', '12GTWY_E101_FALE12404FI.CIN', 'HART_P1CP04_PI12003BT.MEAS', 'HART_P1CP04_PY12003AFB.MEAS', '12GTWY_FG404_AI12554B.PNT', '12P01BCP4_FC12847.OUT', 'HART_P1CP04_LY12001FB.MEAS', '12P01BCP4_XI12597.CIN'])

# %%
# Testing generate_master_df() function
fmt = '%Y-%m-%d %H:%M:%S'
start_date = datetime.strptime('2017-01-01 00:00:01', fmt)
stop_date = datetime.strptime('2019-01-01 00:00:01', fmt)

df_master = generate_master_df('hr', start_date, stop_date)

# %% [markdown]
# ### Generate Statistics Table

# %%
def generate_stats_df(df_features):

    df_stats = pd.DataFrame(columns=['feature', 'total_count', 'missing_val_count', 'max_val', 'min_val', 'variance', 'std', 'mean_val', 'median_val', 'kurt', 'skew'])
    idx = 0

    for feature, df in df_features.items():    
        df_stats.loc[idx] = [feature, len(df), len(df)-df['val'].count(), df['val'].max(), df['val'].min(), df['val'].var(), df['val'].std(), df['val'].mean(), df['val'].median(), df['val'].kurt(), df['val'].skew()]
        idx += 1
        
    # Get the percentage missing values
    df_stats['perc_missing'] = df_stats['missing_val_count']/df_stats['total_count'] * 100
    return df_stats

# %%
# Testing generate_stats_df()
df_stats = generate_stats_df(df_features)

# %%
df_stats
# Out:
#                          feature total_count missing_val_count     max_val  \
# 0   HART_P1CP01_PI12026BT.MEAS    59611       59611            NaN
# 1   HART_P1CP04_PY12110FB.MEAS    1278552     628               102.12500
# 2   12P01BCP4_FC12847.SPT         270028      9                 100.00000
# 3   HART_P1CP04_PY12516FB.MEAS    356369      15                101.81250
# 4   12P01BCP4_PI12956.PNT         784473      1                 4447.38300
# 5   HART_P1CP01_PI12037BT.MEAS    59610       59610            NaN
# 6   HART_P1CP04_PX12003FB.MEAS    60042       60042            NaN
# 7   12GTWY_E101_FTE12404MS.CIN    71387       20                1.00000
# 8   HART_U1CP03_PX12003BT.MEAS    51415       51415            NaN
# 9   12GTWY_FG404_AAH12554BSP.PNT  35081       18                2.00000
# 10  12GTWY_E101_E12101FI.CIN      71413       20                1.00000
# 11  HART_P1CP04_PY12109FB.MEAS    1379603     628               98.00000
# 12  12GTWY_E101_FALE12404SP.PNT   56792       18                24.00000
# 13  12P01BCP4_PI12955.PNT         784488      1                 4256.90800
# 14  HART_P1CP01_PI12046BT.MEAS    59617       59617            NaN
# 15  12GTWY_FG404_AAH12569SP.PNT   35081       18                19.00000
# 16  HART_U1CP03_PY24092FB.MEAS    1040792     591               97.25000
# 17  12GTWY_FG404_AAH12570SP.PNT   35081       18                19.00000
# 18  HART_P1CP04_FY12847FB.MEAS    163747      15                102.12500
# 19  12GTWY_E101_ZAE12131FI.CIN    71377       3126              1.00000
# 20  HART_P1CP04_FI12002BT.MEAS    59688       59688            NaN
# 21  12GTWY_E428_HAE12646FI.CIN    244         244              NaN
# 22  12GTWY_FG404_AAH12555BSP.PNT  35081       18                2.00000
# 23  12GTWY_E101_FIE12404.PNT      386448      1                 96.09976
# 24  12GTWY_E104_HAE12131FI.CIN    71376       3126              1.00000
# 25  12P01BCP4_FC12847.MEAS        784344      3                 122.72710
# 26  12GTWY_E104_E12104FI.CIN      71375       20                1.00000
# 27  HART_P1CP04_HY12017FB.MEAS    59739       59739            NaN
# 28  12GTWY_E101_FALE12404FI.CIN   71410       3126              1.00000
# 29  HART_P1CP04_PI12003BT.MEAS    59737       59737            NaN
# 30  HART_P1CP04_PY12003AFB.MEAS   1009530     623               100.75000
# 31  12GTWY_FG404_AI12554B.PNT     1           1                NaN
# 32  12P01BCP4_FC12847.OUT         61945       9                 100.00000
# 33  HART_P1CP04_LY12001FB.MEAS    59735       59735            NaN
# 34  12P01BCP4_XI12597.CIN         56448       9                 1.00000
#
#         min_val      variance         std     mean_val   median_val  \
# 0  NaN          NaN           NaN         NaN          NaN
# 1   0.207519     0.468946      0.684796    5.849385     5.871094
# 2   0.000000     257.737859    16.054216   8.058265     0.021973
# 3  -1.123047     370.892399    19.258567   23.751814    20.109380
# 4   3784.385000  21201.262845  145.606534  4117.185829  4100.478000
# 5  NaN          NaN           NaN         NaN          NaN
# 6  NaN          NaN           NaN         NaN          NaN
# 7   0.000000     0.002321      0.048173    0.002326     0.000000
# 8  NaN          NaN           NaN         NaN          NaN
# 9   2.000000     0.000000      0.000000    2.000000     2.000000
# 10  0.000000     0.003545      0.059541    0.003558     0.000000
# 11  3.990234     1.241363      1.114165    10.306142    10.296880
# 12  24.000000    0.000000      0.000000    24.000000    24.000000
# 13  3606.624000  6306.483128   79.413369   3977.178800  3970.119000
# 14 NaN          NaN           NaN         NaN          NaN
# 15  19.000000    0.000000      0.000000    19.000000    19.000000
# 16  3.648438     288.956458    16.998719   72.205858    76.000000
# 17  19.000000    0.000000      0.000000    19.000000    19.000000
# 18 -0.610352     411.079160    20.275087   96.440620    100.562500
# 19  0.000000     0.002441      0.049405    0.002447     0.000000
# 20 NaN          NaN           NaN         NaN          NaN
# 21 NaN          NaN           NaN         NaN          NaN
# 22  2.000000     0.000000      0.000000    2.000000     2.000000
# 23  32.344300    205.308187    14.328579   69.175845    68.580590
# 24  0.000000     0.000132      0.011483    0.000132     0.000000
# 25 -0.017090     12.383863     3.519071    0.613796     0.009766
# 26  0.000000     0.000126      0.011230    0.000126     0.000000
# 27 NaN          NaN           NaN         NaN          NaN
# 28  0.000000     0.001272      0.035672    0.001274     0.000000
# 29 NaN          NaN           NaN         NaN          NaN
# 30  13.984380    129.311679    11.371529   30.904592    27.828130
# 31 NaN          NaN           NaN         NaN          NaN
# 32  0.000000     211.496359    14.542914   97.783053    100.000000
# 33 NaN          NaN           NaN         NaN          NaN
# 34  0.000000     0.000531      0.023049    0.000532     0.000000
#
#            kurt       skew perc_missing
# 0  NaN          NaN         1
# 1   2992.421913  34.975494  0.000491181
# 2   0.403597     1.518819   3.33299e-05
# 3  -0.541288     0.479581   4.20912e-05
# 4  -0.922735     0.084622   1.27474e-06
# 5  NaN          NaN         1
# 6  NaN          NaN         1
# 7   424.953874   20.662574  0.000280163
# 8  NaN          NaN         1
# 9   0.000000     0.000000   0.000513098
# 10  276.097794   16.676032  0.000280061
# 11  230.299534   0.977196   0.000455203
# 12  0.000000     0.000000   0.000316946
# 13  0.095705     0.394291   1.27472e-06
# 14 NaN          NaN         1
# 15  0.000000     0.000000   0.000513098
# 16  4.880930    -1.892809   0.000567837
# 17  0.000000     0.000000   0.000513098
# 18  18.427041   -4.514981   9.16047e-05
# 19  403.720739   20.142217  0.0437956
# 20 NaN          NaN         1
# 21 NaN          NaN         1
# 22  0.000000     0.000000   0.000513098
# 23 -0.857001    -0.164399   2.58767e-06
# 24  7578.888772  87.067024  0.0437962
# 25  219.150060   10.942357  3.82485e-06
# 26  7923.888777  89.026213  0.00028021
# 27 NaN          NaN         1
# 28  779.932035   27.962639  0.0437754
# 29 NaN          NaN         1
# 30  5.431192     2.099625   0.000617119
# 31 NaN          NaN         1
# 32  40.315123   -6.488081   0.00014529
# 33 NaN          NaN         1
# 34  1876.466873  43.340517  0.000159439

# %% [markdown]
# ### Features with missing values more than 20%

# %%
df_stats.loc[df_stats['perc_missing'] > 20][['feature','total_count', 'missing_val_count']]
# Out:
#                        feature total_count missing_val_count
# 0   HART_P1CP01_PI12026BT.MEAS  59611       59611
# 5   HART_P1CP01_PI12037BT.MEAS  59610       59610
# 6   HART_P1CP04_PX12003FB.MEAS  60042       60042
# 8   HART_U1CP03_PX12003BT.MEAS  51415       51415
# 14  HART_P1CP01_PI12046BT.MEAS  59617       59617
# 20  HART_P1CP04_FI12002BT.MEAS  59688       59688
# 21  12GTWY_E428_HAE12646FI.CIN  244         244
# 27  HART_P1CP04_HY12017FB.MEAS  59739       59739
# 29  HART_P1CP04_PI12003BT.MEAS  59737       59737
# 31  12GTWY_FG404_AI12554B.PNT   1           1
# 33  HART_P1CP04_LY12001FB.MEAS  59735       59735

# %%
# Features with more than 20% of missing values
np.unique(df_stats.loc[df_stats['perc_missing'] > 20]['feature'])
# Out:
# array(['12GTWY_E428_HAE12646FI.CIN', '12GTWY_FG404_AI12554B.PNT',
#        'HART_P1CP01_PI12026BT.MEAS', 'HART_P1CP01_PI12037BT.MEAS',
#        'HART_P1CP01_PI12046BT.MEAS', 'HART_P1CP04_FI12002BT.MEAS',
#        'HART_P1CP04_HY12017FB.MEAS', 'HART_P1CP04_LY12001FB.MEAS',
#        'HART_P1CP04_PI12003BT.MEAS', 'HART_P1CP04_PX12003FB.MEAS',
#        'HART_U1CP03_PX12003BT.MEAS'], dtype=object)

# %% [markdown]
# ### Remove features with missing values from stats dataframe

# %%
df_statscopy = df_stats.loc[df_stats['perc_missing'] < 20]

# %%
df_statscopy.head()
# Out:
#                       feature total_count missing_val_count    max_val  \
# 1  HART_P1CP04_PY12110FB.MEAS  1278552     628               102.1250
# 2  12P01BCP4_FC12847.SPT       270028      9                 100.0000
# 3  HART_P1CP04_PY12516FB.MEAS  356369      15                101.8125
# 4  12P01BCP4_PI12956.PNT       784473      1                 4447.3830
# 7  12GTWY_E101_FTE12404MS.CIN  71387       20                1.0000
#
#        min_val      variance         std     mean_val   median_val  \
# 1  0.207519     0.468946      0.684796    5.849385     5.871094
# 2  0.000000     257.737859    16.054216   8.058265     0.021973
# 3 -1.123047     370.892399    19.258567   23.751814    20.109380
# 4  3784.385000  21201.262845  145.606534  4117.185829  4100.478000
# 7  0.000000     0.002321      0.048173    0.002326     0.000000
#
#           kurt       skew perc_missing
# 1  2992.421913  34.975494  0.0491181
# 2  0.403597     1.518819   0.00333299
# 3 -0.541288     0.479581   0.00420912
# 4 -0.922735     0.084622   0.000127474
# 7  424.953874   20.662574  0.0280163

# %% [markdown]
# ### Plotting variances

# %%
def stats_plot(df_stats, stat_col, feature_col = 'feature'):
    
    df_variances = df_stats[[feature_col, stat_col]]
    df_variances = df_variances.loc[df_variances[stat_col] > 0.05]
    df_variances = df_variances.sort_values([stat_col], ascending=False)
    x = df_variances[feature_col]
    y = df_variances[stat_col]
    x_pos = np.arange(len(x))

    plt.bar(x_pos, y, align='center', alpha=0.5)
    plt.xticks(x_pos, x, rotation=45)
    plt.xlabel('Features')
    plt.ylabel(stat_col)
    plt.title(str(stat_col) + ' among different parameters')

    plt.show()

# %%
stats_plot(df_stats, 'variance', 'feature')

# %% [markdown]
# ### Remove features with substantial missing values

# %%
def remove_missing_features(df_features, value_col, max_missing_vals_pcnt):
    features = list(df_features.keys())
    for feature in features:
        df = df_features[feature]
        num_rows = len(df)
        count = df[value_col].count()
        percent_missing = (num_rows-count)/num_rows * 100
        # print(feature, percent_missing)
        if percent_missing > max_missing_vals_pcnt:
            del df_features[feature]
            # print('-------------------')
            
    return df_features

# %%
df_features = remove_missing_features(df_features, 'val', 20.0)

# %%
print('Number of features = ', len(list(df_features.keys())))
# Out:
# Number of features =  24

# %% [markdown]
# ### Data Imputation

# %%
def impute_data(df, impute_type):
    '''
    Filling up the missing values
    impute_type: takes one of the following values as strings
        zero - Replaces missing data with zero
        avg - takes the avg between last known value and next known value
        prev - fills the missing value with previous values
        next - fills the missing value with next values
        remove - removes the values with missing data
    '''
    
    if impute_type == 'zero':
        df = df.fillna(0)
    elif impute_type == 'prev':
        df = df.ffill()
    elif impute_type == 'next':
        df = df.bfill()
    elif impute_type == 'remove':
        df = df = df.dropna()
    elif impute_type == 'avg':
        df = df.fillna(df.mean())
    elif impute_type == 'avg_local':
        df = df.fillna(df.mean())
    
    return df

# %%
def impute_data_df(df_features, impute_type='prev', print_debug = False):
    
    df_features_temp = df_features
    
    for feature, df in df_features_temp.items():
        if print_debug:
            print('Processing feature', feature)
        df = impute_data(df, impute_type)
        df_features_temp[feature] = df
        
    return df_features_temp

# %%
df_features_imp = impute_data_df(df_features,  'prev', True)
# Out:
# Processing feature HART_P1CP04:PY12110FB.MEAS
# Processing feature 12P01BCP4:FC12847.SPT
# Processing feature HART_P1CP04:PY12516FB.MEAS
# Processing feature 12P01BCP4:PI12956.PNT
# Processing feature 12GTWY_E101:FTE12404MS.CIN
# Processing feature 12GTWY_FG404:AAH12554BSP.PNT
# Processing feature 12GTWY_E101:E12101FI.CIN
# Processing feature HART_P1CP04:PY12109FB.MEAS
# Processing feature 12GTWY_E101:FALE12404SP.PNT
# Processing feature 12P01BCP4:PI12955.PNT
# Processing feature 12GTWY_FG404:AAH12569SP.PNT
# Processing feature HART_U1CP03:PY24092FB.MEAS
# Processing feature 12GTWY_FG404:AAH12570SP.PNT
# Processing feature HART_P1CP04:FY12847FB.MEAS
# Processing feature 12GTWY_E101:ZAE12131FI.CIN
# Processing feature 12GTWY_FG404:AAH12555BSP.PNT
# Processing feature 12GTWY_E101:FIE12404.PNT
# Processing feature 12GTWY_E104:HAE12131FI.CIN
# Processing feature 12P01BCP4:FC12847.MEAS
# Processing feature 12GTWY_E104:E12104FI.CIN
# Processing feature 12GTWY_E101:FALE12404FI.CIN
# Processing feature HART_P1CP04:PY12003AFB.MEAS
# Processing feature 12P01BCP4:FC12847.OUT
# Processing feature 12P01BCP4:XI12597.CIN

# %% [markdown]
# ### Normalization

# %%
def normalize_values(df_features):
    
    for feature, df in df_features.items():
        df['scaled_val'] = df['val'].apply(lambda x:scale_val(x, min_val, max_val))
        df.sort_values(['datetime_gran'], inplace=True, ascending=True)
    
    return df_features

# %%
def scale_val(val, min_val, max_val):
    if val is not None:
        return (val-min_val)/(max_val-min_val + 1e-7)
    return None

# %% [markdown]
# ### Generate Master Dataframe for time

# %%
from datetime import datetime
def generate_master_df(granularity,
                       time_gran_col,
                       base_date,
                       end_date,
                       print_debug = False):
    '''
    Generates a master dataframe
    Dataframe will have an integer column that denotes x minutes have passed after the base_date
    granulaity - can take one of the following - 'sec' (seconds), min ' (minutes), 'hr' (hour), 
                'day' (day), 'mon' (month), 'yr' (year)
    base_date = date of reference since which the unit of time is computed
    '''
    
    if print_debug:
        print('Granularity is', granularity, '\tStart Date = ', base_date, '\tEnd Date = ', end_date)
            
    max_td = get_granulairty_function(granularity, end_date, base_date)
    
    df_master = pd.DataFrame(columns=[time_gran_col])    
    df_master[time_gran_col] = [i for i in range(1, max_td+1)]
    
    if print_debug:
        print('Shape of the master dataframe is ', df_master.shape, 'with columns ', df_master.columns.values)
    
    return df_master

# %% [markdown]
# ### Plotting comparitive graphs

# %%
def plot_all_features(df_features, 
                       time_granularity, 
                       base_date,
                       start_date,
                       stop_date,
                       feature_set = [],
                       normalization = True,
                       time_col = 'datetime',
                       time_gran_col = 'datetime_gran',
                       value_col = 'val',
                       scaled_value_col = 'scaled_val',
                       moving_avg_set = [],
                       print_debug = False):
    
    # Create Master Dataframe - has all values in the prescribed time granular levels
    max_mins = get_minutes_after(stop_date, base_date)
    min_mins = get_minutes_after(start_date, base_date)
    
    df_master = generate_master_df(time_granularity,  time_gran_col, start_date, stop_date)
    df_master_timetrunc = df_master.loc[(df_master[time_gran_col] < max_mins) & (df_master[time_gran_col] > min_mins)]
    
    colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
    idx = 0
    xlabel = 'Time'
    ylabel = 'Value'

    if len(feature_set) == 0:
        feature_set = list(df_features.keys())
            
    for feature in feature_set:
        
        df = df_features[feature]
                
        # Apply the granularity on the datetime column
        df[time_gran_col] = df[time_col].apply(lambda x:get_granulairty_function(time_granularity, x, base_date))
        
        # Drop NULL values and DUPLICATES
        df = df[df[value_col].notnull()] # Select Non-null values
        df = df.drop_duplicates(subset=time_gran_col, keep="last") # Drop any duplicates
                
        # If NORMALIZATION is enabled
        if normalization:
            min_val = df[value_col].min()
            max_val = df[value_col].max()
            
            df[scaled_value_col] = df[value_col].apply(lambda x:scale_val(x, min_val, max_val))
            df.sort_values([time_gran_col], inplace=True, ascending=True)
            
            value_col = scaled_value_col
            ylabel = 'Scaled Value'
        
        # Merge with the master dataframe - to get all the values at a granular level
        df = pd.merge(df_master_timetrunc, df[[time_col, time_gran_col, value_col]], 
                          how='left', left_on=[time_gran_col], right_on=[time_gran_col])
        df.rename(columns={value_col:feature}, inplace=True)
        df = df.ffill()
        df = df.fillna(0.0)
        
        df[time_col] = df[time_gran_col].apply(lambda x: get_time_from_minutes(x, base_date))
                
        # Plotting the figure
        plt.figure()
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.title('Comparison of feature - ' + feature)

        x = df[time_col]
        y = df[feature]
        plt.plot(x, y, linewidth=1.0, color=colors[idx % len(colors)], alpha=0.5, label='per '+time_granularity+' value')
        
        # Plotting moving averages        
        mov_avg_idx = 1
        for mov_avg in moving_avg_set:
            new_label = 'mov_avg_'+str(mov_avg)
            df[new_label] = df[feature].rolling(mov_avg).mean()
            x = df[time_col]
            y = df[new_label]    
            plt.plot(x, y, linewidth=1.0, color=colors[(idx + mov_avg_idx) % len(colors)], alpha=0.5, label=new_label)
            mov_avg_idx += 1

        plt.legend(loc='lower right')

        idx += 1

# %% [markdown]
# ## Running Time Varying Graphs without Normalization

# %%
fmt = '%Y-%m-%d %H:%M:%S'
base_date = datetime.strptime('2016-01-01 00:00:01', fmt)
start_date = datetime.strptime('2016-06-16 00:00:01', fmt)
stop_date = datetime.strptime('2018-10-01 00:00:01', fmt)

plot_all_features(df_features=df_features, 
                time_granularity='min', 
                base_date=base_date, 
                start_date=start_date, 
                stop_date=stop_date, 
                #feature_set = ['HART_U1CP03:PY24092FB.MEAS'], 
                feature_set = [],
                normalization=False, 
                time_col = 'datetime',
                time_gran_col = 'datetime_gran',
                value_col = 'val',
                scaled_value_col = 'scaled_val',
                moving_avg_set = [1440, 21600, 43200],
                print_debug = False)
# Out:
# /Users/talat/anaconda3/envs/shell/lib/python3.6/site-packages/matplotlib/pyplot.py:513: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# ## Running Time Varying Graphs with Normalization

# %%
fmt = '%Y-%m-%d %H:%M:%S'
base_date = datetime.strptime('2016-01-01 00:00:01', fmt)
start_date = datetime.strptime('2016-06-16 00:00:01', fmt)
stop_date = datetime.strptime('2018-10-01 00:00:01', fmt)

plot_all_features(df_features=df_features, 
                time_granularity='min', 
                base_date=base_date, 
                start_date=start_date, 
                stop_date=stop_date, 
                #feature_set = ['HART_U1CP03:PY24092FB.MEAS'], 
                feature_set = [],
                normalization=True, 
                time_col = 'datetime',
                time_gran_col = 'datetime_gran',
                value_col = 'val',
                scaled_value_col = 'scaled_val',
                moving_avg_set = [1440, 21600, 43200],
                print_debug = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/shell/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'scaled_val'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-406-a3a904009fea> in <module>
#      17                 scaled_value_col = 'scaled_val',
#      18                 moving_avg_set = [1440, 21600, 43200],
# ---> 19                 print_debug = False)
#
# <ipython-input-402-c9832def45bc> in plot_all_features(df_features, time_granularity, base_date, start_date, stop_date, feature_set, normalization, time_col, time_gran_col, value_col, scaled_value_col, moving_avg_set, print_debug)
#      36
#      37         # Drop NULL values and DUPLICATES
# ---> 38         df = df[df[value_col].notnull()] # Select Non-null values
#      39         df = df.drop_duplicates(subset=time_gran_col, keep="last") # Drop any duplicates
#      40
#
# ~/anaconda3/envs/shell/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/envs/shell/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/envs/shell/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/envs/shell/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/envs/shell/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'scaled_val'
