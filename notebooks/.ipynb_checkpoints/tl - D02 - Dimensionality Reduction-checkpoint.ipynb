# %% [markdown]
# ## Data Preprocessing

# %%
# Data = CMAPSSData
# Source = https://ti.arc.nasa.gov/tech/dash/groups/pcoe/prognostic-data-repository/
# Dataset = Turbofan Engine Degradation Simulation Data Set

# %%
# Data to be used - Train and Test data for 1

# %%
import pandas as pd
import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt

# %% [markdown]
# ### Notebook options

# %%
pd.set_option('display.max_colwidth', -1) # Column width
plt.rcParams['figure.figsize'] = [21, 10] # Size of the plots

# %% [markdown]
# ### Data Directories

# %%
INPUT_DIR = '../data/raw/CMAPSSData/'
INT_DIR = '../data/interim/'
OUTPUT_DIR = '../data/interim/'

# %% [markdown]
# ### Read the input data

# %%
input_file = OUTPUT_DIR + 'train_case4.csv'
df_data = pd.read_csv(input_file)

# %% [markdown]
# ### Data Imputation

# %%
# Not required as there are no missing values
# Remove the additional columns

# %% [markdown]
# ### Data Standardization

# %%
df_data.head()
# Out:
#    unit  time_cycles  setting1  setting2  setting3  meas01  meas02   meas03  \
# 0  1     1           -0.0007   -0.0004    100.0     518.67  641.82  1589.70
# 1  1     2            0.0019   -0.0003    100.0     518.67  642.15  1591.82
# 2  1     3           -0.0043    0.0003    100.0     518.67  642.35  1587.99
# 3  1     4            0.0007    0.0000    100.0     518.67  642.35  1582.79
# 4  1     5           -0.0019   -0.0002    100.0     518.67  642.37  1582.85
#
#     meas04  meas05   ...     meas12   meas13   meas14  meas15  meas16  meas17  \
# 0  1400.60  14.62    ...     521.66  2388.02  8138.62  8.4195  0.03    392
# 1  1403.14  14.62    ...     522.28  2388.07  8131.49  8.4318  0.03    392
# 2  1404.20  14.62    ...     522.42  2388.03  8133.23  8.4178  0.03    390
# 3  1401.87  14.62    ...     522.86  2388.08  8133.83  8.3682  0.03    392
# 4  1406.22  14.62    ...     522.19  2388.04  8133.80  8.4294  0.03    393
#
#    meas18  meas19  meas20   meas21
# 0  2388    100.0   39.06   23.4190
# 1  2388    100.0   39.00   23.4236
# 2  2388    100.0   38.95   23.3442
# 3  2388    100.0   38.88   23.3739
# 4  2388    100.0   38.90   23.4044
#
# [5 rows x 26 columns]

# %%
from sklearn.preprocessing import StandardScaler

exclude_cols = ['unit', 'time_cycles']

df_pca = df_raw.copy()
features = [x for x in df_pca.columns.values if x not in set(exclude_cols)]
print(features)

# Separating out the features
x = df_pca.loc[:, features].values

# Standardizing the features
x = StandardScaler().fit_transform(x)
# Out:
# ['setting1', 'setting2', 'setting3', 'meas01', 'meas02', 'meas03', 'meas04', 'meas05', 'meas06', 'meas07', 'meas08', 'meas09', 'meas10', 'meas11', 'meas12', 'meas13', 'meas14', 'meas15', 'meas16', 'meas17', 'meas18', 'meas19', 'meas20', 'meas21']

# %%
df_pca.head()
# Out:
#    unit  time_cycles  setting1  setting2  setting3  meas01  meas02   meas03  \
# 0  1     1           -0.0007   -0.0004    100.0     518.67  641.82  1589.70
# 1  1     2            0.0019   -0.0003    100.0     518.67  642.15  1591.82
# 2  1     3           -0.0043    0.0003    100.0     518.67  642.35  1587.99
# 3  1     4            0.0007    0.0000    100.0     518.67  642.35  1582.79
# 4  1     5           -0.0019   -0.0002    100.0     518.67  642.37  1582.85
#
#     meas04  meas05   ...     meas12   meas13   meas14  meas15  meas16  meas17  \
# 0  1400.60  14.62    ...     521.66  2388.02  8138.62  8.4195  0.03    392
# 1  1403.14  14.62    ...     522.28  2388.07  8131.49  8.4318  0.03    392
# 2  1404.20  14.62    ...     522.42  2388.03  8133.23  8.4178  0.03    390
# 3  1401.87  14.62    ...     522.86  2388.08  8133.83  8.3682  0.03    392
# 4  1406.22  14.62    ...     522.19  2388.04  8133.80  8.4294  0.03    393
#
#    meas18  meas19  meas20   meas21
# 0  2388    100.0   39.06   23.4190
# 1  2388    100.0   39.00   23.4236
# 2  2388    100.0   38.95   23.3442
# 3  2388    100.0   38.88   23.3739
# 4  2388    100.0   38.90   23.4044
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Writing standardized to file

# %%
std_file = OUTPUT_DIR + 'train_case1_std.pkl'
with open(std_file, 'wb') as f:
    pkl.dump(x, f, protocol=pkl.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Reading back from pickle

# %%
with open(std_file, 'rb') as f:
    x = pkl.load(f)

# %% [markdown]
# ### PCA Projection

# %%
from sklearn.decomposition import PCA
num_components = len(df_pca.columns.values) - 2
pca = PCA(n_components=num_components)
principalComponents = pca.fit_transform(x)

# %%
sum = 0
idx = 1
print('| Component | Individual Contribution | Cumulative |')
print('| -- | -- | -- |')
for val in pca.explained_variance_ratio_:
    sum += val
    print('| Component ' + str(idx), end = ' | ')
    print("{:10.2f}".format(val*100), end=' | ')
    print("{:10.2f}".format(sum*100), end= ' |\n')
    idx += 1
# Out:
# | Component | Individual Contribution | Cumulative |
# | -- | -- | -- |
# | Component 1 |      53.10 |      53.10 |
# | Component 2 |      12.35 |      65.44 |
# | Component 3 |       5.95 |      71.40 |
# | Component 4 |       5.84 |      77.23 |
# | Component 5 |       5.66 |      82.89 |
# | Component 6 |       2.43 |      85.33 |
# | Component 7 |       2.17 |      87.49 |
# | Component 8 |       2.05 |      89.54 |
# | Component 9 |       1.80 |      91.34 |
# | Component 10 |       1.70 |      93.05 |
# | Component 11 |       1.50 |      94.55 |
# | Component 12 |       1.21 |      95.76 |
# | Component 13 |       1.15 |      96.91 |
# | Component 14 |       1.04 |      97.95 |
# | Component 15 |       1.01 |      98.97 |
# | Component 16 |       0.86 |      99.83 |
# | Component 17 |       0.17 |     100.00 |
# | Component 18 |       0.00 |     100.00 |
# | Component 19 |       0.00 |     100.00 |
# | Component 20 |       0.00 |     100.00 |
# | Component 21 |       0.00 |     100.00 |
# | Component 22 |       0.00 |     100.00 |
# | Component 23 |       0.00 |     100.00 |
# | Component 24 |       0.00 |     100.00 |

# %% [markdown]
# ### Create a principal dataframe with all the components

# %%
pca_col_list = ['pc'+str(i+1) for i in range(num_components)]
principalDf = pd.DataFrame(data = principalComponents, columns = pca_col_list)

# %% [markdown]
# ### Find the influence of features in each component

# %%
df_infl = pd.DataFrame(pca.components_,columns=features,index=pca_col_list)

# %%
df_infl
# Out:
#           setting1      setting2      setting3        meas01        meas02  \
# pc1   2.381516e-03  5.228829e-03 -2.220446e-16  1.387779e-17  2.727388e-01
# pc2  -5.823868e-03 -1.383703e-02  1.387779e-17  2.220446e-16  1.832876e-02
# pc3   6.707551e-01  7.283068e-01  0.000000e+00  0.000000e+00 -4.185765e-03
# pc2  -0.000000e+00  7.809534e-02 -0.000000e+00 -0.000000e+00 -1.900673e-02
# pc3   0.000000e+00 -1.378696e-03  0.000000e+00  0.000000e+00  3.505066e-03
# pc4  -0.000000e+00 -3.763976e-04 -0.000000e+00 -0.000000e+00 -6.757683e-03
# pc5  -0.000000e+00  1.330539e-02 -0.000000e+00 -0.000000e+00 -1.316073e-02
# pc6  -0.000000e+00 -2.528993e-01 -0.000000e+00 -0.000000e+00  9.936542e-02
# pc7   0.000000e+00  8.126799e-01  0.000000e+00  0.000000e+00  1.115777e-01
# pc8   0.000000e+00  3.957538e-01  0.000000e+00  0.000000e+00  4.067382e-01
# pc9   0.000000e+00 -6.967010e-02  0.000000e+00  0.000000e+00  5.829516e-01
# pc10  0.000000e+00 -1.172983e-01  0.000000e+00  0.000000e+00  5.406478e-01
# pc11 -0.000000e+00 -1.446660e-01 -0.000000e+00 -0.000000e+00  3.096855e-01
# pc12  0.000000e+00 -1.548891e-03  0.000000e+00  0.000000e+00  1.938349e-02
# pc13 -0.000000e+00 -2.688706e-02 -0.000000e+00 -0.000000e+00 -2.250517e-02
# pc14 -0.000000e+00  1.078250e-02 -0.000000e+00 -0.000000e+00 -2.768566e-02
# pc15 -0.000000e+00  4.395896e-03 -0.000000e+00 -0.000000e+00 -1.970317e-02
# pc16 -0.000000e+00  8.336217e-03 -0.000000e+00 -0.000000e+00 -4.385516e-02
# pc17 -0.000000e+00  3.236973e-03 -0.000000e+00 -0.000000e+00 -3.410984e-03
# pc18 -0.000000e+00  2.311906e-17 -0.000000e+00 -0.000000e+00 -7.154296e-17
# pc19  9.020562e-17 -1.196755e-17 -0.000000e+00 -0.000000e+00  3.170560e-18
# pc20 -1.110223e-16 -1.271526e-17  0.000000e+00  0.000000e+00  4.154983e-17
# pc21 -1.110223e-16  8.790684e-17 -0.000000e+00 -0.000000e+00 -6.510232e-17
# pc22  9.958005e-01 -3.652775e-33  9.154957e-02 -2.220446e-16 -1.027895e-32
# pc23 -9.154957e-02 -6.292975e-36  9.958005e-01 -6.938894e-16 -2.951328e-34
# pc24 -1.632990e-16  5.444177e-49  6.806381e-16  1.000000e+00  5.458985e-48
#
#             meas21
# pc1  -2.831342e-01
# pc2  -2.354280e-02
# pc3  -1.129396e-03
# pc4  -2.033935e-02
# pc5  -1.580802e-02
# pc6   6.247518e-02
# pc7   6.106952e-02
# pc8   2.022768e-01
# pc9  -7.955712e-01
# pc10  3.212577e-01
# pc11  3.578948e-01
# pc12  2.023473e-02
# pc13  2.616887e-02
# pc14 -5.225089e-02
# pc15 -3.029301e-02
# pc16 -3.175039e-02
# pc17 -9.406040e-03
# pc18  7.551602e-17
# pc19  4.906510e-17
# pc20  2.866638e-19
# pc21  5.668049e-17
# pc22 -1.181296e-32
# pc23  9.737951e-34
# pc24  1.298520e-48
#
# [24 rows x 24 columns]

# %% [markdown]
# ### Write the principal components to file

# %%
principalDf_file = INT_DIR + 'components_' + str(num_components) + '.csv'
with open(principalDf_file, 'wb') as f:
    principalDf.to_csv(principalDf_file, header=True, index=False)

print('Writing to ', principalDf_file)
# Out:
# Writing to  ../data/interim/components_24.csv
