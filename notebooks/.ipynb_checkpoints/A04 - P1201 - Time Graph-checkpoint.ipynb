# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
import os
import ntpath
import pickle as pkl
import xlrd
import time
import string
import math

from os import listdir
from os.path import isfile, join

# %% [markdown]
# ### Notebook options

# %%
pd.set_option('display.max_colwidth', -1) # Column width
plt.rcParams['figure.figsize'] = [15, 10] # Size of the plots

# %% [markdown]
# ### General Assumptions

# %%
time_col = 'datetime'
time_gran_col = 'datetime_gran'
value_col = 'val'
scaled_value_col = 'scaled_val'
time_granularity = 'min'

# %%
fmt = '%Y-%m-%d %H:%M:%S'
base_date = datetime.strptime('2016-01-01 00:00:01', fmt)
start_date = datetime.strptime('2016-01-01 00:00:01', fmt)
stop_date = datetime.strptime('2019-01-01 00:00:01', fmt)

# %% [markdown]
# ### Data Directories

# %%
RAW_DATA_DIR = '../data/raw/P1201/'
PROC_DATA_DIR = '../data/processed/P1201/'
INT_DATA_DIR = '../data/interim/P1201/'

# %% [markdown]
# ### Functions

# %%
def get_seconds_after(current_date, base_date):
    
    base_ts = time.mktime(base_date.timetuple()) # Converting to Unix timestamp
    current_ts = time.mktime(current_date.timetuple())
    time_diff = round((current_ts - base_ts))
    
    return time_diff

# %%
def get_minutes_after(current_date, base_date):
        
    base_ts = time.mktime(base_date.timetuple()) # Converting to Unix timestamp
    current_ts = time.mktime(current_date.timetuple())
    time_diff = round((current_ts - base_ts) / 60.0) + 1
    
    return time_diff

# %%
def get_hours_after(current_date, base_date):
    
    base_ts = time.mktime(base_date.timetuple()) # Converting to Unix timestamp
    current_ts = time.mktime(current_date.timetuple())
    time_diff = round((current_ts - base_ts) / 60.0 / 60.0) + 1
    
    return time_diff

# %%
def get_days_after(current_date, base_date):
    
    base_ts = time.mktime(base_date.timetuple()) # Converting to Unix timestamp
    current_ts = time.mktime(current_date.timetuple())
    time_diff = round((current_ts - base_ts) / 60.0 / 60.0 / 24) + 1
    
    return time_diff

# %%
def get_months_after(current_date, base_date):    
    time_diff = ((current_date.year - base_date.year) * 12) + current_date.month - base_date.month + 1    
    return time_diff

# %%
def get_years_after(current_date, base_date):    
    time_diff = (current_date.year - base_date.year) + 1 
    return time_diff

# %%
def get_time_from_minutes(time_in_mins, base_date):    
    new_date = base_date + timedelta(minutes = time_in_mins)        
    return new_date

# %% [markdown]
# ### Reading Data

# %%
def read_data(input_path, print_debug = False):
    
    df_features = {}
    
    if os.path.isdir(input_path):
        input_files = [f for f in listdir(input_path) if (isfile(join(input_path, f))) and ((f.endswith('.pkl')) or (f.endswith('.csv')))]
    elif os.path.isfile(input_path):
        input_files = input_path
    
    if print_debug:
        print('Number of files found in %s is %d ' % (input_path, len(input_files)))
    
    for input_file in input_files:
        
        feature,_ = os.path.splitext(input_file)
        input_file = input_path + input_file  
        
        with open(input_file, 'rb') as f:
            df = pkl.load(f)
            df_features[feature] = df
    
    if print_debug:
        print('Number of features extracted from %d files is %d ' % (len(input_files), len(df_features)))
    
    return df_features

# %% [markdown]
# ### Reading Normalized Data

# %%
input_dir = INT_DATA_DIR + 'normalized/'
df_features_norm = read_data(input_dir, True)
# Out:
# Number of files found in ../data/interim/P1201/normalized/ is 24
# Number of features extracted from 24 files is 24

# %% [markdown]
# ### Reading Non-Normalized Data

# %%
input_dir = INT_DATA_DIR + 'imputed/'
df_features_imp = read_data(input_dir, True)
# Out:
# Number of files found in ../data/interim/P1201/imputed/ is 24
# Number of features extracted from 24 files is 24

# %%
print(df_features_norm['HART_P1CP04:PY12109FB.MEAS'].head())
print(df_features_norm['12P01BCP4:FC12847.MEAS'].head())
# Out:
#         datetime_gran        val  scaled_val
# 429673  429674         9.801563   0.150296
# 429674  429675         10.228515  0.161338
# 429675  429676         10.230542  0.161390
# 429676  429677         10.232569  0.161442
# 429677  429678         10.234595  0.161495
#          datetime_gran       val  scaled_val
# 1052640  1052641        0.029297  0.000378
# 1052641  1052642        0.024414  0.000338
# 1052642  1052643        0.026855  0.000358
# 1052643  1052644        0.031738  0.000398
# 1052644  1052645        0.021973  0.000318

# %%
print(df_features_imp['HART_P1CP04:PY12109FB.MEAS'].head())
print(df_features_imp['12P01BCP4:FC12847.MEAS'].head())
# Out:
#         datetime_gran        val
# 429673  429674         9.801563
# 429674  429675         10.228515
# 429675  429676         10.230542
# 429676  429677         10.232569
# 429677  429678         10.234595
#          datetime_gran       val
# 1052640  1052641        0.029297
# 1052641  1052642        0.024414
# 1052642  1052643        0.026855
# 1052643  1052644        0.031738
# 1052644  1052645        0.021973

# %% [markdown]
# ### Getting date from datetime_gran

# %%
for feature, df in df_features_norm.items():
    df[time_col] = df[time_gran_col].apply(lambda x: get_time_from_minutes(x, base_date))

# %%
for feature, df in df_features_imp.items():
    df[time_col] = df[time_gran_col].apply(lambda x: get_time_from_minutes(x, base_date))

# %% [markdown]
# ### Debug

# %%
df = df_features_norm['HART_P1CP04:PY12109FB.MEAS']
print(df.head())
print(df.tail())
# Out:
#         datetime_gran        val  scaled_val            datetime
# 429673  429674         9.801563   0.150296   2016-10-25 09:14:01
# 429674  429675         10.228515  0.161338   2016-10-25 09:15:01
# 429675  429676         10.230542  0.161390   2016-10-25 09:16:01
# 429676  429677         10.232569  0.161442   2016-10-25 09:17:01
# 429677  429678         10.234595  0.161495   2016-10-25 09:18:01
#          datetime_gran       val  scaled_val            datetime
# 1578236  1578237        10.20313  0.160681   2018-12-31 23:57:01
# 1578237  1578238        10.20313  0.160681   2018-12-31 23:58:01
# 1578238  1578239        10.20313  0.160681   2018-12-31 23:59:01
# 1578239  1578240        10.20313  0.160681   2019-01-01 00:00:01
# 1578240  1578241        10.20313  0.160681   2019-01-01 00:01:01

# %% [markdown]
# ### Plotting comparitive graphs

# %%
feature_set = list(df_features_imp.keys())
# feature_set = usable_features

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
xlabel = 'Time'
ylabel = 'Value'

if len(feature_set) == 0:
    feature_set = list(df_features.keys())

total_plots = len(feature_set)
cols_plot = 3
rows_plot = math.ceil(total_plots/cols_plot)

plt.rcParams['figure.figsize'] = [cols_plot * 10, rows_plot * 7] # Size of the plots        
plt.figure()

idx = 0
for feature in feature_set:
    
    df = df_features_imp[feature]
    
    plt.subplot(rows_plot, cols_plot, idx+1)
    # plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45)
    plt.title('Feature - ' + feature)
    
    x = df[time_col]
    y = df[value_col]
    plt.plot(x, y, linewidth=1.0, color=colors[idx % len(colors)], alpha=0.5, label='per '+time_granularity+' value')
        
    plt.legend(loc='upper left')

    idx += 1

# %%
feature_set = list(df_features_imp.keys())
# feature_set = usable_features

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
xlabel = 'Time'
ylabel = 'Value'

if len(feature_set) == 0:
    feature_set = list(df_features.keys())

total_plots = len(feature_set)
cols_plot = 3
rows_plot = math.ceil(total_plots/cols_plot)

plt.rcParams['figure.figsize'] = [cols_plot * 10, rows_plot * 7] # Size of the plots        
plt.figure()

idx = 0
for feature in feature_set:
    
    # print('Feature ', feature)
    
    df = df_features_norm[feature]
    
    plt.subplot(rows_plot, cols_plot, idx+1)
    # plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45)
    plt.title('Feature - ' + feature)
    
    x = df[time_col]
    y = df[scaled_value_col]
    plt.plot(x, y, linewidth=1.0, color=colors[idx % len(colors)], alpha=0.5, label='per '+time_granularity+' value')
        
    plt.legend(loc='upper left')

    idx += 1

# %% [markdown]
# ### Selected Features

# %%
df_features_imp.keys()
# Out:
# dict_keys(['HART_P1CP04:PY12003AFB.MEAS', '12GTWY_E101:FIE12404.PNT', '12GTWY_E104:HAE12131FI.CIN', '12GTWY_E104:E12104FI.CIN', '12P01BCP4:PI12956.PNT', '12P01BCP4:FC12847.MEAS', '12P01BCP4:FC12847.SPT', '12GTWY_FG404:AAH12555BSP.PNT', '12GTWY_E101:FALE12404FI.CIN', '12P01BCP4:PI12955.PNT', 'HART_P1CP04:PY12110FB.MEAS', 'HART_P1CP04:PY12516FB.MEAS', '12GTWY_E101:FTE12404MS.CIN', 'HART_P1CP04:PY12109FB.MEAS', '12GTWY_E101:E12101FI.CIN', '12GTWY_FG404:AAH12569SP.PNT', '12P01BCP4:XI12597.CIN', 'HART_U1CP03:PY24092FB.MEAS', '12GTWY_FG404:AAH12570SP.PNT', '12P01BCP4:FC12847.OUT', 'HART_P1CP04:FY12847FB.MEAS', '12GTWY_FG404:AAH12554BSP.PNT', '12GTWY_E101:ZAE12131FI.CIN', '12GTWY_E101:FALE12404SP.PNT'])

# %%
# Removing the following 
# a) All .OUT
# b) All .CIN
# c) All .SPT
# d) .PNTs that have a flat line in graph
usable_features = [
    'HART_P1CP04:PY12003AFB.MEAS', 
    '12GTWY_E101:FIE12404.PNT', 
    '12P01BCP4:PI12956.PNT', 
    '12P01BCP4:FC12847.MEAS', 
    '12P01BCP4:PI12955.PNT', 
    'HART_P1CP04:PY12110FB.MEAS', 
    'HART_P1CP04:PY12516FB.MEAS', 
    'HART_P1CP04:PY12109FB.MEAS', 
    'HART_U1CP03:PY24092FB.MEAS', 
    'HART_P1CP04:FY12847FB.MEAS'
]

print('Number of usable features = ', len(usable_features))
# Out:
# Number of usable features =  10

# %% [markdown]
# ### Non-normalized for selected features

# %%
# feature_set = list(df_features.keys())
feature_set = usable_features

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
xlabel = 'Time'
ylabel = 'Value'

if len(feature_set) == 0:
    feature_set = list(df_features.keys())

total_plots = len(feature_set)
cols_plot = 3
rows_plot = math.ceil(total_plots/cols_plot)

plt.rcParams['figure.figsize'] = [cols_plot * 10, rows_plot * 7] # Size of the plots        
plt.figure()

idx = 0
for feature in feature_set:
    
    df = df_features_imp[feature]
    
    plt.subplot(rows_plot, cols_plot, idx+1)
    # plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45)
    plt.title('Feature - ' + feature)
    
    x = df[time_col]
    y = df[value_col]
    plt.plot(x, y, linewidth=1.0, color=colors[idx % len(colors)], alpha=0.5, label='per '+time_granularity+' value')
        
    plt.legend(loc='upper left')

    idx += 1

# %% [markdown]
# ### Normalized for selected features

# %%
# feature_set = list(df_features.keys())
feature_set = usable_features

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
xlabel = 'Time'
ylabel = 'Value'

if len(feature_set) == 0:
    feature_set = list(df_features.keys())

total_plots = len(feature_set)
cols_plot = 3
rows_plot = math.ceil(total_plots/cols_plot)

plt.rcParams['figure.figsize'] = [cols_plot * 10, rows_plot * 7] # Size of the plots        
plt.figure()

idx = 0
for feature in feature_set:
    
    # print('Feature ', feature)
    
    df = df_features_norm[feature]
    
    plt.subplot(rows_plot, cols_plot, idx+1)
    # plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45)
    plt.title('Feature - ' + feature)
    
    x = df[time_col]
    y = df[scaled_value_col]
    plt.plot(x, y, linewidth=1.0, color=colors[idx % len(colors)], alpha=0.5, label='per '+time_granularity+' value')
        
    plt.legend(loc='upper left')

    idx += 1
