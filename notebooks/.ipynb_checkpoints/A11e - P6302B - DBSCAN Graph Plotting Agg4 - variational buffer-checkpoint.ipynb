# %% [markdown]
# ## Using DBSCAN directly on the features

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
import os
import ntpath
import pickle as pkl
import time
import string
import math

from os import listdir
from os.path import isfile, join
from collections import Counter

# %% [markdown]
# ### Notebook options

# %%
pd.set_option('display.max_colwidth', -1) # Column width
plt.rcParams['figure.figsize'] = [15, 10] # Size of the plots

# %% [markdown]
# ### General Assumptions

# %%
time_col = 'datetime'
time_gran_col = 'datetime_gran'
value_col = 'val'
scaled_value_col = 'scaled_val'
time_granularity = 'min'

# %%
fmt = '%Y-%m-%d %H:%M:%S'
base_date = datetime.strptime('2014-01-01 00:00:01', fmt)
start_date = datetime.strptime('2014-01-01 00:00:01', fmt)
stop_date = datetime.strptime('2019-01-01 00:00:01', fmt)

# %% [markdown]
# ### Data Directories

# %%
pid = 1203

# %%
pump = 'P6302B'
RAW_DATA_DIR = '../data/raw/'+pump+'/'
PROC_DATA_DIR = '../data/processed/'+pump+'/'
INT_DATA_DIR = '../data/interim/'+pump+'/'
RESULTS_DIR = '../data/results/'+pump+'/'
LABELS_DIR = RESULTS_DIR + 'labels/' + str(pid) + '/'
labels_file = LABELS_DIR + 'complete_labels.pkl'

# %% [markdown]
# ### Load the labels

# %%
print(labels_file)
with open(labels_file, 'rb') as fp:
    labels = pkl.load(fp)
# Out:
# ../data/results/P6302B/labels/1203/complete_labels.pkl

# %%
type(labels)
# Out:
# list

# %% [markdown]
# ### Read the data file of X used as feature file

# %%
agg_val = 1
eps = 2.5
mpts = 3
before_stop_buffer = 2
after_start_buffer = 10

agg_col = 'agg' + str(agg_val)

# %%
input_file = INT_DATA_DIR + 'agg_runstat/' + 'agg'+str(agg_val)+'_before'+str(before_stop_buffer)  + '_after' +str(after_start_buffer)+ '.csv'
with open(input_file, 'rb') as f:
    df_agg = pd.read_csv(input_file)

# %%
df_agg.head()
# Out:
#     agg1  PC63112E.AV  05GTWY_BN06:XT61B19.PNT  TT61B06.PV  FT61A99.PV  \
# 0  29680  0.054785     0.731538                 0.730450    0.874481
# 1  29691  0.054785     0.839511                 0.733860    0.874150
# 2  29692  0.054785     0.813155                 0.733576    0.874481
# 3  29693  0.054785     0.821657                 0.733292    0.875802
# 4  29694  0.054785     0.776598                 0.733008    0.874481
#
#    PT63112.PV  05GTWY_BN06:XT61B18.PNT  TT61B05.PV  05GTWY_BN06:XT61B17.PNT  \
# 0 -0.558801    0.183875                 0.592684    0.571180
# 1  0.616395    0.271142                 0.582961    0.545826
# 2  0.608037    0.197154                 0.584581    0.424483
# 3  0.599680    0.384969                 0.586201    0.609817
# 4  0.673095    0.317938                 0.582960    0.756514
#
#    05GTWY_BN06:XT61B12.PNT     ...      TT61B01.PV  05GTWY_BN06:XT61B13.PNT  \
# 0  0.680249                    ...      1.899783    0.869104
# 1  0.656337                    ...      1.899783    0.879144
# 2  0.812336                    ...      1.914781    0.879144
# 3  0.800949                    ...      1.929778    0.974982
# 4  0.619899                    ...      1.912907    0.907438
#
#      F61221  TT61B03.PV  TC63109E.AV  PT63103.PV  PT61A98.PV  \
# 0  0.814552  1.384925    0.586338     0.297278    0.825295
# 1  0.813250  1.387541    0.586338     0.684954    0.823961
# 2  0.813250  1.395389    0.586338     0.579520    0.817293
# 3  0.813250  1.403238    0.586338     0.474085    0.810624
# 4  0.813250  1.394082    0.586338     0.586616    0.830058
#
#    05GTWY_BN06:XT61B20.PNT  PT61B00.PV  TT61B04.PV
# 0  0.870151                 0.900861    1.021560
# 1  0.987437                 0.991854    1.033388
# 2  1.122158                 0.979575    1.037331
# 3  1.054797                 0.967296    1.041274
# 4  1.054797                 0.918651    1.031417
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Combine the features & labels

# %%
df_agg['labels'] = labels

# %%
df_labels = df_agg

# %%
df_labels.head()
# Out:
#     agg1  PC63112E.AV  05GTWY_BN06:XT61B19.PNT  TT61B06.PV  FT61A99.PV  \
# 0  29680  0.054785     0.731538                 0.730450    0.874481
# 1  29691  0.054785     0.839511                 0.733860    0.874150
# 2  29692  0.054785     0.813155                 0.733576    0.874481
# 3  29693  0.054785     0.821657                 0.733292    0.875802
# 4  29694  0.054785     0.776598                 0.733008    0.874481
#
#    PT63112.PV  05GTWY_BN06:XT61B18.PNT  TT61B05.PV  05GTWY_BN06:XT61B17.PNT  \
# 0 -0.558801    0.183875                 0.592684    0.571180
# 1  0.616395    0.271142                 0.582961    0.545826
# 2  0.608037    0.197154                 0.584581    0.424483
# 3  0.599680    0.384969                 0.586201    0.609817
# 4  0.673095    0.317938                 0.582960    0.756514
#
#    05GTWY_BN06:XT61B12.PNT   ...    05GTWY_BN06:XT61B13.PNT    F61221  \
# 0  0.680249                  ...    0.869104                 0.814552
# 1  0.656337                  ...    0.879144                 0.813250
# 2  0.812336                  ...    0.879144                 0.813250
# 3  0.800949                  ...    0.974982                 0.813250
# 4  0.619899                  ...    0.907438                 0.813250
#
#    TT61B03.PV  TC63109E.AV  PT63103.PV  PT61A98.PV  05GTWY_BN06:XT61B20.PNT  \
# 0  1.384925    0.586338     0.297278    0.825295    0.870151
# 1  1.387541    0.586338     0.684954    0.823961    0.987437
# 2  1.395389    0.586338     0.579520    0.817293    1.122158
# 3  1.403238    0.586338     0.474085    0.810624    1.054797
# 4  1.394082    0.586338     0.586616    0.830058    1.054797
#
#    PT61B00.PV  TT61B04.PV  labels
# 0  0.900861    1.021560    1
# 1  0.991854    1.033388    1
# 2  0.979575    1.037331    1
# 3  0.967296    1.041274    1
# 4  0.918651    1.031417    1
#
# [5 rows x 27 columns]

# %%
print(df_labels.shape)
# Out:
# (1587453, 27)

# %% [markdown]
# ### Get the timestamps

# %%
from utils import get_time_from_minutes
df_labels[time_col] = df_labels[agg_col].apply(lambda x: get_time_from_minutes(x, base_date))

df_labels.head()
# Out:
# 22GTWY_E403:FALE22E23SP.PNT Error 2017-12-30 23:48:05
#     agg1  PC63112E.AV  05GTWY_BN06:XT61B19.PNT  TT61B06.PV  FT61A99.PV  \
# 0  29680  0.054785     0.731538                 0.730450    0.874481
# 1  29691  0.054785     0.839511                 0.733860    0.874150
# 2  29692  0.054785     0.813155                 0.733576    0.874481
# 3  29693  0.054785     0.821657                 0.733292    0.875802
# 4  29694  0.054785     0.776598                 0.733008    0.874481
#
#    PT63112.PV  05GTWY_BN06:XT61B18.PNT  TT61B05.PV  05GTWY_BN06:XT61B17.PNT  \
# 0 -0.558801    0.183875                 0.592684    0.571180
# 1  0.616395    0.271142                 0.582961    0.545826
# 2  0.608037    0.197154                 0.584581    0.424483
# 3  0.599680    0.384969                 0.586201    0.609817
# 4  0.673095    0.317938                 0.582960    0.756514
#
#    05GTWY_BN06:XT61B12.PNT         ...            F61221  TT61B03.PV  \
# 0  0.680249                        ...          0.814552  1.384925
# 1  0.656337                        ...          0.813250  1.387541
# 2  0.812336                        ...          0.813250  1.395389
# 3  0.800949                        ...          0.813250  1.403238
# 4  0.619899                        ...          0.813250  1.394082
#
#    TC63109E.AV  PT63103.PV  PT61A98.PV  05GTWY_BN06:XT61B20.PNT  PT61B00.PV  \
# 0  0.586338     0.297278    0.825295    0.870151                 0.900861
# 1  0.586338     0.684954    0.823961    0.987437                 0.991854
# 2  0.586338     0.579520    0.817293    1.122158                 0.979575
# 3  0.586338     0.474085    0.810624    1.054797                 0.967296
# 4  0.586338     0.586616    0.830058    1.054797                 0.918651
#
#    TT61B04.PV  labels            datetime
# 0  1.021560    1      2014-01-21 14:40:01
# 1  1.033388    1      2014-01-21 14:51:01
# 2  1.037331    1      2014-01-21 14:52:01
# 3  1.041274    1      2014-01-21 14:53:01
# 4  1.031417    1      2014-01-21 14:54:01
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Unique Labels

# %%
from collections import Counter

labels = df_labels['labels']

print(np.unique(labels))

print(Counter(labels))
# Out:
# [0 1]
# Counter({1: 1587239, 0: 214})

# %% [markdown]
# ### Bar chart for Cluster Distribution

# %%
from collections import Counter

counter = Counter(labels)

frequency_dict = {}
for k in counter:
    v = counter[k]
    frequency_dict[k] = v
    
plt.rcParams['figure.figsize'] = [15, 10] # Size of the plots

x = list(frequency_dict.keys())
x = list(map(str, x))
y = list(frequency_dict.values())

for i, v in enumerate(y):
    v = round(v, 3)
    plt.text(i-.25, v + .25, str(v), color='blue', fontweight='bold')

plt.bar(x,y)
plt.xlabel('Cluster No.')
plt.ylabel('Total Instances')
plt.xticks(x, x, rotation=45)
plt.show()

# %% [markdown]
# ## DBSCAN Outlier Graphs

# %% [markdown]
# ### Clusters numbers that can be considered outliers

# %%
clusters_to_plot = [0]

# %% [markdown]
# ### Number of Outliers

# %%
df_outlier = df_labels.loc[df_labels['labels'].isin(clusters_to_plot)].copy()
outlier_count = len(df_outlier)
print(len(df_outlier))
# Out:
# 214

# %% [markdown]
# ### Outlier dates

# %%
df_outlier[time_col].values
# Out:
# array(['2014-02-23T23:21:01.000000000', '2014-03-04T01:51:01.000000000',
#        '2014-03-25T05:04:01.000000000', '2014-05-05T10:41:01.000000000',
#        '2014-05-15T12:23:01.000000000', '2014-05-22T10:11:01.000000000',
#        '2014-06-01T18:56:01.000000000', '2014-06-05T20:47:01.000000000',
#        '2014-06-26T14:57:01.000000000', '2014-06-29T11:13:01.000000000',
#        '2018-04-03T06:31:01.000000000', '2018-04-20T23:11:01.000000000',
#        '2018-04-24T00:12:01.000000000', '2018-04-24T09:43:01.000000000',
#        '2018-04-26T03:30:01.000000000', '2018-04-26T16:30:01.000000000',
#        '2018-04-29T16:05:01.000000000', '2018-04-30T15:03:01.000000000',
#        '2018-05-06T03:01:01.000000000', '2018-05-07T15:40:01.000000000',
#        '2018-05-11T02:35:01.000000000', '2018-05-20T07:30:01.000000000',
#        '2018-05-24T16:12:01.000000000', '2018-05-25T17:39:01.000000000',
#        '2018-06-08T15:17:01.000000000', '2018-06-13T16:12:01.000000000',
#        '2018-06-19T14:50:01.000000000', '2018-06-20T10:35:01.000000000',
#        '2018-06-24T15:45:01.000000000', '2018-06-27T08:47:01.000000000',
#        '2018-06-28T23:37:01.000000000', '2018-06-29T04:26:01.000000000',
#        '2018-07-11T19:23:01.000000000', '2018-07-18T16:08:01.000000000',
#        '2018-07-21T10:56:01.000000000', '2018-07-23T14:24:01.000000000',
#        '2018-07-27T06:45:01.000000000', '2018-07-28T02:52:01.000000000',
#        '2018-08-17T19:08:01.000000000', '2018-08-27T12:43:01.000000000',
#        '2018-08-27T15:51:01.000000000', '2018-08-30T07:32:01.000000000',
#        '2018-09-02T03:33:01.000000000', '2018-09-06T04:30:01.000000000',
#        '2018-09-10T15:31:01.000000000', '2018-09-17T19:06:01.000000000',
#        '2018-09-19T19:00:01.000000000', '2018-09-29T19:03:01.000000000',
#        '2018-10-02T00:45:01.000000000', '2018-10-03T22:20:01.000000000',
#        '2018-10-12T21:18:01.000000000', '2018-10-14T09:50:01.000000000',
#        '2018-10-23T09:29:01.000000000', '2018-10-28T02:59:01.000000000',
#        '2018-11-03T01:13:01.000000000', '2018-11-12T12:37:01.000000000',
#        '2018-11-13T07:59:01.000000000', '2018-11-15T23:57:01.000000000'],
#       dtype='datetime64[ns]')

# %%
df_outlier['dates'] = df_outlier[time_col].apply(lambda x: x.date())

# %%
astart = datetime.strptime('2017-06-01 00:00:01', fmt)
aend = datetime.strptime('2017-07-01 00:00:01', fmt)

df_outlier.loc[(df_outlier['datetime'] < aend) & (df_outlier['datetime'] > astart)]
# Out:
#             agg1  PC63112E.AV  05GTWY_BN06:XT61B19.PNT  TT61B06.PV  \
# 1033070  1796606  0.054785     0.165308                -0.397760
# 1036084  1799689  0.054785     0.642267                -0.490405
# 1036724  1800702  0.054785     0.713682                -0.569976
# 1037683  1802119  0.054785    -1.301275                -0.797323
# 1038688  1803738  0.054785     0.462026                -0.172119
# 1038737  1803813  0.054785     0.831010                 0.336003
# 1039912  1805019  0.054785     0.534292                -0.246007
# 1040602  1805801  0.054785     0.713682                -0.514276
# 1040709  1806421  0.054785     0.515588                -0.457439
# 1041824  1807948  0.054785     0.795302                -0.715478
# 1042408  1809270  0.054785    -1.301275                -1.228146
# 1043025  1810824  0.054785     0.560648                -0.474491
# 1044002  1812266  0.054785    -1.301275                -0.333535
# 1045433  1814242  0.054785    -1.310627                -0.460849
# 1045601  1815078  0.054785     0.381257                -0.810964
# 2017-10-26
# 2017-10-28
# 2017-11-01
# 2017-11-05
# 2017-11-07
# 2017-11-13
# 2017-11-15
# 2017-11-18
# 2017-11-22
# 2017-11-23
# 2017-11-25
# 2017-11-26
# 2017-12-04
# 2017-12-11
# 2017-12-17
# 2017-12-22
# 2017-12-26
# 2017-12-27
# 2017-12-29
# 2018-01-02
# 2018-01-07
# 2018-01-09
# 2018-01-19
# 2018-01-21
# 2018-01-24
# 2018-01-25
# 2018-01-27
# 2018-01-29
# 2018-01-30
# 2018-02-01
# 2018-02-03
# 2018-02-09
# 2018-02-11
# 2018-02-17
# 2018-02-19
# 2018-02-20
# 2018-02-28
# 2018-03-01
# 2018-03-08
# 2018-03-12
# 2018-03-13
# 2018-03-24
# 2018-03-25
# 2018-04-03
# 2018-04-20
# 2018-04-24
# 2018-04-26
# 2018-04-29
# 2018-04-30
# 2018-05-06
# 2018-05-07
# 2018-05-11
# 2018-05-20
# 2018-05-24
# 2018-05-25
# 2018-06-08
# 2018-06-13
# 2018-06-19
# 2018-06-20
# 2018-06-24
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-11
# 2018-07-18
# 2018-07-21
# 2018-07-23
# 2018-07-27
# 2018-07-28
# 2018-08-17
# 2018-08-27
# 2018-08-30
# 2018-09-02
# 2018-09-06
# 2018-09-10
# 2018-09-17
# 2018-09-19
# 2018-09-29
# 2018-10-02
# 2018-10-03
# 2018-10-12
# 2018-10-14
# 2018-10-23
# 2018-10-28
# 2018-11-03
# 2018-11-12
# 2018-11-13
# 2018-11-15

# %% [markdown]
# ### Plot graph - function

# %%
def plot_outlier_graph(df_db, feature_set):
    colors = ['b', 'y', 'r', 'c', 'm', 'g', 'k']
    xlabel = 'Time'
    ylabel = 'Value'

    total_plots = len(feature_set)
    cols_plot = 3
    rows_plot = math.ceil(total_plots/cols_plot)

    plt.rcParams['figure.figsize'] = [cols_plot * 10, rows_plot * 7] # Size of the plots        
    plt.figure()

    unq_labels = np.unique(df_db['labels'])
    unq_labels.sort()


    idx = 0
    for feature in feature_set:

        if feature in df_db.columns.values:

            df = df_db[[time_col, feature, 'labels']]

            plt.subplot(rows_plot, cols_plot, idx+1)
            plt.ylabel(ylabel)
            plt.xticks(rotation=45)
            plt.title('Feature - ' + feature)


            for i in range(len(unq_labels)):

                cluster_num = unq_labels[i]
                df_cluster = df[[time_col, feature]].loc[df['labels'] == cluster_num]
                x = np.array(df_cluster[time_col])
                y = np.array(df_cluster[feature])

                if cluster_num in clusters_to_plot:                
                    color = colors[0]
                    size = 10
                    alpha = 1
                else:
                    # color = colors[(cluster_num+1)%len(colors)]
                    color = colors[1]
                    size = 1
                    alpha = 0.1

                plt.scatter(x, y, c=color, alpha=alpha, s=size, label='Cluster'+str(i))

            plt.legend(loc='upper left')

            idx += 1

# %% [markdown]
# ### Plot Graphs

# %%
from utils import get_tags
tag_type = 'vibration'
tags = get_tags(tag_type) 

plot_outlier_graph(df_db=df_labels, feature_set=tags)

# %%
from utils import get_tags
tag_type = 'temperature'
tags = get_tags(tag_type) 

plot_outlier_graph(df_db=df_labels, feature_set=tags)

# %%
from utils import get_tags
tag_type = 'pressure'
tags = get_tags(tag_type) 

plot_outlier_graph(df_db=df_labels, feature_set=tags)

# %%
from utils import get_tags
tag_type = 'flow'
tags = get_tags(tag_type) 

plot_outlier_graph(df_db=df_labels, feature_set=tags)

# %%
from utils import get_tags
tag_type = 'alarm'
tags = get_tags(tag_type) 

plot_outlier_graph(df_db=df_labels, feature_set=tags)

# %%
def plot_outlier_graph_interval(df_db, feature_set, start_date, end_date):
    
    colors = ['b', 'y', 'r', 'c', 'm', 'g', 'k']
    xlabel = 'Time'
    ylabel = 'Value'

    total_plots = len(feature_set)
    cols_plot = 3
    rows_plot = math.ceil(total_plots/cols_plot)

    plt.rcParams['figure.figsize'] = [cols_plot * 10, rows_plot * 7] # Size of the plots        
    plt.figure()
    
    df_db = df_db.loc[(df_db[time_col] >= start_date) & (df_db[time_col] <= end_date)]

    unq_labels = np.unique(df_db['labels'])
    unq_labels.sort()

    idx = 0
    for feature in feature_set:

        if feature in df_db.columns.values:

            df = df_db[[time_col, feature, 'labels']]

            plt.subplot(rows_plot, cols_plot, idx+1)
            plt.ylabel(ylabel)
            plt.xticks(rotation=45)
            plt.title('Feature - ' + feature)


            for i in range(len(unq_labels)):

                cluster_num = unq_labels[i]
                df_cluster = df[[time_col, feature]].loc[df['labels'] == cluster_num]
                x = np.array(df_cluster[time_col])
                y = np.array(df_cluster[feature])

                if cluster_num in clusters_to_plot:                
                    color = colors[0]
                    size = 10
                    alpha = 1
                else:
                    # color = colors[(cluster_num+1)%len(colors)]
                    color = colors[1]
                    size = 1
                    alpha = 0.1

                plt.scatter(x, y, c=color, alpha=alpha, s=size, label='Cluster'+str(i))

            plt.legend(loc='upper left')

            idx += 1

# %%
from utils import get_tags
tag_type = 'vibration'
tags = get_tags(tag_type)
plot_start_date = datetime.strptime('2018-01-01 00:00:01', fmt)
plot_stop_date = datetime.strptime('2018-02-01 00:00:01', fmt)

plot_outlier_graph_interval(df_db=df_labels, feature_set=tags, start_date=plot_start_date, end_date=plot_stop_date)

# %%
from utils import get_tags
tag_type = 'temperature'
tags = get_tags(tag_type) 
plot_start_date = datetime.strptime('2018-01-01 00:00:01', fmt)
plot_stop_date = datetime.strptime('2018-02-01 00:00:01', fmt)

plot_outlier_graph_interval(df_db=df_labels, feature_set=tags, start_date=plot_start_date, end_date=plot_stop_date)

# %%
from utils import get_tags
tag_type = 'pressure'
tags = get_tags(tag_type) 
plot_start_date = datetime.strptime('2018-01-01 00:00:01', fmt)
plot_stop_date = datetime.strptime('2018-02-01 00:00:01', fmt)

plot_outlier_graph_interval(df_db=df_labels, feature_set=tags, start_date=plot_start_date, end_date=plot_stop_date)

# %%
from utils import get_tags
tag_type = 'flow'
tags = get_tags(tag_type) 
plot_start_date = datetime.strptime('2018-01-01 00:00:01', fmt)
plot_stop_date = datetime.strptime('2018-02-01 00:00:01', fmt)

plot_outlier_graph_interval(df_db=df_labels, feature_set=tags, start_date=plot_start_date, end_date=plot_stop_date)
