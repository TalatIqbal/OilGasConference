# %% [markdown]
# # P2253 - Data Wrangling based on the tags available in Data string

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import os
import ntpath
import pickle as pkl
import xlrd
import time
import string
from os.path import basename

# %%
pd.set_option('display.max_colwidth', -1)

# %%
RAW_DATA_DIR = '../data/raw/P2253/'
PROC_DATA_DIR = '../data/processed/P2253/'
INT_DATA_DIR = '../data/interim/P2253/'

# %%
def remove_punctuation(x):
    table = str.maketrans({key: None for key in string.punctuation})
    return x.translate(table)

# %% [markdown]
# ### Functions

# %%
def remove_punctuation(x):
    table = str.maketrans({key: None for key in string.punctuation})
    return x.translate(table)

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
def get_time(dt_str):
    dt_str = dt_str.strip()
    dtobj = datetime.strptime(dt_str, '%m/%d/%Y %I:%M:%S %p')
    return dtobj

# %%
def parse(txt):
    '''
    @{PIPoint=SCTM:22GTWY_E403:FALE22E23SP.PNT; Value=60; Timestamp=12/30/2017 11:48:05 PM}
    '''
    pi_point, val, time  = None, None, None
    delimiter = ';'
    sub_delimiter = '='
    
    txt = txt[txt.find('{')+1:txt.find('}')]    
    parsed_vals = txt.split(';')
    
    if len(parsed_vals) >= 3:
        pi_point = parsed_vals[0].split(sub_delimiter)[1]
    
        if pi_point is not None:
            values = parsed_vals[1].split(sub_delimiter)
            if len(values) >= 2:
                val = values[1]
                if is_number(val):
                    val = float(val)
                else:
                    val = None
            else:
                val = None

            time_vals = parsed_vals[2].split(sub_delimiter)
            if len(time_vals) >= 2:
                time = time_vals[1]
                time = get_time(time)
            else:
                return None, None, None

    if pi_point is not None:
        pi_point = pi_point.replace('SCTM:', '')
    
    return pi_point, val, time

# %%
def longestSubstringFinder(string1, string2):
    '''
    Code from https://stackoverflow.com/questions/18715688/find-common-substring-between-two-strings    
    '''
    answer = ""
    len1, len2 = len(string1), len(string2)
    for i in range(len1):
        match = ""
        for j in range(len2):
            if (i + j < len1 and string1[i + j] == string2[j]):
                match += string2[j]
            else:
                if (len(match) > len(answer)): answer = match
                match = ""
    return answer

# %% [markdown]
# ### Reading of Data - Using tags to uniquely identify

# %%
data = {} # Contains mapping between tags and data
tag_files = {} # Contains mapping between tags and the file names
files_tag = {} # Contains the mapping between file names and tags

dir_files = os.listdir(RAW_DATA_DIR)

print('No of files in %s is %d' % (RAW_DATA_DIR, len(dir_files)))

for current_file in dir_files:

    current_base = current_file
    current_file = RAW_DATA_DIR + current_file

    if current_base.endswith('.csv'):
        print('Processing ', current_file, '\t', end='')
        df = pd.read_csv(current_file, header=None)

    df['feature'], df['val'], df['datetime'] = zip(*df[0].map(parse))

    df = df[df['feature'] != None]
    df = df[df['datetime'].notnull()]

    tags = np.unique(df['feature'])

    
    print('Tags Found = ', tags)

    for tag in tags:
        df_tag = df.loc[df['feature'] == tag]

        print('Intersection = ', longestSubstringFinder(tag, current_base))

        if tag not in data.keys():
            data[tag] = pd.DataFrame(columns=df_tag.columns.values)
        data[tag] = data[tag].append(df_tag)
# Out:
# No of files in ../data/raw/P2253/ is 96
# Processing  ../data/raw/P2253/IX22E472018.csv 	Tags Found =  ['22PM53CPM:IX22E47.PNT']
# Intersection =  IX22E47
# Processing  ../data/raw/P2253/XI22F26Y2017.csv 	Tags Found =  ['UBNV05CPB:XI22F26Y.PNT']
# Intersection =  XI22F26Y
# Processing  ../data/raw/P2253/22E24PNT2017.csv 	Tags Found =  ['22GTWY_E403:PDIE22E24.PNT']
# Intersection =  22E24
# Processing  ../data/raw/P2253/E23SP2018.csv 	Tags Found =  ['22GTWY_E402:PALE22F32SP.PNT']
# Intersection =  E2
# Processing  ../data/raw/P2253/FQI22E222018.csv 	Tags Found =  ['22P53CP4:FQI22E22.OUT']
# Intersection =  FQI22E22
# Processing  ../data/raw/P2253/XI22F30X2017.csv 	Tags Found =  ['UBNV05CPB:XI22F30X.PNT']
# Intersection =  XI22F30X
# Processing  ../data/raw/P2253/PI22F312018.csv 	Tags Found =  ['22P53CP4:PI22F31.PNT']
# Intersection =  PI22F31
# Processing  ../data/raw/P2253/XI22F29X2018.csv 	Tags Found =  ['UBNV05CPB:XI22F29X.PNT']
# Intersection =  XI22F29X
# Processing  ../data/raw/P2253/TI22F15A2018.csv 	Tags Found =  ['22PM53CPM:TI22F15A.PNT']
# Intersection =  TI22F15A
# Processing  ../data/raw/P2253/TI22F122017.csv 	Tags Found =  ['22P53CP4:TI22F12.PNT']
# Intersection =  TI22F12
# Processing  ../data/raw/P2253/Flow_balance2018.csv 	Tags Found =  ['TMP:HCU_P2253_Flow_Balance.Cal']
# Intersection =  alance
# Processing  ../data/raw/P2253/TC22F38SPT2017.csv 	Tags Found =  ['22P53CP4:TC22F38.SPT']
# Intersection =  TC22F38
# Processing  ../data/raw/P2253/FXC22E222018.csv 	Tags Found =  ['22P53CP4:FXC22E22.MEAS']
# Intersection =  FXC22E22
# Processing  ../data/raw/P2253/FC22E042017.csv 	Tags Found =  ['22P53CP4:FC22E04.MEAS']
# Intersection =  FC22E04
# Processing  ../data/raw/P2253/ZI22F272017.csv 	Tags Found =  ['UBNV05CPB:ZI22F27.PNT']
# Intersection =  ZI22F27
# Processing  ../data/raw/P2253/22E24SP2017.csv 	Tags Found =  ['22GTWY_E403:PDALE22E24SP.PNT']
# Intersection =  22E24SP
# Processing  ../data/raw/P2253/XI22F29Y2018.csv 	Tags Found =  ['UBNV05CPB:XI22F29Y.PNT']
# Intersection =  XI22F29Y
# Tags Found =  ['UBNV05CPB:XI22F29Y.PNT']
# Intersection =  .
# Processing  ../data/raw/P2253/XI22F30Y2017.csv 	Tags Found =  ['UBNV05CPB:XI22F30Y.PNT']
# Intersection =  XI22F30Y
# Processing  ../data/raw/P2253/TI22F19A_B2017.csv 	Tags Found =  ['22PM53CPM:TI22F19A.PNT' '22PM53CPM:TI22F19B.PNT']
# Intersection =  TI22F19A
# Intersection =  TI22F19
# Processing  ../data/raw/P2253/TI22F132017.csv 	Tags Found =  ['22P53CP4:TI22F13.PNT']
# Intersection =  TI22F13
# Processing  ../data/raw/P2253/FX22E22SP2018.csv 	Tags Found =  ['22P53CP4:FX22E22SPF.MEAS']
# Intersection =  FX22E22SP
# Processing  ../data/raw/P2253/FC22E22out2018.csv 	Tags Found =  ['22P53CP4:FC22E22.OUT']
# Intersection =  FC22E22
# Processing  ../data/raw/P2253/FXC22E22out2017.csv 	Tags Found =  ['22P53CP4:FXC22E22.OUT']
# Intersection =  FXC22E22
# Processing  ../data/raw/P2253/XI22F26X2017.csv 	Tags Found =  ['UBNV05CPB:XI22F26X.PNT']
# Intersection =  XI22F26X
# Processing  ../data/raw/P2253/FC22E04out2018.csv 	Tags Found =  ['22P53CP4:FC22E04.OUT']
# Intersection =  FC22E04
# Processing  ../data/raw/P2253/TI22F18B2018.csv 	Tags Found =  ['22PM53CPM:TI22F18B.PNT']
# Intersection =  TI22F18B
# Processing  ../data/raw/P2253/TI22F19B2018.csv 	Tags Found =  ['22PM53CPM:TI22F19B.PNT']
# Intersection =  TI22F19B
# Processing  ../data/raw/P2253/FC22E222017.csv 	Tags Found =  ['22P53CP4:FC22E22.MEAS']
# Intersection =  FC22E22
# Processing  ../data/raw/P2253/TI22F15B2018.csv 	Tags Found =  ['22PM53CPM:TI22F15B.PNT']
# Intersection =  TI22F15B
# Processing  ../data/raw/P2253/FC22E22spt2018.csv 	Tags Found =  ['22P53CP4:FC22E22.SPT']
# Intersection =  FC22E22
# Processing  ../data/raw/P2253/PI22E052017.csv 	Tags Found =  ['22P53CP4:PI22E05.PNT']
# Intersection =  PI22E05
# Processing  ../data/raw/P2253/II22E472017.csv 	Tags Found =  ['22PM53CPM:II22E47.PNT']
# Intersection =  II22E47
# Processing  ../data/raw/P2253/FXC22E22spt2017.csv 	Tags Found =  ['22P53CP4:FXC22E22.SPT']
# Intersection =  FXC22E22
# Processing  ../data/raw/P2253/FX22E22SPF2017.csv 	Tags Found =  ['22P53CP4:FX22E22SPF.MEAS']
# Intersection =  FX22E22SPF
# Processing  ../data/raw/P2253/E232018.csv 	Tags Found =  ['22GTWY_E403:FIE22E23.PNT']
# Intersection =  E23
# Processing  ../data/raw/P2253/22E23SP2017.csv 	Tags Found =  ['22GTWY_E402:PIE22F32.PNT' '22GTWY_E403:FALE22E23SP.PNT']
# Intersection =  22
# Intersection =  22E23SP
# Processing  ../data/raw/P2253/TI22F112017.csv 	Tags Found =  ['22P53CP4:TI22F11.PNT']
# Intersection =  TI22F11
# Processing  ../data/raw/P2253/XI22F25Y2018.csv 	Tags Found =  ['UBNV05CPB:XI22F25Y.PNT']
# Intersection =  XI22F25Y
# Processing  ../data/raw/P2253/TI22F142018.csv 	Tags Found =  ['22P53CP4:TI22F14.PNT']
# Intersection =  TI22F14
# Processing  ../data/raw/P2253/22F33 22F37 22F36 2018.csv 	Tags Found =  ['22P53CP4:LIE22F36.PNT' '22P53CP4:PDI22F33.PNT' '22P53CP4:TI22F37.PNT']
# Intersection =  22F36
# Intersection =  22F33
# Intersection =  22F37
# Processing  ../data/raw/P2253/XI22F25X2018.csv 	Tags Found =  ['UBNV05CPB:XI22F25X.PNT']
# Intersection =  XI22F25X
# Processing  ../data/raw/P2253/TI22F18A2018.csv 	Tags Found =  ['22PM53CPM:TI22F18A.PNT']
# Intersection =  TI22F18A
# Processing  ../data/raw/P2253/TI22F19A2018.csv 	Tags Found =  ['22PM53CPM:TI22F19A.PNT']
# Intersection =  TI22F19A
# Processing  ../data/raw/P2253/E24SP2018.csv 	Tags Found =  ['22GTWY_E403:PDALE22E24SP.PNT']
# Intersection =  E24SP
# Processing  ../data/raw/P2253/TC22F38out2017.csv 	Tags Found =  ['22P53CP4:TC22F38.OUT']
# Intersection =  TC22F38
# Processing  ../data/raw/P2253/TI22F16A_B2017.csv 	Tags Found =  ['22PM53CPM:TI22F16A.PNT' '22PM53CPM:TI22F16B.PNT']
# Intersection =  TI22F16A
# Intersection =  TI22F16
# Processing  ../data/raw/P2253/ZI22F282018.csv 	Tags Found =  ['UBNV05CPB:ZI22F28.PNT']
# Intersection =  ZI22F28
# Processing  ../data/raw/P2253/FX22E22CMP2017.csv 	Tags Found =  ['22P53CP4:FX22E22CMP.PNT']
# Intersection =  FX22E22CMP
# Processing  ../data/raw/P2253/XI22F25X2017.csv 	Tags Found =  ['UBNV05CPB:XI22F25X.PNT']
# Intersection =  XI22F25X
# Processing  ../data/raw/P2253/TI22F18A_B2017.csv 	Tags Found =  ['22PM53CPM:TI22F18A.PNT' '22PM53CPM:TI22F18B.PNT']
# Intersection =  TI22F18A
# Intersection =  TI22F18
# Processing  ../data/raw/P2253/TC22F382017.csv 	Tags Found =  ['22P53CP4:TC22F38.MEAS']
# Intersection =  TC22F38
# Processing  ../data/raw/P2253/F32SP2018.csv 	Tags Found =  ['22GTWY_E402:PALE22F32SP.PNT']
# Intersection =  F32SP
# Processing  ../data/raw/P2253/ZI22F282017.csv 	Tags Found =  ['UBNV05CPB:ZI22F28.PNT']
# Intersection =  ZI22F28
# Processing  ../data/raw/P2253/FX22E22CMP2018.csv 	Tags Found =  ['22P53CP4:FX22E22CMP.PNT']
# Intersection =  FX22E22CMP
# Processing  ../data/raw/P2253/TC22F3812018.csv 	Tags Found =  ['22P53CP4:TC22F38.MEAS']
# Intersection =  TC22F38
# Processing  ../data/raw/P2253/TI22F15B2017.csv 	Tags Found =  ['22PM53CPM:TI22F15B.PNT']
# Intersection =  TI22F15B
# Processing  ../data/raw/P2253/SI22F232017.csv 	Tags Found =  ['UBNV05CPB:SI22F23.PNT']
# Intersection =  SI22F23
# Processing  ../data/raw/P2253/FC22E22SPT2017.csv 	Tags Found =  ['22P53CP4:FC22E22.SPT']
# Intersection =  FC22E22
# Processing  ../data/raw/P2253/PI22E052018.csv 	Tags Found =  ['22P53CP4:PI22E05.PNT']
# Intersection =  PI22E05
# Processing  ../data/raw/P2253/II22E472018.csv 	Tags Found =  ['22PM53CPM:II22E47.PNT']
# Intersection =  II22E47
# Processing  ../data/raw/P2253/FC22E04SP2018.csv 	Tags Found =  ['22P53CP4:FC22E04.SPT']
# Intersection =  FC22E04
# Processing  ../data/raw/P2253/FXC22E22SPT2018.csv 	Tags Found =  ['22P53CP4:FXC22E22.SPT']
# Intersection =  FXC22E22
# Processing  ../data/raw/P2253/TI22F16A2018.csv 	Tags Found =  ['22PM53CPM:TI22F16A.PNT']
# Intersection =  TI22F16A
# Processing  ../data/raw/P2253/TI22F17A2018.csv 	Tags Found =  ['22PM53CPM:TI22F17A.PNT']
# Intersection =  TI22F17A
# Processing  ../data/raw/P2253/TI22F112018.csv 	Tags Found =  ['22P53CP4:TI22F11.PNT']
# Intersection =  TI22F11
# Processing  ../data/raw/P2253/TC22F381SPT2018.csv 	Tags Found =  ['22P53CP4:TC22F38.SPT']
# Intersection =  TC22F38
# Processing  ../data/raw/P2253/XI22F25Y2017.csv 	Tags Found =  ['UBNV05CPB:XI22F25Y.PNT']
# Intersection =  XI22F25Y
# Processing  ../data/raw/P2253/TI22F142017.csv 	Tags Found =  ['22P53CP4:TI22F14.PNT']
# Intersection =  TI22F14
# Processing  ../data/raw/P2253/F322018.csv 	Tags Found =  ['22GTWY_E402:PALE22F32SP.PNT']
# Intersection =  F32
# Processing  ../data/raw/P2253/22F322017.csv 	Tags Found =  ['22GTWY_E402:PIE22F32.PNT']
# Intersection =  22F32
# Processing  ../data/raw/P2253/FC22E04SPT2017.csv 	Tags Found =  ['22P53CP4:FC22E04.SPT']
# Intersection =  FC22E04
# Processing  ../data/raw/P2253/FXC22E222017.csv 	Tags Found =  ['22P53CP4:FXC22E22.MEAS']
# Intersection =  FXC22E22
# Processing  ../data/raw/P2253/FC22E042018.csv 	Tags Found =  ['22P53CP4:FC22E04.MEAS']
# Intersection =  FC22E04
# Processing  ../data/raw/P2253/ZI22F272018.csv 	Tags Found =  ['UBNV05CPB:ZI22F27.PNT']
# Intersection =  ZI22F27
# Processing  ../data/raw/P2253/XI22F29Y2017.csv 	Tags Found =  ['UBNV05CPB:XI22F29Y.PNT']
# Intersection =  XI22F29Y
# Processing  ../data/raw/P2253/TC22F381out2018.csv 	Tags Found =  ['22P53CP4:TC22F38.OUT']
# Intersection =  TC22F38
# Processing  ../data/raw/P2253/Flowbalance2017.csv 	Tags Found =  ['TMP:HCU_P2253_Flow_Balance.Cal']
# Intersection =  alance
# Processing  ../data/raw/P2253/XI22F30Y2018.csv 	Tags Found =  ['UBNV05CPB:XI22F30Y.PNT']
# Intersection =  XI22F30Y
# Processing  ../data/raw/P2253/TI22F132018.csv 	Tags Found =  ['22P53CP4:TI22F13.PNT']
# Intersection =  TI22F13
# Processing  ../data/raw/P2253/FC22E22OUT2017.csv 	Tags Found =  ['22P53CP4:FC22E22.OUT']
# Intersection =  FC22E22
# Processing  ../data/raw/P2253/FXC22E22out2018.csv 	Tags Found =  ['22P53CP4:FXC22E22.OUT']
# Intersection =  FXC22E22
# Processing  ../data/raw/P2253/TI22F17A_B2017.csv 	Tags Found =  ['22PM53CPM:TI22F17A.PNT' '22PM53CPM:TI22F17B.PNT']
# Intersection =  TI22F17A
# Intersection =  TI22F17
# Processing  ../data/raw/P2253/XI22F26X2018.csv 	Tags Found =  ['UBNV05CPB:XI22F26X.PNT']
# Intersection =  XI22F26X
# Processing  ../data/raw/P2253/FC22E04OUT2017.csv 	Tags Found =  ['22P53CP4:FC22E04.OUT']
# Intersection =  FC22E04
# Processing  ../data/raw/P2253/E242018.csv 	Tags Found =  ['22GTWY_E403:PDIE22E24.PNT']
# Intersection =  E24
# Processing  ../data/raw/P2253/FC22E222018.csv 	Tags Found =  ['22P53CP4:FC22E22.MEAS']
# Intersection =  FC22E22
# Processing  ../data/raw/P2253/XI22F26Y2018.csv 	Tags Found =  ['UBNV05CPB:XI22F26Y.PNT']
# Intersection =  XI22F26Y
# Processing  ../data/raw/P2253/TI22F16B2018.csv 	Tags Found =  ['22PM53CPM:TI22F16B.PNT']
# Intersection =  TI22F16B
# Processing  ../data/raw/P2253/TI22F17B2018.csv 	Tags Found =  ['22PM53CPM:TI22F17B.PNT']
# Intersection =  TI22F17B
# Processing  ../data/raw/P2253/FQI22E222017.csv 	Tags Found =  ['22P53CP4:FQI22E22.OUT']
# Intersection =  FQI22E22
# Processing  ../data/raw/P2253/XI22F30X2018.csv 	Tags Found =  ['UBNV05CPB:XI22F30X.PNT']
# Intersection =  XI22F30X
# Processing  ../data/raw/P2253/PI22F312017.csv 	Tags Found =  ['22P53CP4:PI22F31.PNT']
# Intersection =  PI22F31
# Processing  ../data/raw/P2253/XI22F29X2017.csv 	Tags Found =  ['UBNV05CPB:XI22F29X.PNT']
# Intersection =  XI22F29X
# Processing  ../data/raw/P2253/TI22F15A2017.csv 	Tags Found =  ['22PM53CPM:TI22F15A.PNT']
# Intersection =  TI22F15A
# Processing  ../data/raw/P2253/TI22F122018.csv 	Tags Found =  ['22P53CP4:TI22F12.PNT']
# Intersection =  TI22F12

# %%
print('Number of distince tags available are ', len(data.keys()))
# Out:
# Number of distince tags available are  54

# %% [markdown]
# ### Find the Minimum date for the items

# %%
# This is to get the base year found among all datasets
for tag, df in data.items():
    
    min_date = df['datetime'].min()
    max_date = df['datetime'].max()
    
    df_temp = df.loc[df['datetime'] == min_date]
    print('Tag = ', tag, '\tShape = ', df_temp.shape, '\t', min_date, '\t', max_date)
# Out:
# Tag =  22PM53CPM:IX22E47.PNT 	Shape =  (1, 4) 	 2018-01-01 00:00:29 	 2018-09-21 08:13:30
# Tag =  UBNV05CPB:XI22F26Y.PNT 	Shape =  (1, 4) 	 2017-06-22 05:10:45 	 2018-09-21 12:49:15
# Tag =  22GTWY_E403:PDIE22E24.PNT 	Shape =  (1, 4) 	 2017-06-21 21:16:40 	 2018-09-18 11:21:10
# Tag =  22GTWY_E402:PALE22F32SP.PNT 	Shape =  (3, 4) 	 2018-01-01 00:12:45 	 2018-09-18 11:12:14
# Tag =  22P53CP4:FQI22E22.OUT 	Shape =  (1, 4) 	 2017-06-21 21:18:50 	 2018-09-18 12:03:15
# Tag =  UBNV05CPB:XI22F30X.PNT 	Shape =  (1, 4) 	 2017-06-22 05:10:45 	 2018-09-21 13:14:15
# Tag =  22P53CP4:PI22F31.PNT 	Shape =  (1, 4) 	 2017-06-21 21:18:50 	 2018-09-18 13:19:10
# Tag =  UBNV05CPB:XI22F29X.PNT 	Shape =  (1, 4) 	 2017-06-22 05:10:45 	 2018-09-21 12:57:15
# Tag =  22PM53CPM:TI22F15A.PNT 	Shape =  (2, 4) 	 2017-06-21 21:29:35 	 2018-09-21 08:14:25
# Tag =  22P53CP4:TI22F12.PNT 	Shape =  (1, 4) 	 2017-06-21 21:19:15 	 2018-09-20 14:59:14
# Tag =  TMP:HCU_P2253_Flow_Balance.Cal 	Shape =  (1, 4) 	 2017-06-22 05:03:00 	 2018-09-21 08:36:00
# Tag =  22P53CP4:TC22F38.SPT 	Shape =  (1, 4) 	 2017-06-21 21:30:10 	 2018-09-20 14:55:10
# Tag =  22P53CP4:FXC22E22.MEAS 	Shape =  (1, 4) 	 2017-06-21 21:18:50 	 2018-09-18 12:17:10
# Tag =  22P53CP4:FC22E04.MEAS 	Shape =  (1, 4) 	 2017-06-21 21:18:50 	 2018-09-18 11:26:10
# Tag =  UBNV05CPB:ZI22F27.PNT 	Shape =  (1, 4) 	 2017-06-22 05:10:45 	 2018-09-21 13:21:15
# Tag =  22GTWY_E403:PDALE22E24SP.PNT 	Shape =  (1, 4) 	 2017-06-21 21:30:15 	 2018-09-18 11:20:15
# Tag =  UBNV05CPB:XI22F29Y.PNT 	Shape =  (1, 4) 	 2017-06-22 05:10:45 	 2018-09-21 12:59:15
# Tag =  UBNV05CPB:XI22F30Y.PNT 	Shape =  (1, 4) 	 2017-06-22 05:10:45 	 2018-09-21 13:19:15
# Tag =  22PM53CPM:TI22F19A.PNT 	Shape =  (1, 4) 	 2017-06-21 21:29:35 	 2018-09-21 08:35:25
# Tag =  22PM53CPM:TI22F19B.PNT 	Shape =  (1, 4) 	 2017-06-21 21:29:35 	 2018-09-21 08:36:25
# Tag =  22P53CP4:TI22F13.PNT 	Shape =  (1, 4) 	 2017-06-21 21:19:15 	 2018-09-20 15:01:15
# Tag =  22P53CP4:FX22E22SPF.MEAS 	Shape =  (1, 4) 	 2017-06-21 21:18:50 	 2018-09-18 12:12:10
# Tag =  22P53CP4:FC22E22.OUT 	Shape =  (2, 4) 	 2017-06-21 21:18:50 	 2018-09-18 11:58:10
# Tag =  22P53CP4:FXC22E22.OUT 	Shape =  (1, 4) 	 2017-06-21 21:18:50 	 2018-09-18 12:19:10
# Tag =  UBNV05CPB:XI22F26X.PNT 	Shape =  (1, 4) 	 2017-06-22 05:10:45 	 2018-09-21 11:29:14
# Tag =  22P53CP4:FC22E04.OUT 	Shape =  (1, 4) 	 2017-06-21 21:30:10 	 2018-09-18 11:28:10
# Tag =  22PM53CPM:TI22F18B.PNT 	Shape =  (2, 4) 	 2017-06-21 21:29:35 	 2018-09-21 08:35:25
# Tag =  22P53CP4:FC22E22.MEAS 	Shape =  (1, 4) 	 2017-06-21 21:18:50 	 2018-09-18 11:42:09
# Tag =  22PM53CPM:TI22F15B.PNT 	Shape =  (2, 4) 	 2017-06-21 21:29:35 	 2018-09-21 08:30:25
# Tag =  22P53CP4:FC22E22.SPT 	Shape =  (1, 4) 	 2017-06-21 21:18:50 	 2018-09-18 11:59:10
# Tag =  22P53CP4:PI22E05.PNT 	Shape =  (1, 4) 	 2017-06-21 21:18:50 	 2018-09-18 13:17:09
# Tag =  22PM53CPM:II22E47.PNT 	Shape =  (1, 4) 	 2017-06-21 21:19:10 	 2018-09-21 08:07:30
# Tag =  22P53CP4:FXC22E22.SPT 	Shape =  (1, 4) 	 2017-06-21 21:30:10 	 2018-09-18 13:15:09
# Tag =  22GTWY_E403:FIE22E23.PNT 	Shape =  (1, 4) 	 2018-01-01 00:00:50 	 2018-09-18 11:18:10
# Tag =  22GTWY_E402:PIE22F32.PNT 	Shape =  (2, 4) 	 2017-06-21 21:16:50 	 2017-12-30 23:57:50
# Tag =  22GTWY_E403:FALE22E23SP.PNT 	Shape =  (4, 4) 	 2017-06-21 21:30:15 	 2017-12-30 23:48:05
# Tag =  22P53CP4:TI22F11.PNT 	Shape =  (1, 4) 	 2017-06-21 21:19:15 	 2018-09-20 14:56:15
# Tag =  UBNV05CPB:XI22F25Y.PNT 	Shape =  (1, 4) 	 2017-06-22 05:10:45 	 2018-09-21 11:26:15
# Tag =  22P53CP4:TI22F14.PNT 	Shape =  (1, 4) 	 2017-06-21 21:19:15 	 2018-09-21 08:04:15
# Tag =  22P53CP4:LIE22F36.PNT 	Shape =  (1, 4) 	 2018-01-01 00:00:50 	 2018-11-20 13:41:10
# Tag =  22P53CP4:PDI22F33.PNT 	Shape =  (1, 4) 	 2018-01-01 00:00:50 	 2018-11-20 13:41:10
# Tag =  22P53CP4:TI22F37.PNT 	Shape =  (1, 4) 	 2018-01-01 00:00:35 	 2018-11-20 13:41:15
# Tag =  UBNV05CPB:XI22F25X.PNT 	Shape =  (2, 4) 	 2017-06-22 05:10:45 	 2018-09-21 11:24:15
# Tag =  22PM53CPM:TI22F18A.PNT 	Shape =  (2, 4) 	 2017-06-21 21:29:35 	 2018-09-21 08:34:25
# Tag =  22P53CP4:TC22F38.OUT 	Shape =  (1, 4) 	 2017-06-21 21:30:10 	 2018-09-20 14:48:09
# Tag =  22PM53CPM:TI22F16A.PNT 	Shape =  (1, 4) 	 2017-06-21 21:29:35 	 2018-09-21 08:32:25
# Tag =  22PM53CPM:TI22F16B.PNT 	Shape =  (1, 4) 	 2017-06-21 21:29:35 	 2018-09-21 08:32:25
# Tag =  UBNV05CPB:ZI22F28.PNT 	Shape =  (1, 4) 	 2017-06-22 05:10:45 	 2018-09-21 13:24:15
# Tag =  22P53CP4:FX22E22CMP.PNT 	Shape =  (1, 4) 	 2017-06-21 21:18:50 	 2018-09-18 12:05:15
# Tag =  22P53CP4:TC22F38.MEAS 	Shape =  (1, 4) 	 2017-06-21 21:18:50 	 2018-09-18 13:23:10
# Tag =  UBNV05CPB:SI22F23.PNT 	Shape =  (1, 4) 	 2017-06-22 05:10:05 	 2017-12-30 23:59:25
# Tag =  22P53CP4:FC22E04.SPT 	Shape =  (1, 4) 	 2017-06-21 21:30:10 	 2018-09-18 11:40:09
# Tag =  22PM53CPM:TI22F17A.PNT 	Shape =  (1, 4) 	 2017-06-21 21:29:35 	 2018-09-21 08:32:45
# Tag =  22PM53CPM:TI22F17B.PNT 	Shape =  (1, 4) 	 2017-06-21 21:29:35 	 2018-09-21 08:33:25

# %% [markdown]
# ### Writing to Pickle Files

# %%
for tag, df in data.items():
    
    df = df[['feature', 'datetime', 'val']]
    f_name = tag.replace(':', '_')
    pkl_file = INT_DATA_DIR + '/' + f_name + '.pkl'
    print('Writing to file ', pkl_file)
    
    with open(pkl_file, 'wb') as f:
        pkl.dump(df, f, protocol=pkl.HIGHEST_PROTOCOL)
# Out:
# Writing to file  ../data/interim/P2253//22PM53CPM_IX22E47.PNT.pkl
# Writing to file  ../data/interim/P2253//UBNV05CPB_XI22F26Y.PNT.pkl
# Writing to file  ../data/interim/P2253//22GTWY_E403_PDIE22E24.PNT.pkl
# Writing to file  ../data/interim/P2253//22GTWY_E402_PALE22F32SP.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_FQI22E22.OUT.pkl
# Writing to file  ../data/interim/P2253//UBNV05CPB_XI22F30X.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_PI22F31.PNT.pkl
# Writing to file  ../data/interim/P2253//UBNV05CPB_XI22F29X.PNT.pkl
# Writing to file  ../data/interim/P2253//22PM53CPM_TI22F15A.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_TI22F12.PNT.pkl
# Writing to file  ../data/interim/P2253//TMP_HCU_P2253_Flow_Balance.Cal.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_TC22F38.SPT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_FXC22E22.MEAS.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_FC22E04.MEAS.pkl
# Writing to file  ../data/interim/P2253//UBNV05CPB_ZI22F27.PNT.pkl
# Writing to file  ../data/interim/P2253//22GTWY_E403_PDALE22E24SP.PNT.pkl
# Writing to file  ../data/interim/P2253//UBNV05CPB_XI22F29Y.PNT.pkl
# Writing to file  ../data/interim/P2253//UBNV05CPB_XI22F30Y.PNT.pkl
# Writing to file  ../data/interim/P2253//22PM53CPM_TI22F19A.PNT.pkl
# Writing to file  ../data/interim/P2253//22PM53CPM_TI22F19B.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_TI22F13.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_FX22E22SPF.MEAS.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_FC22E22.OUT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_FXC22E22.OUT.pkl
# Writing to file  ../data/interim/P2253//UBNV05CPB_XI22F26X.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_FC22E04.OUT.pkl
# Writing to file  ../data/interim/P2253//22PM53CPM_TI22F18B.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_FC22E22.MEAS.pkl
# Writing to file  ../data/interim/P2253//22PM53CPM_TI22F15B.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_FC22E22.SPT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_PI22E05.PNT.pkl
# Writing to file  ../data/interim/P2253//22PM53CPM_II22E47.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_FXC22E22.SPT.pkl
# Writing to file  ../data/interim/P2253//22GTWY_E403_FIE22E23.PNT.pkl
# Writing to file  ../data/interim/P2253//22GTWY_E402_PIE22F32.PNT.pkl
# Writing to file  ../data/interim/P2253//22GTWY_E403_FALE22E23SP.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_TI22F11.PNT.pkl
# Writing to file  ../data/interim/P2253//UBNV05CPB_XI22F25Y.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_TI22F14.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_LIE22F36.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_PDI22F33.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_TI22F37.PNT.pkl
# Writing to file  ../data/interim/P2253//UBNV05CPB_XI22F25X.PNT.pkl
# Writing to file  ../data/interim/P2253//22PM53CPM_TI22F18A.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_TC22F38.OUT.pkl
# Writing to file  ../data/interim/P2253//22PM53CPM_TI22F16A.PNT.pkl
# Writing to file  ../data/interim/P2253//22PM53CPM_TI22F16B.PNT.pkl
# Writing to file  ../data/interim/P2253//UBNV05CPB_ZI22F28.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_FX22E22CMP.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_TC22F38.MEAS.pkl
# Writing to file  ../data/interim/P2253//UBNV05CPB_SI22F23.PNT.pkl
# Writing to file  ../data/interim/P2253//22P53CP4_FC22E04.SPT.pkl
# Writing to file  ../data/interim/P2253//22PM53CPM_TI22F17A.PNT.pkl
# Writing to file  ../data/interim/P2253//22PM53CPM_TI22F17B.PNT.pkl
